# %%
# !pip install plaid-python
# Out:
# Collecting plaid-python
#   Downloading plaid_python-37.1.0.tar.gz (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 14.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: urllib3>=1.25.3 in /usr/local/lib/python3.12/dist-packages (from plaid-python) (2.5.0)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.12/dist-packages (from plaid-python) (2.9.0.post0)
# Collecting nulltype (from plaid-python)
#   Downloading nulltype-2.3.1-py2.py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil->plaid-python) (1.17.0)
# Downloading nulltype-2.3.1-py2.py3-none-any.whl (11 kB)
# Building wheels for collected packages: plaid-python
#   Building wheel for plaid-python (setup.py) ... done
#   Created wheel for plaid-python: filename=plaid_python-37.1.0-py3-none-any.whl size=5676628 sha256=e53df875ec84995b05bdf3f196196b2880664ad6267fa9e8fbcffad8f4481ff6
#   Stored in directory: /root/.cache/pip/wheels/54/b5/86/dc37590ff3699c9200f0b019f479416ffce4ea0518f15a6f62
# Successfully built plaid-python
# Installing collected packages: nulltype, plaid-python
# Successfully installed nulltype-2.3.1 plaid-python-37.1.0

# %%
import plaid
from plaid.api import plaid_api

# Available environments are
# 'Production'
# 'Sandbox'
configuration = plaid.Configuration(
    host=plaid.Environment.Sandbox,
    api_key={
        'clientId': '6920fa79a844c2001f7b512d',
        'secret': 'ee99b2796f052391ec9e6cf77ddd83',
    }
)

api_client = plaid.ApiClient(configuration)
client = plaid_api.PlaidApi(api_client)

# %%
item_id = 'P6NEABk1Bns5w8E9rWgLIZ3PQgvp7Mc7NaRnP'
access_token = 'access-sandbox-ff2068f9-e386-4145-a53c-66a3028961ac'

# %%
from plaid.model.link_token_create_request import LinkTokenCreateRequest
from plaid.model.country_code import CountryCode
from plaid.model.link_token_create_request_user import LinkTokenCreateRequestUser
from plaid.model.products import Products
import time
from plaid.model.link_token_create_request_statements import LinkTokenCreateRequestStatements
from datetime import date, timedelta
from plaid.model.consumer_report_permissible_purpose import ConsumerReportPermissiblePurpose
from plaid.model.link_token_create_request_cra_options import LinkTokenCreateRequestCraOptions
import json
from flask import Flask, request, jsonify

PLAID_PRODUCTS = ['auth','transactions','signal']
products = []
for product in PLAID_PRODUCTS:
    products.append(Products(product))

PLAID_COUNTRY_CODES=['US','CA']
user_token = None

try:
  request = LinkTokenCreateRequest(
      products=products,
      client_name="Plaid Quickstart",
      country_codes=list(map(lambda x: CountryCode(x), PLAID_COUNTRY_CODES)),
      language='en',
      user=LinkTokenCreateRequestUser(
          client_user_id=str(time.time())
      )
  )
  if Products('statements') in products:
      statements=LinkTokenCreateRequestStatements(
          end_date=date.today(),
          start_date=date.today()-timedelta(days=30)
      )
      request['statements']=statements

  cra_products = ["cra_base_report", "cra_income_insights", "cra_partner_insights"]
  if any(product in cra_products for product in PLAID_PRODUCTS):
      request['user_token'] = user_token
      request['consumer_report_permissible_purpose'] = ConsumerReportPermissiblePurpose('ACCOUNT_REVIEW_CREDIT')
      request['cra_options'] = LinkTokenCreateRequestCraOptions(
          days_requested=60
      )
# create link token
  response = client.link_token_create(request)
  link = response.to_dict()
except plaid.ApiException as e:
  print(e)
  link = json.loads(e.body)

# %%
link
# Out:
# {'link_token': 'link-sandbox-9ade80e0-d734-4467-aa3a-d102c84bdfb8',
#  'expiration': datetime.datetime(2025, 11, 30, 6, 56, 31, tzinfo=tzlocal()),
#  'request_id': '5KRCAKdvIWYbO2h'}

# %%
import plaid
from plaid.model.transactions_sync_request import TransactionsSyncRequest
import datetime

request = TransactionsSyncRequest(
    access_token='access-sandbox-0b0703df-74af-4aed-ba02-a6090349b79e',
)
response = client.transactions_sync(request)
transactions = response['added']

# the transactions in the response are paginated, so make multiple calls while incrementing the cursor to
# retrieve all transactions
while (response['has_more']):
    request = TransactionsSyncRequest(
        access_token=access_token,
        cursor=response['next_cursor']
    )
    response = client.transactions_sync(request)
    transactions += response['added']

# %%
transactions
# Out:
# [{'account_id': 'k5Ev4kkZq6I9wkD1xJr7HZoBJV48zBuLEne6B',
#   'account_owner': None,
#   'amount': 6.33,
#   'authorized_date': datetime.date(2025, 11, 27),
#   'authorized_datetime': None,
#   'category': None,
#   'category_id': None,
#   'check_number': None,
#   'counterparties': [{'confidence_level': 'VERY_HIGH',
#                       'entity_id': 'eyg8o776k0QmNgVpAmaQj4WgzW9Qzo6O51gdd',
#                       'logo_url': 'https://plaid-merchant-logos.plaid.com/uber_1060.png',
#                       'name': 'Uber',
#                       'phone_number': None,
#                       'type': 'merchant',
#                       'website': 'uber.com'}],
#   'date': datetime.date(2025, 11, 28),
#   'datetime': None,
#   'iso_currency_code': 'USD',
#   'location': {'address': None,
#                'city': None,
#                'country': None,
#                'lat': None,
#                'lon': None,
#                'postal_code': None,
#                'region': None,
#                'store_number': None},
#   'logo_url': 'https://plaid-merchant-logos.plaid.com/uber_1060.png',
#   'merchant_entity_id': 'eyg8o776k0QmNgVpAmaQj4WgzW9Qzo6O51gdd',
#   'merchant_name': 'Uber',
#   'name': 'Uber 072515 SF**POOL**',
#   'payment_channel': 'online',
#   'payment_meta': {'by_order_of': None,
#                    'payee': None,
#                    'payer': None,
#                    'payment_method': None,
#                    'payment_processor': None,
#                    'ppd_id': None,
#                    'reason': None,
#                    'reference_number': None},
#   'pending': False,
#   'pending_transaction_id': None,
#   'personal_finance_category': {'confidence_level': 'VERY_HIGH',
#                                 'detailed': 'TRANSPORTATION_TAXIS_AND_RIDE_SHARES',
#                                 'primary': 'TRANSPORTATION',
#                                 'version': 'v1'},
#   'personal_finance_category_icon_url': 'https://plaid-category-icons.plaid.com/PFC_TRANSPORTATION.png',
#   'transaction_code': None,
#   'transaction_id': 'vVXvkAAGPwTmnJo4eNzZIL5ay9Lm4xCqDXr6R',
#   'transaction_type': 'special',
#   'unofficial_currency_code': None,
#   'website': 'uber.com'},
#  {'account_id': 'k5Ev4kkZq6I9wkD1xJr7HZoBJV48zBuLEne6B',
#   'account_owner': None,
#   'amount': 5.4,
#   'authorized_date': datetime.date(2025, 11, 14),
#   'authorized_datetime': None,
#   'category': None,
#   'category_id': None,
#   'check_number': None,
#   'counterparties': [{'confidence_level': 'VERY_HIGH',
#                       'entity_id': 'eyg8o776k0QmNgVpAmaQj4WgzW9Qzo6O51gdd',
#                       'logo_url': 'https://plaid-merchant-logos.plaid.com/uber_1060.png',
#                       'name': 'Uber',
#                       'phone_number': None,
#                       'type': 'merchant',
#                       'website': 'uber.com'}],
#   'date': datetime.date(2025, 11, 15),
#   'datetime': None,
#   'iso_currency_code': 'USD',
#   'location': {'address': None,
#                'city': None,
#                'country': None,
#                'lat': None,
#                'lon': None,
#                'postal_code': None,
#                'region': None,
#                'store_number': None},
#   'logo_url': 'https://plaid-merchant-logos.plaid.com/uber_1060.png',
#   'merchant_entity_id': 'eyg8o776k0QmNgVpAmaQj4WgzW9Qzo6O51gdd',
#   'merchant_name': 'Uber',
#   'name': 'Uber 063015 SF**POOL**',
#   'payment_channel': 'online',
#   'payment_meta': {'by_order_of': None,
#                    'payee': None,
#                    'payer': None,
#                    'payment_method': None,
#                    'payment_processor': None,
#                    'ppd_id': None,
#                    'reason': None,
#                    'reference_number': None},
#   'pending': False,
#   'pending_transaction_id': None,
#   'personal_finance_category': {'confidence_level': 'VERY_HIGH',
#                                 'detailed': 'TRANSPORTATION_TAXIS_AND_RIDE_SHARES',
#                                 'primary': 'TRANSPORTATION',
#                                 'version': 'v1'},
#   'personal_finance_category_icon_url': 'https://plaid-category-icons.plaid.com/PFC_TRANSPORTATION.png',
#   'transaction_code': None,
#   'transaction_id': 'Rg3q9oom5aFBw4m5N3bEIrZJ8xrDkNtaQG8pA',
#   'transaction_type': 'special',
#   'unofficial_currency_code': None,
#   'website': 'uber.com'},
#  {'account_id': 'k5Ev4kkZq6I9wkD1xJr7HZoBJV48zBuLEne6B',
#   'account_owner': None,
#   'amount': -500.0,
#   'authorized_date': datetime.date(2025, 11, 13),
#   'authorized_datetime': None,
#   'category': None,
#   'category_id': None,
#   'check_number': None,
#   'counterparties': [{'confidence_level': 'VERY_HIGH',
#                       'entity_id': 'NKDjqyAdQQzpyeD8qpLnX0D6yvLe2KYKYYzQ4',
#                       'logo_url': 'https://plaid-merchant-logos.plaid.com/united_airlines_1065.png',
#                       'name': 'United Airlines',
#                       'phone_number': None,
#                       'type': 'merchant',
#                       'website': 'united.com'}],
#   'date': datetime.date(2025, 11, 13),
#   'datetime': None,
#   'iso_currency_code': 'USD',
#   'location': {'address': None,
#                'city': None,
#                'country': None,
#                'lat': None,
#                'lon': None,
#                'postal_code': None,
#                'region': None,
#                'store_number': None},
#   'logo_url': 'https://plaid-merchant-logos.plaid.com/united_airlines_1065.png',
#   'merchant_entity_id': 'NKDjqyAdQQzpyeD8qpLnX0D6yvLe2KYKYYzQ4',
#   'merchant_name': 'United Airlines',
#   'name': 'United Airlines',
#   'payment_channel': 'in store',
#   'payment_meta': {'by_order_of': None,
#                    'payee': None,
#                    'payer': None,
#                    'payment_method': None,
#                    'payment_processor': None,
#                    'ppd_id': None,
#                    'reason': None,
#                    'reference_number': None},
#   'pending': False,
#   'pending_transaction_id': None,
#   'personal_finance_category': {'confidence_level': 'VERY_HIGH',
#                                 'detailed': 'TRAVEL_FLIGHTS',
#                                 'primary': 'TRAVEL',
#                                 'version': 'v1'},
#   'personal_finance_category_icon_url': 'https://plaid-category-icons.plaid.com/PFC_TRAVEL.png',
#   'transaction_code': None,
#   'transaction_id': '6Wlp7ddr83fen9w36Ljvs4q8oG4PzWf8Rx4DP',
#   'transaction_type': 'special',
#   'unofficial_currency_code': None,
#   'website': 'united.com'},
#  {'account_id': 'k5Ev4kkZq6I9wkD1xJr7HZoBJV48zBuLEne6B',
#   'account_owner': None,
#   'amount': 12.0,
#   'authorized_date': datetime.date(2025, 11, 12),
#   'authorized_datetime': None,
#   'category': None,
#   'category_id': None,
#   'check_number': None,
#   'counterparties': [{'confidence_level': 'VERY_HIGH',
#                       'entity_id': 'vzWXDWBjB06j5BJoD3Jo84OJZg7JJzmqOZA22',
#                       'logo_url': 'https://plaid-merchant-logos.plaid.com/mcdonalds_619.png',
#                       'name': "McDonald's",
#                       'phone_number': None,
#                       'type': 'merchant',
#                       'website': 'mcdonalds.com'}],
#   'date': datetime.date(2025, 11, 12),
#   'datetime': None,
#   'iso_currency_code': 'USD',
#   'location': {'address': None,
#                'city': None,
#                'country': None,
#                'lat': None,
#                'lon': None,
#                'postal_code': None,
#                'region': None,
#                'store_number': '3322'},
#   'logo_url': 'https://plaid-merchant-logos.plaid.com/mcdonalds_619.png',
#   'merchant_entity_id': 'vzWXDWBjB06j5BJoD3Jo84OJZg7JJzmqOZA22',
#   'merchant_name': "McDonald's",
#   'name': "McDonald's",
#   'payment_channel': 'in store',
#   'payment_meta': {'by_order_of': None,
#                    'payee': None,
#                    'payer': None,
#                    'payment_method': None,
#                    'payment_processor': None,
#                    'ppd_id': None,
#                    'reason': None,
#                    'reference_number': None},
#   'pending': False,
#   'pending_transaction_id': None,
#   'personal_finance_category': {'confidence_level': 'VERY_HIGH',
#                                 'detailed': 'FOOD_AND_DRINK_FAST_FOOD',
#                                 'primary': 'FOOD_AND_DRINK',
#                                 'version': 'v1'},
#   'personal_finance_category_icon_url': 'https://plaid-category-icons.plaid.com/PFC_FOOD_AND_DRINK.png',
#   'transaction_code': None,
#   'transaction_id': 'XnPx9BBX5esjRJ6lZNXqio3BVbozA8IbRxGKk',
#   'transaction_type': 'place',
#   'unofficial_currency_code': None,
#   'website': 'mcdonalds.com'},
#  {'account_id': 'k5Ev4kkZq6I9wkD1xJr7HZoBJV48zBuLEne6B',
#   'account_owner': None,
#   'amount': 4.33,
#   'authorized_date': datetime.date(2025, 11, 12),
#   'authorized_datetime': None,
#   'category': None,
#   'category_id': None,
#   'check_number': None,
#   'counterparties': [{'confidence_level': 'VERY_HIGH',
#                       'entity_id': 'NZAJQ5wYdo1W1p39X5q5gpb15OMe39pj4pJBb',
#                       'logo_url': 'https://plaid-merchant-logos.plaid.com/starbucks_956.png',
#                       'name': 'Starbucks',
#                       'phone_number': None,
#                       'type': 'merchant',
#                       'website': 'starbucks.com'}],
#   'date': datetime.date(2025, 11, 12),
#   'datetime': None,
#   'iso_currency_code': 'USD',
#   'location': {'address': None,
#                'city': None,
#                'country': None,
#                'lat': None,
#                'lon': None,
#                'postal_code': None,
#                'region': None,
#                'store_number': None},
#   'logo_url': 'https://plaid-merchant-logos.plaid.com/starbucks_956.png',
#   'merchant_entity_id': 'NZAJQ5wYdo1W1p39X5q5gpb15OMe39pj4pJBb',
#   'merchant_name': 'Starbucks',
#   'name': 'Starbucks',
#   'payment_channel': 'in store',
#   'payment_meta': {'by_order_of': None,
#                    'payee': None,
#                    'payer': None,
#                    'payment_method': None,
#                    'payment_processor': None,
#                    'ppd_id': None,
#                    'reason': None,
#                    'reference_number': None},
#   'pending': False,
#   'pending_transaction_id': None,
#   'personal_finance_category': {'confidence_level': 'VERY_HIGH',
#                                 'detailed': 'FOOD_AND_DRINK_COFFEE',
#                                 'primary': 'FOOD_AND_DRINK',
#                                 'version': 'v1'},
#   'personal_finance_category_icon_url': 'https://plaid-category-icons.plaid.com/PFC_FOOD_AND_DRINK.png',
#   'transaction_code': None,
#   'transaction_id': 'Da7JvVVZ5LtD3vp5eZ8Ru7ANaE7M1gu38XbWR',
#   'transaction_type': 'place',
#   'unofficial_currency_code': None,
#   'website': 'starbucks.com'},
#  {'account_id': 'k5Ev4kkZq6I9wkD1xJr7HZoBJV48zBuLEne6B',
#   'account_owner': None,
#   'amount': 89.4,
#   'authorized_date': datetime.date(2025, 11, 10),
#   'authorized_datetime': None,
#   'category': None,
#   'category_id': None,
#   'check_number': None,
#   'counterparties': [{'confidence_level': 'LOW',
#                       'entity_id': None,
#                       'logo_url': None,
#                       'name': 'FUN',
#                       'phone_number': None,
#                       'type': 'merchant',
#                       'website': None}],
#   'date': datetime.date(2025, 11, 11),
#   'datetime': None,
#   'iso_currency_code': 'USD',
#   'location': {'address': None,
#                'city': None,
#                'country': None,
#                'lat': None,
#                'lon': None,
#                'postal_code': None,
#                'region': None,
#                'store_number': None},
#   'logo_url': None,
#   'merchant_entity_id': None,
#   'merchant_name': 'FUN',
#   'name': 'SparkFun',
#   'payment_channel': 'in store',
#   'payment_meta': {'by_order_of': None,
#                    'payee': None,
#                    'payer': None,
#                    'payment_method': None,
#                    'payment_processor': None,
#                    'ppd_id': None,
#                    'reason': None,
#                    'reference_number': None},
#   'pending': False,
#   'pending_transaction_id': None,
#   'personal_finance_category': {'confidence_level': 'LOW',
#                                 'detailed': 'ENTERTAINMENT_SPORTING_EVENTS_AMUSEMENT_PARKS_AND_MUSEUMS',
#                                 'primary': 'ENTERTAINMENT',
#                                 'version': 'v1'},
#   'personal_finance_category_icon_url': 'https://plaid-category-icons.plaid.com/PFC_ENTERTAINMENT.png',
#   'transaction_code': None,
#   'transaction_id': 'VA4B9rrR5jtL7p45eGK9IaZBwPaezQC9Jnzgg',
#   'transaction_type': 'place',
#   'unofficial_currency_code': None,
#   'website': None},
#  {'account_id': 'lVE6NddMKGT4QbwldJzNUoKXxn1bjXspWQeo4',
#   'account_owner': None,
#   'amount': 25.0,
#   'authorized_date': datetime.date(2025, 11, 14),
#   'authorized_datetime': None,
#   'category': None,
#   'category_id': None,
#   'check_number': None,
#   'counterparties': [],
#   'date': datetime.date(2025, 11, 15),
#   'datetime': None,
#   'iso_currency_code': 'USD',
#   'location': {'address': None,
#                'city': None,
#                'country': None,
#                'lat': None,
#                'lon': None,
#                'postal_code': None,
#                'region': None,
#                'store_number': None},
#   'logo_url': None,
#   'merchant_entity_id': None,
#   'merchant_name': None,
#   'name': 'CREDIT CARD 3333 PAYMENT *//',
#   'payment_channel': 'other',
#   'payment_meta': {'by_order_of': None,
#                    'payee': None,
#                    'payer': None,
#                    'payment_method': None,
#                    'payment_processor': None,
#                    'ppd_id': None,
#                    'reason': None,
#                    'reference_number': None},
#   'pending': False,
#   'pending_transaction_id': None,
#   'personal_finance_category': {'confidence_level': 'LOW',
#                                 'detailed': 'TRANSFER_OUT_ACCOUNT_TRANSFER',
#                                 'primary': 'TRANSFER_OUT',
#                                 'version': 'v1'},
#   'personal_finance_category_icon_url': 'https://plaid-category-icons.plaid.com/PFC_TRANSFER_OUT.png',
#   'transaction_code': None,
#   'transaction_id': 'wVEvoJJnjGTpwMdV1LW4CNrjGMNzy4fP6lJZX',
#   'transaction_type': 'special',
#   'unofficial_currency_code': None,
#   'website': None},
#  {'account_id': 'lVE6NddMKGT4QbwldJzNUoKXxn1bjXspWQeo4',
#   'account_owner': None,
#   'amount': -4.22,
#   'authorized_date': datetime.date(2025, 11, 10),
#   'authorized_datetime': None,
#   'category': None,
#   'category_id': None,
#   'check_number': None,
#   'counterparties': [],
#   'date': datetime.date(2025, 11, 10),
#   'datetime': None,
#   'iso_currency_code': 'USD',
#   'location': {'address': None,
#                'city': None,
#                'country': None,
#                'lat': None,
#                'lon': None,
#                'postal_code': None,
#                'region': None,
#                'store_number': None},
#   'logo_url': None,
#   'merchant_entity_id': None,
#   'merchant_name': None,
#   'name': 'INTRST PYMNT',
#   'payment_channel': 'other',
#   'payment_meta': {'by_order_of': None,
#                    'payee': None,
#                    'payer': None,
#                    'payment_method': None,
#                    'payment_processor': None,
#                    'ppd_id': None,
#                    'reason': None,
#                    'reference_number': None},
#   'pending': False,
#   'pending_transaction_id': None,
#   'personal_finance_category': {'confidence_level': 'LOW',
#                                 'detailed': 'INCOME_WAGES',
#                                 'primary': 'INCOME',
#                                 'version': 'v1'},
#   'personal_finance_category_icon_url': 'https://plaid-category-icons.plaid.com/PFC_INCOME.png',
#   'transaction_code': None,
#   'transaction_id': '5Epkj66KgBfw5M6EneaKTwlRPvw1Woc5Dp9K1',
#   'transaction_type': 'special',
#   'unofficial_currency_code': None,
#   'website': None},
#  {'account_id': 'k5Ev4kkZq6I9wkD1xJr7HZoBJV48zBuLEne6B',
#   'account_owner': None,
#   'amount': 6.33,
#   'authorized_date': datetime.date(2025, 10, 28),
#   'authorized_datetime': None,
#   'category': None,
#   'category_id': None,
#   'check_number': None,
#   'counterparties': [{'confidence_level': 'VERY_HIGH',
#                       'entity_id': 'eyg8o776k0QmNgVpAmaQj4WgzW9Qzo6O51gdd',
#                       'logo_url': 'https://plaid-merchant-logos.plaid.com/uber_1060.png',
#                       'name': 'Uber',
#                       'phone_number': None,
#                       'type': 'merchant',
#                       'website': 'uber.com'}],
#   'date': datetime.date(2025, 10, 29),
#   'datetime': None,
#   'iso_currency_code': 'USD',
#   'location': {'address': None,
#                'city': None,
#                'country': None,
#                'lat': None,
#                'lon': None,
#                'postal_code': None,
#                'region': None,
#                'store_number': None},
#   'logo_url': 'https://plaid-merchant-logos.plaid.com/uber_1060.png',
#   'merchant_entity_id': 'eyg8o776k0QmNgVpAmaQj4WgzW9Qzo6O51gdd',
#   'merchant_name': 'Uber',
#   'name': 'Uber 072515 SF**POOL**',
#   'payment_channel': 'online',
#   'payment_meta': {'by_order_of': None,
#                    'payee': None,
#                    'payer': None,
#                    'payment_method': None,
#                    'payment_processor': None,
#                    'ppd_id': None,
#                    'reason': None,
#                    'reference_number': None},
#   'pending': False,
#   'pending_transaction_id': None,
#   'personal_finance_category': {'confidence_level': 'VERY_HIGH',
#                                 'detailed': 'TRANSPORTATION_TAXIS_AND_RIDE_SHARES',
#                                 'primary': 'TRANSPORTATION',
#                                 'version': 'v1'},
#   'personal_finance_category_icon_url': 'https://plaid-category-icons.plaid.com/PFC_TRANSPORTATION.png',
#   'transaction_code': None,
#   'transaction_id': 'ZV7aJeel5ZTzWarKvm3MIjGmB5klWWFej1jo3',
#   'transaction_type': 'special',
#   'unofficial_currency_code': None,
#   'website': 'uber.com'},
#  {'account_id': 'k5Ev4kkZq6I9wkD1xJr7HZoBJV48zBuLEne6B',
#   'account_owner': None,
#   'amount': 5.4,
#   'authorized_date': datetime.date(2025, 10, 15),
#   'authorized_datetime': None,
#   'category': None,
#   'category_id': None,
#   'check_number': None,
#   'counterparties': [{'confidence_level': 'VERY_HIGH',
#                       'entity_id': 'eyg8o776k0QmNgVpAmaQj4WgzW9Qzo6O51gdd',
#                       'logo_url': 'https://plaid-merchant-logos.plaid.com/uber_1060.png',
#                       'name': 'Uber',
#                       'phone_number': None,
#                       'type': 'merchant',
#                       'website': 'uber.com'}],
#   'date': datetime.date(2025, 10, 16),
#   'datetime': None,
#   'iso_currency_code': 'USD',
#   'location': {'address': None,
#                'city': None,
#                'country': None,
#                'lat': None,
#                'lon': None,
#                'postal_code': None,
#                'region': None,
#                'store_number': None},
#   'logo_url': 'https://plaid-merchant-logos.plaid.com/uber_1060.png',
#   'merchant_entity_id': 'eyg8o776k0QmNgVpAmaQj4WgzW9Qzo6O51gdd',
#   'merchant_name': 'Uber',
#   'name': 'Uber 063015 SF**POOL**',
#   'payment_channel': 'online',
#   'payment_meta': {'by_order_of': None,
#                    'payee': None,
#                    'payer': None,
#                    'payment_method': None,
#                    'payment_processor': None,
#                    'ppd_id': None,
#                    'reason': None,
#                    'reference_number': None},
#   'pending': False,
#   'pending_transaction_id': None,
#   'personal_finance_category': {'confidence_level': 'VERY_HIGH',
#                                 'detailed': 'TRANSPORTATION_TAXIS_AND_RIDE_SHARES',
#                                 'primary': 'TRANSPORTATION',
#                                 'version': 'v1'},
#   'personal_finance_category_icon_url': 'https://plaid-category-icons.plaid.com/PFC_TRANSPORTATION.png',
#   'transaction_code': None,
#   'transaction_id': 'MMqJmooW5zi7o4d53qPxIWGM1AZbmmhLoRojW',
#   'transaction_type': 'special',
#   'unofficial_currency_code': None,
#   'website': 'uber.com'},
#  {'account_id': 'k5Ev4kkZq6I9wkD1xJr7HZoBJV48zBuLEne6B',
#   'account_owner': None,
#   'amount': -500.0,
#   'authorized_date': datetime.date(2025, 10, 14),
#   'authorized_datetime': None,
#   'category': None,
#   'category_id': None,
#   'check_number': None,
#   'counterparties': [{'confidence_level': 'VERY_HIGH',
#                       'entity_id': 'NKDjqyAdQQzpyeD8qpLnX0D6yvLe2KYKYYzQ4',
#                       'logo_url': 'https://plaid-merchant-logos.plaid.com/united_airlines_1065.png',
#                       'name': 'United Airlines',
#                       'phone_number': None,
#                       'type': 'merchant',
#                       'website': 'united.com'}],
#   'date': datetime.date(2025, 10, 14),
#   'datetime': None,
#   'iso_currency_code': 'USD',
#   'location': {'address': None,
#                'city': None,
#                'country': None,
#                'lat': None,
#                'lon': None,
#                'postal_code': None,
#                'region': None,
#                'store_number': None},
#   'logo_url': 'https://plaid-merchant-logos.plaid.com/united_airlines_1065.png',
#   'merchant_entity_id': 'NKDjqyAdQQzpyeD8qpLnX0D6yvLe2KYKYYzQ4',
#   'merchant_name': 'United Airlines',
#   'name': 'United Airlines',
#   'payment_channel': 'in store',
#   'payment_meta': {'by_order_of': None,
#                    'payee': None,
#                    'payer': None,
#                    'payment_method': None,
#                    'payment_processor': None,
#                    'ppd_id': None,
#                    'reason': None,
#                    'reference_number': None},
#   'pending': False,
#   'pending_transaction_id': None,
#   'personal_finance_category': {'confidence_level': 'VERY_HIGH',
#                                 'detailed': 'TRAVEL_FLIGHTS',
#                                 'primary': 'TRAVEL',
#                                 'version': 'v1'},
#   'personal_finance_category_icon_url': 'https://plaid-category-icons.plaid.com/PFC_TRAVEL.png',
#   'transaction_code': None,
#   'transaction_id': '1pZQammX1qUrmM3qLpBnFoZzQ37laaipwPwnK',
#   'transaction_type': 'special',
#   'unofficial_currency_code': None,
#   'website': 'united.com'},
#  {'account_id': 'k5Ev4kkZq6I9wkD1xJr7HZoBJV48zBuLEne6B',
#   'account_owner': None,
#   'amount': 12.0,
#   'authorized_date': datetime.date(2025, 10, 13),
#   'authorized_datetime': None,
#   'category': None,
#   'category_id': None,
#   'check_number': None,
#   'counterparties': [{'confidence_level': 'VERY_HIGH',
#                       'entity_id': 'vzWXDWBjB06j5BJoD3Jo84OJZg7JJzmqOZA22',
#                       'logo_url': 'https://plaid-merchant-logos.plaid.com/mcdonalds_619.png',
#                       'name': "McDonald's",
#                       'phone_number': None,
#                       'type': 'merchant',
#                       'website': 'mcdonalds.com'}],
#   'date': datetime.date(2025, 10, 13),
#   'datetime': None,
#   'iso_currency_code': 'USD',
#   'location': {'address': None,
#                'city': None,
#                'country': None,
#                'lat': None,
#                'lon': None,
#                'postal_code': None,
#                'region': None,
#                'store_number': '3322'},
#   'logo_url': 'https://plaid-merchant-logos.plaid.com/mcdonalds_619.png',
#   'merchant_entity_id': 'vzWXDWBjB06j5BJoD3Jo84OJZg7JJzmqOZA22',
#   'merchant_name': "McDonald's",
#   'name': "McDonald's",
#   'payment_channel': 'in store',
#   'payment_meta': {'by_order_of': None,
#                    'payee': None,
#                    'payer': None,
#                    'payment_method': None,
#                    'payment_processor': None,
#                    'ppd_id': None,
#                    'reason': None,
#                    'reference_number': None},
#   'pending': False,
#   'pending_transaction_id': None,
#   'personal_finance_category': {'confidence_level': 'VERY_HIGH',
#                                 'detailed': 'FOOD_AND_DRINK_FAST_FOOD',
#                                 'primary': 'FOOD_AND_DRINK',
#                                 'version': 'v1'},
#   'personal_finance_category_icon_url': 'https://plaid-category-icons.plaid.com/PFC_FOOD_AND_DRINK.png',
#   'transaction_code': None,
#   'transaction_id': 'LZlJ9ooE5rHy4Na5BlPvUojqGrz3EEikJWJA8',
#   'transaction_type': 'place',
#   'unofficial_currency_code': None,
#   'website': 'mcdonalds.com'},
#  {'account_id': 'k5Ev4kkZq6I9wkD1xJr7HZoBJV48zBuLEne6B',
#   'account_owner': None,
#   'amount': 4.33,
#   'authorized_date': datetime.date(2025, 10, 13),
#   'authorized_datetime': None,
#   'category': None,
#   'category_id': None,
#   'check_number': None,
#   'counterparties': [{'confidence_level': 'VERY_HIGH',
#                       'entity_id': 'NZAJQ5wYdo1W1p39X5q5gpb15OMe39pj4pJBb',
#                       'logo_url': 'https://plaid-merchant-logos.plaid.com/starbucks_956.png',
#                       'name': 'Starbucks',
#                       'phone_number': None,
#                       'type': 'merchant',
#                       'website': 'starbucks.com'}],
#   'date': datetime.date(2025, 10, 13),
#   'datetime': None,
#   'iso_currency_code': 'USD',
#   'location': {'address': None,
#                'city': None,
#                'country': None,
#                'lat': None,
#                'lon': None,
#                'postal_code': None,
#                'region': None,
#                'store_number': None},
#   'logo_url': 'https://plaid-merchant-logos.plaid.com/starbucks_956.png',
#   'merchant_entity_id': 'NZAJQ5wYdo1W1p39X5q5gpb15OMe39pj4pJBb',
#   'merchant_name': 'Starbucks',
#   'name': 'Starbucks',
#   'payment_channel': 'in store',
#   'payment_meta': {'by_order_of': None,
#                    'payee': None,
#                    'payer': None,
#                    'payment_method': None,
#                    'payment_processor': None,
#                    'ppd_id': None,
#                    'reason': None,
#                    'reference_number': None},
#   'pending': False,
#   'pending_transaction_id': None,
#   'personal_finance_category': {'confidence_level': 'VERY_HIGH',
#                                 'detailed': 'FOOD_AND_DRINK_COFFEE',
#                                 'primary': 'FOOD_AND_DRINK',
#                                 'version': 'v1'},
#   'personal_finance_category_icon_url': 'https://plaid-category-icons.plaid.com/PFC_FOOD_AND_DRINK.png',
#   'transaction_code': None,
#   'transaction_id': 'pVwve99o3yTG6M1zAqQNswaDlpNvXXIpxQx7G',
#   'transaction_type': 'place',
#   'unofficial_currency_code': None,
#   'website': 'starbucks.com'},
#  {'account_id': 'k5Ev4kkZq6I9wkD1xJr7HZoBJV48zBuLEne6B',
#   'account_owner': None,
#   'amount': 89.4,
#   'authorized_date': datetime.date(2025, 10, 11),
#   'authorized_datetime': None,
#   'category': None,
#   'category_id': None,
#   'check_number': None,
#   'counterparties': [{'confidence_level': 'LOW',
#                       'entity_id': None,
#                       'logo_url': None,
#                       'name': 'FUN',
#                       'phone_number': None,
#                       'type': 'merchant',
#                       'website': None}],
#   'date': datetime.date(2025, 10, 12),
#   'datetime': None,
#   'iso_currency_code': 'USD',
#   'location': {'address': None,
#                'city': None,
#                'country': None,
#                'lat': None,
#                'lon': None,
#                'postal_code': None,
#                'region': None,
#                'store_number': None},
#   'logo_url': None,
#   'merchant_entity_id': None,
#   'merchant_name': 'FUN',
#   'name': 'SparkFun',
#   'payment_channel': 'in store',
#   'payment_meta': {'by_order_of': None,
#                    'payee': None,
#                    'payer': None,
#                    'payment_method': None,
#                    'payment_processor': None,
#                    'ppd_id': None,
#                    'reason': None,
#                    'reference_number': None},
#   'pending': False,
#   'pending_transaction_id': None,
#   'personal_finance_category': {'confidence_level': 'LOW',
#                                 'detailed': 'ENTERTAINMENT_SPORTING_EVENTS_AMUSEMENT_PARKS_AND_MUSEUMS',
#                                 'primary': 'ENTERTAINMENT',
#                                 'version': 'v1'},
#   'personal_finance_category_icon_url': 'https://plaid-category-icons.plaid.com/PFC_ENTERTAINMENT.png',
#   'transaction_code': None,
#   'transaction_id': 'xVlvJ55b7GTolMnPJN3AI1r8eABkEEI6EKE5b',
#   'transaction_type': 'place',
#   'unofficial_currency_code': None,
#   'website': None},
#  {'account_id': 'k5Ev4kkZq6I9wkD1xJr7HZoBJV48zBuLEne6B',
#   'account_owner': None,
#   'amount': 6.33,
#   'authorized_date': datetime.date(2025, 9, 28),
#   'authorized_datetime': None,
#   'category': None,
#   'category_id': None,
#   'check_number': None,
#   'counterparties': [{'confidence_level': 'VERY_HIGH',
#                       'entity_id': 'eyg8o776k0QmNgVpAmaQj4WgzW9Qzo6O51gdd',
#                       'logo_url': 'https://plaid-merchant-logos.plaid.com/uber_1060.png',
#                       'name': 'Uber',
#                       'phone_number': None,
#                       'type': 'merchant',
#                       'website': 'uber.com'}],
#   'date': datetime.date(2025, 9, 29),
#   'datetime': None,
#   'iso_currency_code': 'USD',
#   'location': {'address': None,
#                'city': None,
#                'country': None,
#                'lat': None,
#                'lon': None,
#                'postal_code': None,
#                'region': None,
#                'store_number': None},
#   'logo_url': 'https://plaid-merchant-logos.plaid.com/uber_1060.png',
#   'merchant_entity_id': 'eyg8o776k0QmNgVpAmaQj4WgzW9Qzo6O51gdd',
#   'merchant_name': 'Uber',
#   'name': 'Uber 072515 SF**POOL**',
#   'payment_channel': 'online',
#   'payment_meta': {'by_order_of': None,
#                    'payee': None,
#                    'payer': None,
#                    'payment_method': None,
#                    'payment_processor': None,
#                    'ppd_id': None,
#                    'reason': None,
#                    'reference_number': None},
#   'pending': False,
#   'pending_transaction_id': None,
#   'personal_finance_category': {'confidence_level': 'VERY_HIGH',
#                                 'detailed': 'TRANSPORTATION_TAXIS_AND_RIDE_SHARES',
#                                 'primary': 'TRANSPORTATION',
#                                 'version': 'v1'},
#   'personal_finance_category_icon_url': 'https://plaid-category-icons.plaid.com/PFC_TRANSPORTATION.png',
#   'transaction_code': None,
#   'transaction_id': 'dVE1r8845kTGd5NWn1Dqs3JNjXA466SJ3n38q',
#   'transaction_type': 'special',
#   'unofficial_currency_code': None,
#   'website': 'uber.com'},
#  {'account_id': 'k5Ev4kkZq6I9wkD1xJr7HZoBJV48zBuLEne6B',
#   'account_owner': None,
#   'amount': 5.4,
#   'authorized_date': datetime.date(2025, 9, 15),
#   'authorized_datetime': None,
#   'category': None,
#   'category_id': None,
#   'check_number': None,
#   'counterparties': [{'confidence_level': 'VERY_HIGH',
#                       'entity_id': 'eyg8o776k0QmNgVpAmaQj4WgzW9Qzo6O51gdd',
#                       'logo_url': 'https://plaid-merchant-logos.plaid.com/uber_1060.png',
#                       'name': 'Uber',
#                       'phone_number': None,
#                       'type': 'merchant',
#                       'website': 'uber.com'}],
#   'date': datetime.date(2025, 9, 16),
#   'datetime': None,
#   'iso_currency_code': 'USD',
#   'location': {'address': None,
#                'city': None,
#                'country': None,
#                'lat': None,
#                'lon': None,
#                'postal_code': None,
#                'region': None,
#                'store_number': None},
#   'logo_url': 'https://plaid-merchant-logos.plaid.com/uber_1060.png',
#   'merchant_entity_id': 'eyg8o776k0QmNgVpAmaQj4WgzW9Qzo6O51gdd',
#   'merchant_name': 'Uber',
#   'name': 'Uber 063015 SF**POOL**',
#   'payment_channel': 'online',
#   'payment_meta': {'by_order_of': None,
#                    'payee': None,
#                    'payer': None,
#                    'payment_method': None,
#                    'payment_processor': None,
#                    'ppd_id': None,
#                    'reason': None,
#                    'reference_number': None},
#   'pending': False,
#   'pending_transaction_id': None,
#   'personal_finance_category': {'confidence_level': 'VERY_HIGH',
#                                 'detailed': 'TRANSPORTATION_TAXIS_AND_RIDE_SHARES',
#                                 'primary': 'TRANSPORTATION',
#                                 'version': 'v1'},
#   'personal_finance_category_icon_url': 'https://plaid-category-icons.plaid.com/PFC_TRANSPORTATION.png',
#   'transaction_code': None,
#   'transaction_id': 'aVpQl99x58TQZEPvW1yjh9wQBVGxvvTZ9K9jb',
#   'transaction_type': 'special',
#   'unofficial_currency_code': None,
#   'website': 'uber.com'},
#  {'account_id': 'k5Ev4kkZq6I9wkD1xJr7HZoBJV48zBuLEne6B',
#   'account_owner': None,
#   'amount': -500.0,
#   'authorized_date': datetime.date(2025, 9, 14),
#   'authorized_datetime': None,
#   'category': None,
#   'category_id': None,
#   'check_number': None,
#   'counterparties': [{'confidence_level': 'VERY_HIGH',
#                       'entity_id': 'NKDjqyAdQQzpyeD8qpLnX0D6yvLe2KYKYYzQ4',
#                       'logo_url': 'https://plaid-merchant-logos.plaid.com/united_airlines_1065.png',
#                       'name': 'United Airlines',
#                       'phone_number': None,
#                       'type': 'merchant',
#                       'website': 'united.com'}],
#   'date': datetime.date(2025, 9, 14),
#   'datetime': None,
#   'iso_currency_code': 'USD',
#   'location': {'address': None,
#                'city': None,
#                'country': None,
#                'lat': None,
#                'lon': None,
#                'postal_code': None,
#                'region': None,
#                'store_number': None},
#   'logo_url': 'https://plaid-merchant-logos.plaid.com/united_airlines_1065.png',
#   'merchant_entity_id': 'NKDjqyAdQQzpyeD8qpLnX0D6yvLe2KYKYYzQ4',
#   'merchant_name': 'United Airlines',
#   'name': 'United Airlines',
#   'payment_channel': 'in store',
#   'payment_meta': {'by_order_of': None,
#                    'payee': None,
#                    'payer': None,
#                    'payment_method': None,
#                    'payment_processor': None,
#                    'ppd_id': None,
#                    'reason': None,
#                    'reference_number': None},
#   'pending': False,
#   'pending_transaction_id': None,
#   'personal_finance_category': {'confidence_level': 'VERY_HIGH',
#                                 'detailed': 'TRAVEL_FLIGHTS',
#                                 'primary': 'TRAVEL',
#                                 'version': 'v1'},
#   'personal_finance_category_icon_url': 'https://plaid-category-icons.plaid.com/PFC_TRAVEL.png',
#   'transaction_code': None,
#   'transaction_id': '48L1PGGqozUrk6eEZ4MqFPL6gqr988iJxRx68',
#   'transaction_type': 'special',
#   'unofficial_currency_code': None,
#   'website': 'united.com'},
#  {'account_id': 'k5Ev4kkZq6I9wkD1xJr7HZoBJV48zBuLEne6B',
#   'account_owner': None,
#   'amount': 12.0,
#   'authorized_date': datetime.date(2025, 9, 13),
#   'authorized_datetime': None,
#   'category': None,
#   'category_id': None,
#   'check_number': None,
#   'counterparties': [{'confidence_level': 'VERY_HIGH',
#                       'entity_id': 'vzWXDWBjB06j5BJoD3Jo84OJZg7JJzmqOZA22',
#                       'logo_url': 'https://plaid-merchant-logos.plaid.com/mcdonalds_619.png',
#                       'name': "McDonald's",
#                       'phone_number': None,
#                       'type': 'merchant',
#                       'website': 'mcdonalds.com'}],
#   'date': datetime.date(2025, 9, 13),
#   'datetime': None,
#   'iso_currency_code': 'USD',
#   'location': {'address': None,
#                'city': None,
#                'country': None,
#                'lat': None,
#                'lon': None,
#                'postal_code': None,
#                'region': None,
#                'store_number': '3322'},
#   'logo_url': 'https://plaid-merchant-logos.plaid.com/mcdonalds_619.png',
#   'merchant_entity_id': 'vzWXDWBjB06j5BJoD3Jo84OJZg7JJzmqOZA22',
#   'merchant_name': "McDonald's",
#   'name': "McDonald's",
#   'payment_channel': 'in store',
#   'payment_meta': {'by_order_of': None,
#                    'payee': None,
#                    'payer': None,
#                    'payment_method': None,
#                    'payment_processor': None,
#                    'ppd_id': None,
#                    'reason': None,
#                    'reference_number': None},
#   'pending': False,
#   'pending_transaction_id': None,
#   'personal_finance_category': {'confidence_level': 'VERY_HIGH',
#                                 'detailed': 'FOOD_AND_DRINK_FAST_FOOD',
#                                 'primary': 'FOOD_AND_DRINK',
#                                 'version': 'v1'},
#   'personal_finance_category_icon_url': 'https://plaid-category-icons.plaid.com/PFC_FOOD_AND_DRINK.png',
#   'transaction_code': None,
#   'transaction_id': 'N1KJ9ggk5BieMLG5xXNmslRbqaNmLLty1A1lr',
#   'transaction_type': 'place',
#   'unofficial_currency_code': None,
#   'website': 'mcdonalds.com'},
#  {'account_id': 'k5Ev4kkZq6I9wkD1xJr7HZoBJV48zBuLEne6B',
#   'account_owner': None,
#   'amount': 4.33,
#   'authorized_date': datetime.date(2025, 9, 13),
#   'authorized_datetime': None,
#   'category': None,
#   'category_id': None,
#   'check_number': None,
#   'counterparties': [{'confidence_level': 'VERY_HIGH',
#                       'entity_id': 'NZAJQ5wYdo1W1p39X5q5gpb15OMe39pj4pJBb',
#                       'logo_url': 'https://plaid-merchant-logos.plaid.com/starbucks_956.png',
#                       'name': 'Starbucks',
#                       'phone_number': None,
#                       'type': 'merchant',
#                       'website': 'starbucks.com'}],
#   'date': datetime.date(2025, 9, 13),
#   'datetime': None,
#   'iso_currency_code': 'USD',
#   'location': {'address': None,
#                'city': None,
#                'country': None,
#                'lat': None,
#                'lon': None,
#                'postal_code': None,
#                'region': None,
#                'store_number': None},
#   'logo_url': 'https://plaid-merchant-logos.plaid.com/starbucks_956.png',
#   'merchant_entity_id': 'NZAJQ5wYdo1W1p39X5q5gpb15OMe39pj4pJBb',
#   'merchant_name': 'Starbucks',
#   'name': 'Starbucks',
#   'payment_channel': 'in store',
#   'payment_meta': {'by_order_of': None,
#                    'payee': None,
#                    'payer': None,
#                    'payment_method': None,
#                    'payment_processor': None,
#                    'ppd_id': None,
#                    'reason': None,
#                    'reference_number': None},
#   'pending': False,
#   'pending_transaction_id': None,
#   'personal_finance_category': {'confidence_level': 'VERY_HIGH',
#                                 'detailed': 'FOOD_AND_DRINK_COFFEE',
#                                 'primary': 'FOOD_AND_DRINK',
#                                 'version': 'v1'},
#   'personal_finance_category_icon_url': 'https://plaid-category-icons.plaid.com/PFC_FOOD_AND_DRINK.png',
#   'transaction_code': None,
#   'transaction_id': 'PpzJwoon5xUoZd15azN8I3Q49amGWWSo4y4x7',
#   'transaction_type': 'place',
#   'unofficial_currency_code': None,
#   'website': 'starbucks.com'},
#  {'account_id': 'k5Ev4kkZq6I9wkD1xJr7HZoBJV48zBuLEne6B',
#   'account_owner': None,
#   'amount': 89.4,
#   'authorized_date': datetime.date(2025, 9, 11),
#   'authorized_datetime': None,
#   'category': None,
#   'category_id': None,
#   'check_number': None,
#   'counterparties': [{'confidence_level': 'LOW',
#                       'entity_id': None,
#                       'logo_url': None,
#                       'name': 'FUN',
#                       'phone_number': None,
#                       'type': 'merchant',
#                       'website': None}],
#   'date': datetime.date(2025, 9, 12),
#   'datetime': None,
#   'iso_currency_code': 'USD',
#   'location': {'address': None,
#                'city': None,
#                'country': None,
#                'lat': None,
#                'lon': None,
#                'postal_code': None,
#                'region': None,
#                'store_number': None},
#   'logo_url': None,
#   'merchant_entity_id': None,
#   'merchant_name': 'FUN',
#   'name': 'SparkFun',
#   'payment_channel': 'in store',
#   'payment_meta': {'by_order_of': None,
#                    'payee': None,
#                    'payer': None,
#                    'payment_method': None,
#                    'payment_processor': None,
#                    'ppd_id': None,
#                    'reason': None,
#                    'reference_number': None},
#   'pending': False,
#   'pending_transaction_id': None,
#   'personal_finance_category': {'confidence_level': 'LOW',
#                                 'detailed': 'ENTERTAINMENT_SPORTING_EVENTS_AMUSEMENT_PARKS_AND_MUSEUMS',
#                                 'primary': 'ENTERTAINMENT',
#                                 'version': 'v1'},
#   'personal_finance_category_icon_url': 'https://plaid-category-icons.plaid.com/PFC_ENTERTAINMENT.png',
#   'transaction_code': None,
#   'transaction_id': 'jVEvaPPQl9TGkxrAeLVJsKRvVegqzzT63R3N6',
#   'transaction_type': 'place',
#   'unofficial_currency_code': None,
#   'website': None},
#  {'account_id': 'lVE6NddMKGT4QbwldJzNUoKXxn1bjXspWQeo4',
#   'account_owner': None,
#   'amount': 25.0,
#   'authorized_date': datetime.date(2025, 10, 15),
#   'authorized_datetime': None,
#   'category': None,
#   'category_id': None,
#   'check_number': None,
#   'counterparties': [],
#   'date': datetime.date(2025, 10, 16),
#   'datetime': None,
#   'iso_currency_code': 'USD',
#   'location': {'address': None,
#                'city': None,
#                'country': None,
#                'lat': None,
#                'lon': None,
#                'postal_code': None,
#                'region': None,
#                'store_number': None},
#   'logo_url': None,
#   'merchant_entity_id': None,
#   'merchant_name': None,
#   'name': 'CREDIT CARD 3333 PAYMENT *//',
#   'payment_channel': 'other',
#   'payment_meta': {'by_order_of': None,
#                    'payee': None,
#                    'payer': None,
#                    'payment_method': None,
#                    'payment_processor': None,
#                    'ppd_id': None,
#                    'reason': None,
#                    'reference_number': None},
#   'pending': False,
#   'pending_transaction_id': None,
#   'personal_finance_category': {'confidence_level': 'LOW',
#                                 'detailed': 'LOAN_PAYMENTS_OTHER_PAYMENT',
#                                 'primary': 'LOAN_PAYMENTS',
#                                 'version': 'v1'},
#   'personal_finance_category_icon_url': 'https://plaid-category-icons.plaid.com/PFC_LOAN_PAYMENTS.png',
#   'transaction_code': None,
#   'transaction_id': 'QoBlkmmb5di7ZEb5voNyIemX5lAEJJiwdldNa',
#   'transaction_type': 'special',
#   'unofficial_currency_code': None,
#   'website': None},
#  {'account_id': 'lVE6NddMKGT4QbwldJzNUoKXxn1bjXspWQeo4',
#   'account_owner': None,
#   'amount': -4.22,
#   'authorized_date': datetime.date(2025, 10, 11),
#   'authorized_datetime': None,
#   'category': None,
#   'category_id': None,
#   'check_number': None,
#   'counterparties': [],
#   'date': datetime.date(2025, 10, 11),
#   'datetime': None,
#   'iso_currency_code': 'USD',
#   'location': {'address': None,
#                'city': None,
#                'country': None,
#                'lat': None,
#                'lon': None,
#                'postal_code': None,
#                'region': None,
#                'store_number': None},
#   'logo_url': None,
#   'merchant_entity_id': None,
#   'merchant_name': None,
#   'name': 'INTRST PYMNT',
#   'payment_channel': 'other',
#   'payment_meta': {'by_order_of': None,
#                    'payee': None,
#                    'payer': None,
#                    'payment_method': None,
#                    'payment_processor': None,
#                    'ppd_id': None,
#                    'reason': None,
#                    'reference_number': None},
#   'pending': False,
#   'pending_transaction_id': None,
#   'personal_finance_category': {'confidence_level': 'LOW',
#                                 'detailed': 'INCOME_WAGES',
#                                 'primary': 'INCOME',
#                                 'version': 'v1'},
#   'personal_finance_category_icon_url': 'https://plaid-category-icons.plaid.com/PFC_INCOME.png',
#   'transaction_code': None,
#   'transaction_id': 'ZV7aJeel5ZTzWarKvm3MIjGmB5klWWFej1joz',
#   'transaction_type': 'special',
#   'unofficial_currency_code': None,
#   'website': None},
#  {'account_id': 'lVE6NddMKGT4QbwldJzNUoKXxn1bjXspWQeo4',
#   'account_owner': None,
#   'amount': 25.0,
#   'authorized_date': datetime.date(2025, 9, 15),
#   'authorized_datetime': None,
#   'category': None,
#   'category_id': None,
#   'check_number': None,
#   'counterparties': [],
#   'date': datetime.date(2025, 9, 16),
#   'datetime': None,
#   'iso_currency_code': 'USD',
#   'location': {'address': None,
#                'city': None,
#                'country': None,
#                'lat': None,
#                'lon': None,
#                'postal_code': None,
#                'region': None,
#                'store_number': None},
#   'logo_url': None,
#   'merchant_entity_id': None,
#   'merchant_name': None,
#   'name': 'CREDIT CARD 3333 PAYMENT *//',
#   'payment_channel': 'other',
#   'payment_meta': {'by_order_of': None,
#                    'payee': None,
#                    'payer': None,
#                    'payment_method': None,
#                    'payment_processor': None,
#                    'ppd_id': None,
#                    'reason': None,
#                    'reference_number': None},
#   'pending': False,
#   'pending_transaction_id': None,
#   'personal_finance_category': {'confidence_level': 'LOW',
#                                 'detailed': 'LOAN_PAYMENTS_OTHER_PAYMENT',
#                                 'primary': 'LOAN_PAYMENTS',
#                                 'version': 'v1'},
#   'personal_finance_category_icon_url': 'https://plaid-category-icons.plaid.com/PFC_LOAN_PAYMENTS.png',
#   'transaction_code': None,
#   'transaction_id': 'MMqJmooW5zi7o4d53qPxIWGM1AZbmmhLoRojN',
#   'transaction_type': 'special',
#   'unofficial_currency_code': None,
#   'website': None},
#  {'account_id': 'lVE6NddMKGT4QbwldJzNUoKXxn1bjXspWQeo4',
#   'account_owner': None,
#   'amount': -4.22,
#   'authorized_date': datetime.date(2025, 9, 11),
#   'authorized_datetime': None,
#   'category': None,
#   'category_id': None,
#   'check_number': None,
#   'counterparties': [],
#   'date': datetime.date(2025, 9, 11),
#   'datetime': None,
#   'iso_currency_code': 'USD',
#   'location': {'address': None,
#                'city': None,
#                'country': None,
#                'lat': None,
#                'lon': None,
#                'postal_code': None,
#                'region': None,
#                'store_number': None},
#   'logo_url': None,
#   'merchant_entity_id': None,
#   'merchant_name': None,
#   'name': 'INTRST PYMNT',
#   'payment_channel': 'other',
#   'payment_meta': {'by_order_of': None,
#                    'payee': None,
#                    'payer': None,
#                    'payment_method': None,
#                    'payment_processor': None,
#                    'ppd_id': None,
#                    'reason': None,
#                    'reference_number': None},
#   'pending': False,
#   'pending_transaction_id': None,
#   'personal_finance_category': {'confidence_level': 'LOW',
#                                 'detailed': 'INCOME_WAGES',
#                                 'primary': 'INCOME',
#                                 'version': 'v1'},
#   'personal_finance_category_icon_url': 'https://plaid-category-icons.plaid.com/PFC_INCOME.png',
#   'transaction_code': None,
#   'transaction_id': '1pZQammX1qUrmM3qLpBnFoZzQ37laaipwPwnD',
#   'transaction_type': 'special',
#   'unofficial_currency_code': None,
#   'website': None}]

# %%
# Cell 2: Imports + Plaid client configuration

import time
import json
from datetime import date, timedelta

from plaid import ApiClient, Configuration, Environment
from plaid.api import plaid_api

from plaid.model.link_token_create_request import LinkTokenCreateRequest
from plaid.model.country_code import CountryCode
from plaid.model.link_token_create_request_user import LinkTokenCreateRequestUser
from plaid.model.products import Products
from plaid.model.link_token_create_request_statements import LinkTokenCreateRequestStatements
from plaid.model.consumer_report_permissible_purpose import ConsumerReportPermissiblePurpose
from plaid.model.link_token_create_request_cra_options import LinkTokenCreateRequestCraOptions
from plaid.model.link_token_get_request import LinkTokenGetRequest
from plaid.model.item_public_token_exchange_request import ItemPublicTokenExchangeRequest
from plaid.model.plaid_error import PlaidError
import plaid

# ==== CONFIG - FILL THESE IN ====
PLAID_CLIENT_ID = "6920fa79a844c2001f7b512d"
PLAID_SECRET = "ee99b2796f052391ec9e6cf77ddd83"  # use sandbox secret
PLAID_ENV = Environment.Sandbox       # Sandbox for testing

# Create Plaid client
configuration = Configuration(
    host=PLAID_ENV,
    api_key={
        "clientId": PLAID_CLIENT_ID,
        "secret": PLAID_SECRET,
    }
)
api_client = ApiClient(configuration)
client = plaid_api.PlaidApi(api_client)

print("Plaid client initialized in Sandbox ✅")
# Out:
# Plaid client initialized in Sandbox ✅

# %%
# Cell 3 (updated): Create a Link token configured for Hosted Link and print the hosted_link_url

PLAID_PRODUCTS = ['auth', 'transactions', 'signal']   # adjust as needed
products = [Products(p) for p in PLAID_PRODUCTS]

PLAID_COUNTRY_CODES = ['US', 'CA']
user_token = None  # if you use /user/create later, you can plug that in

LINK_TOKEN = None  # will be set below


def create_link_token():
    global LINK_TOKEN

    try:
        # Base Link token request
        link_token_request = LinkTokenCreateRequest(
            products=products,
            client_name="Plaid Colab Demo",  # <= max 30 chars
            country_codes=[CountryCode(c) for c in PLAID_COUNTRY_CODES],
            language="en",
            user=LinkTokenCreateRequestUser(
                client_user_id=str(time.time()),
                # These are optional for your current manual flow,
                # but good to have for when you later use SMS/email delivery.
                phone_number="+14155550123",
                email_address="sandbox-user@example.com",
            ),
        )

        # 🔹 This is the key: enable Hosted Link with an *empty* object
        # Your plaid-python version treats this as a generic object,
        # and Plaid will still return `hosted_link_url` in the response.
        link_token_request['hosted_link'] = {}

        # Optional: if you ever add 'statements' to PLAID_PRODUCTS
        if Products('statements') in products:
            statements = LinkTokenCreateRequestStatements(
                end_date=date.today(),
                start_date=date.today() - timedelta(days=30)
            )
            link_token_request['statements'] = statements

        # Optional: CRA options (only if you actually add CRA products)
        cra_products = ["cra_base_report", "cra_income_insights", "cra_partner_insights"]
        if any(p in cra_products for p in PLAID_PRODUCTS):
            link_token_request['user_token'] = user_token
            link_token_request['consumer_report_permissible_purpose'] = \
                ConsumerReportPermissiblePurpose('ACCOUNT_REVIEW_CREDIT')
            link_token_request['cra_options'] = LinkTokenCreateRequestCraOptions(
                days_requested=60
            )

        response = client.link_token_create(link_token_request)
        data = response.to_dict()

        LINK_TOKEN = data["link_token"]
        hosted_link_url = data.get("hosted_link_url")

        print("✅ Link token created")
        print("LINK_TOKEN:", LINK_TOKEN)
        print()
        print("👉 Open this URL in your browser to complete Hosted Link:")
        print(hosted_link_url)

        return data

    except plaid.ApiException as e:
        print("Plaid API exception while creating link token:")
        try:
            body = json.loads(e.body)
            print(json.dumps(body, indent=2))
        except Exception:
            print(e)
        raise


link_response = create_link_token()
# Out:
# ✅ Link token created
# LINK_TOKEN: link-sandbox-94efc09d-d3f8-44fe-959d-c07638a18ab7
#
# 👉 Open this URL in your browser to complete Hosted Link:
# https://secure.plaid.com/hl/ls49rsp54qq8s399sr404qp52183n63no2

# %%
# Cell 4 (updated): After completing Hosted Link, get public_token and exchange it for access_token

from pprint import pprint  # nicer, no JSON serialization issues

def finalize_link_with_link_token(link_token: str):
    """
    1. /link/token/get -> get public_token (for Hosted Link / Delivery flows)
    2. /item/public_token/exchange -> get access_token
    """
    try:
        # Step 1: get info about Link session, including public_token (if ready)
        get_request = LinkTokenGetRequest(link_token=link_token)
        get_response = client.link_token_get(get_request)
        get_data = get_response.to_dict()

        print("🔍 /link/token/get response (Python dict):")
        pprint(get_data)   # <-- no json.dumps, avoids datetime issue

        public_token = get_data.get("public_token")
        if not public_token:
            print("\n❗ public_token is not available yet.")
            print("   Make sure you fully completed the Hosted Link flow in the browser.")
            return None

        print("\n✅ Got public_token:", public_token)

        # Step 2: exchange public_token for access_token
        exchange_request = ItemPublicTokenExchangeRequest(public_token=public_token)
        exchange_response = client.item_public_token_exchange(exchange_request)
        exchange_data = exchange_response.to_dict()

        access_token = exchange_data["access_token"]
        item_id = exchange_data["item_id"]

        print("\n🎉 SUCCESS")
        print("access_token:", access_token)
        print("item_id:", item_id)

        # In a real app: store access_token securely (DB/secret store)
        return {
            "access_token": access_token,
            "item_id": item_id,
            "exchange_raw": exchange_data,
        }

    except plaid.ApiException as e:
        print("Plaid API exception while finalizing link:")
        try:
            error_body = json.loads(e.body)
            print(json.dumps(error_body, indent=2))
        except Exception:
            print(e)
        return None


# Use the LINK_TOKEN from Cell 3
if LINK_TOKEN is None:
    print("LINK_TOKEN is None – run Cell 3 first.")
else:
    result = finalize_link_with_link_token(LINK_TOKEN)
# Out:
# 🔍 /link/token/get response (Python dict):
# {'created_at': datetime.datetime(2025, 12, 3, 6, 29, 13, tzinfo=tzlocal()),
#  'expiration': datetime.datetime(2025, 12, 3, 6, 59, 14, tzinfo=tzlocal()),
#  'link_sessions': [{'events': [{'event_id': '9d3d6f1a-cadb-49af-b46f-834169d64789',
#                                 'event_metadata': {'institution_id': 'ins_109511',
#                                                    'institution_name': 'Tartan '
#                                                                        'Bank',
#                                                    'request_id': 'F5l8nJpjTJroBbL'},
#                                 'event_name': 'HANDOFF',
#                                 'timestamp': '2025-12-03T06:29:34Z'},
#                                {'event_id': '179e854d-4da6-493c-aba7-710a24f3f6b9',
#                                 'event_metadata': {'institution_id': 'ins_109511',
#                                                    'institution_name': 'Tartan '
#                                                                        'Bank',
#                                                    'request_id': 'TKclCOlBVRhdUdj'},
#                                 'event_name': 'SELECT_INSTITUTION',
#                                 'timestamp': '2025-12-03T06:29:30Z'},
#                                {'event_id': '9af46de8-f7fd-48b0-9c72-38bf4e215fa8',
#                                 'event_metadata': {'request_id': 'TKclCOlBVRhdUdj'},
#                                 'event_name': 'VERIFY_PHONE',
#                                 'timestamp': '2025-12-03T06:29:27Z'},
#                                {'event_id': '0204a628-3f15-45a6-8d6b-2f083af7ea98',
#                                 'event_metadata': {'request_id': 'TKclCOlBVRhdUdj',
#                                                    'view_name': 'SELECT_SAVED_INSTITUTION'},
#                                 'event_name': 'TRANSITION_VIEW',
#                                 'timestamp': '2025-12-03T06:29:27Z'},
#                                {'event_id': '8c334ca9-3362-417e-afdc-e235b9ff572b',
#                                 'event_metadata': {'request_id': 'nd4inxc7TrA4QDR'},
#                                 'event_name': 'SUBMIT_OTP',
#                                 'timestamp': '2025-12-03T06:29:26Z'},
#                                {'event_id': '17759ce9-52db-434b-92a8-6800c6089666',
#                                 'event_metadata': {'request_id': 'nd4inxc7TrA4QDR',
#                                                    'view_name': 'VERIFY_PHONE'},
#                                 'event_name': 'TRANSITION_VIEW',
#                                 'timestamp': '2025-12-03T06:29:23Z'},
#                                {'event_id': 'a3f29886-f9cf-4271-91bb-feb59559e879',
#                                 'event_metadata': {'request_id': '9xG1h2rHZHAvbz5'},
#                                 'event_name': 'SUBMIT_PHONE',
#                                 'timestamp': '2025-12-03T06:29:22Z'},
#                                {'event_id': 'be4ba2aa-30ed-477f-b753-e125d21b8499',
#                                 'event_metadata': {'request_id': '9xG1h2rHZHAvbz5',
#                                                    'view_name': 'SUBMIT_PHONE'},
#                                 'event_name': 'TRANSITION_VIEW',
#                                 'timestamp': '2025-12-03T06:29:16Z'},
#                                {'event_id': 'f5280c6a-9c56-4b18-bb5a-43168ceb8c93',
#                                 'event_metadata': {'request_id': '9xG1h2rHZHAvbz5',
#                                                    'view_name': 'CONSENT'},
#                                 'event_name': 'OPEN',
#                                 'timestamp': '2025-12-03T06:29:16Z'},
#                                {'event_id': '4500cd30-ff83-438c-858a-53ca9dd2f31c',
#                                 'event_metadata': {'request_id': '9xG1h2rHZHAvbz5',
#                                                    'view_name': 'CONSENT'},
#                                 'event_name': 'TRANSITION_VIEW',
#                                 'timestamp': '2025-12-03T06:29:16Z'}],
#                     'finished_at': datetime.datetime(2025, 12, 3, 6, 29, 33, 891408, tzinfo=tzlocal()),
#                     'link_session_id': '019ae2e6-9f3f-77f2-b3d5-6fe273d0ec4e',
#                     'results': {'bank_income_results': [],
#                                 'cra_item_add_results': [],
#                                 'cra_update_results': [],
#                                 'document_income_results': None,
#                                 'item_add_results': [{'accounts': [{'class_type': None,
#                                                                     'id': 'Wa3k6PyvpXczzBQ8rRrRhZdvz9RpXXC6Ba3RL',
#                                                                     'mask': '0000',
#                                                                     'name': 'Plaid '
#                                                                             'Checking',
#                                                                     'subtype': 'checking',
#                                                                     'type': 'depository',
#                                                                     'verification_status': None},
#                                                                    {'class_type': None,
#                                                                     'id': 'ALJK7Bk84wcwwyJ5q6q6hmE3bnM1ggF9BeLpg',
#                                                                     'mask': '1111',
#                                                                     'name': 'Plaid '
#                                                                             'Saving',
#                                                                     'subtype': 'savings',
#                                                                     'type': 'depository',
#                                                                     'verification_status': None},
#                                                                    {'class_type': None,
#                                                                     'id': 'GWJdLNxvRnI66XlzoZoZUdqJWB9NXXi6ZjKpm',
#                                                                     'mask': '9002',
#                                                                     'name': 'Plaid '
#                                                                             'Cash '
#                                                                             'Management',
#                                                                     'subtype': 'cash '
#                                                                                'management',
#                                                                     'type': 'depository',
#                                                                     'verification_status': None}],
#                                                       'institution': {'institution_id': 'ins_109511',
#                                                                       'name': 'Tartan '
#                                                                               'Bank'},
#                                                       'public_token': 'public-sandbox-821623ab-1eed-4962-83fc-e3b66e10d233'}],
#                                 'payroll_income_results': []},
#                     'started_at': datetime.datetime(2025, 12, 3, 6, 29, 16, 593925, tzinfo=tzlocal())}],
#  'link_token': 'link-sandbox-94efc09d-d3f8-44fe-959d-c07638a18ab7',
#  'metadata': {'client_name': 'Plaid Colab Demo',
#               'country_codes': ['US', 'CA'],
#               'initial_products': ['auth', 'signal', 'transactions'],
#               'language': 'en',
#               'redirect_uri': None,
#               'webhook': None},
#  'request_id': 'N7cjFXJpwGjKT6r'}
#
# ❗ public_token is not available yet.
#    Make sure you fully completed the Hosted Link flow in the browser.

# %%
# Cell 4 (updated): After completing Hosted Link, get public_token and exchange it for access_token
# 1. /link/token/get -> get public_token (for Hosted Link / Delivery flows)
# Step 1: get info about Link session, including public_token (if ready)

from pprint import pprint

get_request = LinkTokenGetRequest(link_token=LINK_TOKEN)
get_response = client.link_token_get(get_request)
get_data = get_response.to_dict()

print("🔍 /link/token/get response (Python dict):")
pprint(get_data)   # <-- no json.dumps, avoids datetime issue

if "public_token" in get_data and get_data["public_token"]:
    PUBLIC_TOKEN = get_data["public_token"]

# 2) Hosted Link pattern
for session in get_data.get("link_sessions", []):
    results = session.get("results", {})
    for item_result in results.get("item_add_results", []):
        public_token = item_result.get("public_token")
        if public_token:
            PUBLIC_TOKEN = public_token

if not PUBLIC_TOKEN:
    print("\n❗ public_token is not available yet.")
    print("   Make sure you fully completed the Hosted Link flow in the browser.")


print("\n✅ Got public_token:", public_token)
# Out:
# 🔍 /link/token/get response (Python dict):
# {'created_at': datetime.datetime(2025, 12, 3, 6, 29, 13, tzinfo=tzlocal()),
#  'expiration': datetime.datetime(2025, 12, 3, 6, 59, 14, tzinfo=tzlocal()),
#  'link_sessions': [{'events': [{'event_id': '9d3d6f1a-cadb-49af-b46f-834169d64789',
#                                 'event_metadata': {'institution_id': 'ins_109511',
#                                                    'institution_name': 'Tartan '
#                                                                        'Bank',
#                                                    'request_id': 'F5l8nJpjTJroBbL'},
#                                 'event_name': 'HANDOFF',
#                                 'timestamp': '2025-12-03T06:29:34Z'},
#                                {'event_id': '179e854d-4da6-493c-aba7-710a24f3f6b9',
#                                 'event_metadata': {'institution_id': 'ins_109511',
#                                                    'institution_name': 'Tartan '
#                                                                        'Bank',
#                                                    'request_id': 'TKclCOlBVRhdUdj'},
#                                 'event_name': 'SELECT_INSTITUTION',
#                                 'timestamp': '2025-12-03T06:29:30Z'},
#                                {'event_id': '9af46de8-f7fd-48b0-9c72-38bf4e215fa8',
#                                 'event_metadata': {'request_id': 'TKclCOlBVRhdUdj'},
#                                 'event_name': 'VERIFY_PHONE',
#                                 'timestamp': '2025-12-03T06:29:27Z'},
#                                {'event_id': '0204a628-3f15-45a6-8d6b-2f083af7ea98',
#                                 'event_metadata': {'request_id': 'TKclCOlBVRhdUdj',
#                                                    'view_name': 'SELECT_SAVED_INSTITUTION'},
#                                 'event_name': 'TRANSITION_VIEW',
#                                 'timestamp': '2025-12-03T06:29:27Z'},
#                                {'event_id': '8c334ca9-3362-417e-afdc-e235b9ff572b',
#                                 'event_metadata': {'request_id': 'nd4inxc7TrA4QDR'},
#                                 'event_name': 'SUBMIT_OTP',
#                                 'timestamp': '2025-12-03T06:29:26Z'},
#                                {'event_id': '17759ce9-52db-434b-92a8-6800c6089666',
#                                 'event_metadata': {'request_id': 'nd4inxc7TrA4QDR',
#                                                    'view_name': 'VERIFY_PHONE'},
#                                 'event_name': 'TRANSITION_VIEW',
#                                 'timestamp': '2025-12-03T06:29:23Z'},
#                                {'event_id': 'a3f29886-f9cf-4271-91bb-feb59559e879',
#                                 'event_metadata': {'request_id': '9xG1h2rHZHAvbz5'},
#                                 'event_name': 'SUBMIT_PHONE',
#                                 'timestamp': '2025-12-03T06:29:22Z'},
#                                {'event_id': 'be4ba2aa-30ed-477f-b753-e125d21b8499',
#                                 'event_metadata': {'request_id': '9xG1h2rHZHAvbz5',
#                                                    'view_name': 'SUBMIT_PHONE'},
#                                 'event_name': 'TRANSITION_VIEW',
#                                 'timestamp': '2025-12-03T06:29:16Z'},
#                                {'event_id': 'f5280c6a-9c56-4b18-bb5a-43168ceb8c93',
#                                 'event_metadata': {'request_id': '9xG1h2rHZHAvbz5',
#                                                    'view_name': 'CONSENT'},
#                                 'event_name': 'OPEN',
#                                 'timestamp': '2025-12-03T06:29:16Z'},
#                                {'event_id': '4500cd30-ff83-438c-858a-53ca9dd2f31c',
#                                 'event_metadata': {'request_id': '9xG1h2rHZHAvbz5',
#                                                    'view_name': 'CONSENT'},
#                                 'event_name': 'TRANSITION_VIEW',
#                                 'timestamp': '2025-12-03T06:29:16Z'}],
#                     'finished_at': datetime.datetime(2025, 12, 3, 6, 29, 33, 891408, tzinfo=tzlocal()),
#                     'link_session_id': '019ae2e6-9f3f-77f2-b3d5-6fe273d0ec4e',
#                     'results': {'bank_income_results': [],
#                                 'cra_item_add_results': [],
#                                 'cra_update_results': [],
#                                 'document_income_results': None,
#                                 'item_add_results': [{'accounts': [{'class_type': None,
#                                                                     'id': 'Wa3k6PyvpXczzBQ8rRrRhZdvz9RpXXC6Ba3RL',
#                                                                     'mask': '0000',
#                                                                     'name': 'Plaid '
#                                                                             'Checking',
#                                                                     'subtype': 'checking',
#                                                                     'type': 'depository',
#                                                                     'verification_status': None},
#                                                                    {'class_type': None,
#                                                                     'id': 'ALJK7Bk84wcwwyJ5q6q6hmE3bnM1ggF9BeLpg',
#                                                                     'mask': '1111',
#                                                                     'name': 'Plaid '
#                                                                             'Saving',
#                                                                     'subtype': 'savings',
#                                                                     'type': 'depository',
#                                                                     'verification_status': None},
#                                                                    {'class_type': None,
#                                                                     'id': 'GWJdLNxvRnI66XlzoZoZUdqJWB9NXXi6ZjKpm',
#                                                                     'mask': '9002',
#                                                                     'name': 'Plaid '
#                                                                             'Cash '
#                                                                             'Management',
#                                                                     'subtype': 'cash '
#                                                                                'management',
#                                                                     'type': 'depository',
#                                                                     'verification_status': None}],
#                                                       'institution': {'institution_id': 'ins_109511',
#                                                                       'name': 'Tartan '
#                                                                               'Bank'},
#                                                       'public_token': 'public-sandbox-821623ab-1eed-4962-83fc-e3b66e10d233'}],
#                                 'payroll_income_results': []},
#                     'started_at': datetime.datetime(2025, 12, 3, 6, 29, 16, 593925, tzinfo=tzlocal())}],
#  'link_token': 'link-sandbox-94efc09d-d3f8-44fe-959d-c07638a18ab7',
#  'metadata': {'client_name': 'Plaid Colab Demo',
#               'country_codes': ['US', 'CA'],
#               'initial_products': ['auth', 'signal', 'transactions'],
#               'language': 'en',
#               'redirect_uri': None,
#               'webhook': None},
#  'request_id': 'vIcvAh3CwbSx9E1'}
#
# ✅ Got public_token: public-sandbox-821623ab-1eed-4962-83fc-e3b66e10d233

# %%
# Cell 4 (updated): After completing Hosted Link, get public_token and exchange it for access_token

from pprint import pprint  # nicer, no JSON serialization issues
try:
    # Step 2: exchange public_token for access_token
    exchange_request = ItemPublicTokenExchangeRequest(public_token=PUBLIC_TOKEN)
    exchange_response = client.item_public_token_exchange(exchange_request)
    exchange_data = exchange_response.to_dict()

    access_token = exchange_data["access_token"]
    item_id = exchange_data["item_id"]

    print("\n🎉 SUCCESS")
    print("access_token:", access_token)
    print("item_id:", item_id)

    # In a real app: store access_token securely (DB/secret store)
    access_credentials = {
        "access_token": access_token,
        "item_id": item_id,
        "exchange_raw": exchange_data,
    }

except plaid.ApiException as e:
    print("Plaid API exception while finalizing link:")
    try:
        error_body = json.loads(e.body)
        print(json.dumps(error_body, indent=2))
    except Exception:
        print(e)

print(access_credentials)
# Out:
# 🎉 SUCCESS
# access_token: access-sandbox-c9dae132-6a99-404a-8e63-52c1d4f3bd04
# item_id: E8J3MkBGnVtggbA7zyzyhNwZXyJP56uXZWknP
# {'access_token': 'access-sandbox-c9dae132-6a99-404a-8e63-52c1d4f3bd04', 'item_id': 'E8J3MkBGnVtggbA7zyzyhNwZXyJP56uXZWknP', 'exchange_raw': {'access_token': 'access-sandbox-c9dae132-6a99-404a-8e63-52c1d4f3bd04', 'item_id': 'E8J3MkBGnVtggbA7zyzyhNwZXyJP56uXZWknP', 'request_id': 'VdP8ROVaEbafXTZ'}}

# %%
import plaid
from plaid.model.transactions_sync_request import TransactionsSyncRequest
import datetime

request = TransactionsSyncRequest(
    access_token=access_credentials['access_token'],
)
response = client.transactions_sync(request)
transactions = response['added']

# the transactions in the response are paginated, so make multiple calls while incrementing the cursor to
# retrieve all transactions
while (response['has_more']):
    request = TransactionsSyncRequest(
        access_token=access_token,
        cursor=response['next_cursor']
    )
    response = client.transactions_sync(request)
    transactions += response['added']

transactions[:5]
# Out:
# [{'account_id': 'Wa3k6PyvpXczzBQ8rRrRhZdvz9RpXXC6Ba3RL',
#   'account_owner': None,
#   'amount': 6.33,
#   'authorized_date': datetime.date(2025, 11, 27),
#   'authorized_datetime': None,
#   'category': None,
#   'category_id': None,
#   'check_number': None,
#   'counterparties': [{'confidence_level': 'VERY_HIGH',
#                       'entity_id': 'eyg8o776k0QmNgVpAmaQj4WgzW9Qzo6O51gdd',
#                       'logo_url': 'https://plaid-merchant-logos.plaid.com/uber_1060.png',
#                       'name': 'Uber',
#                       'phone_number': None,
#                       'type': 'merchant',
#                       'website': 'uber.com'}],
#   'date': datetime.date(2025, 11, 28),
#   'datetime': None,
#   'iso_currency_code': 'USD',
#   'location': {'address': None,
#                'city': None,
#                'country': None,
#                'lat': None,
#                'lon': None,
#                'postal_code': None,
#                'region': None,
#                'store_number': None},
#   'logo_url': 'https://plaid-merchant-logos.plaid.com/uber_1060.png',
#   'merchant_entity_id': 'eyg8o776k0QmNgVpAmaQj4WgzW9Qzo6O51gdd',
#   'merchant_name': 'Uber',
#   'name': 'Uber 072515 SF**POOL**',
#   'payment_channel': 'online',
#   'payment_meta': {'by_order_of': None,
#                    'payee': None,
#                    'payer': None,
#                    'payment_method': None,
#                    'payment_processor': None,
#                    'ppd_id': None,
#                    'reason': None,
#                    'reference_number': None},
#   'pending': False,
#   'pending_transaction_id': None,
#   'personal_finance_category': {'confidence_level': 'VERY_HIGH',
#                                 'detailed': 'TRANSPORTATION_TAXIS_AND_RIDE_SHARES',
#                                 'primary': 'TRANSPORTATION',
#                                 'version': 'v1'},
#   'personal_finance_category_icon_url': 'https://plaid-category-icons.plaid.com/PFC_TRANSPORTATION.png',
#   'transaction_code': None,
#   'transaction_id': 'mmvA18XdaMULLNaZQdQdIeVXmGe66EfkgwmMK',
#   'transaction_type': 'special',
#   'unofficial_currency_code': None,
#   'website': 'uber.com'},
#  {'account_id': 'Wa3k6PyvpXczzBQ8rRrRhZdvz9RpXXC6Ba3RL',
#   'account_owner': None,
#   'amount': 5.4,
#   'authorized_date': datetime.date(2025, 11, 14),
#   'authorized_datetime': None,
#   'category': None,
#   'category_id': None,
#   'check_number': None,
#   'counterparties': [{'confidence_level': 'VERY_HIGH',
#                       'entity_id': 'eyg8o776k0QmNgVpAmaQj4WgzW9Qzo6O51gdd',
#                       'logo_url': 'https://plaid-merchant-logos.plaid.com/uber_1060.png',
#                       'name': 'Uber',
#                       'phone_number': None,
#                       'type': 'merchant',
#                       'website': 'uber.com'}],
#   'date': datetime.date(2025, 11, 15),
#   'datetime': None,
#   'iso_currency_code': 'USD',
#   'location': {'address': None,
#                'city': None,
#                'country': None,
#                'lat': None,
#                'lon': None,
#                'postal_code': None,
#                'region': None,
#                'store_number': None},
#   'logo_url': 'https://plaid-merchant-logos.plaid.com/uber_1060.png',
#   'merchant_entity_id': 'eyg8o776k0QmNgVpAmaQj4WgzW9Qzo6O51gdd',
#   'merchant_name': 'Uber',
#   'name': 'Uber 063015 SF**POOL**',
#   'payment_channel': 'online',
#   'payment_meta': {'by_order_of': None,
#                    'payee': None,
#                    'payer': None,
#                    'payment_method': None,
#                    'payment_processor': None,
#                    'ppd_id': None,
#                    'reason': None,
#                    'reference_number': None},
#   'pending': False,
#   'pending_transaction_id': None,
#   'personal_finance_category': {'confidence_level': 'VERY_HIGH',
#                                 'detailed': 'TRANSPORTATION_TAXIS_AND_RIDE_SHARES',
#                                 'primary': 'TRANSPORTATION',
#                                 'version': 'v1'},
#   'personal_finance_category_icon_url': 'https://plaid-category-icons.plaid.com/PFC_TRANSPORTATION.png',
#   'transaction_code': None,
#   'transaction_id': 'y4wrm8WLDkC66Gn7xPxPU1We3V1PPZCM4L3Wk',
#   'transaction_type': 'special',
#   'unofficial_currency_code': None,
#   'website': 'uber.com'},
#  {'account_id': 'Wa3k6PyvpXczzBQ8rRrRhZdvz9RpXXC6Ba3RL',
#   'account_owner': None,
#   'amount': -500.0,
#   'authorized_date': datetime.date(2025, 11, 13),
#   'authorized_datetime': None,
#   'category': None,
#   'category_id': None,
#   'check_number': None,
#   'counterparties': [{'confidence_level': 'VERY_HIGH',
#                       'entity_id': 'NKDjqyAdQQzpyeD8qpLnX0D6yvLe2KYKYYzQ4',
#                       'logo_url': 'https://plaid-merchant-logos.plaid.com/united_airlines_1065.png',
#                       'name': 'United Airlines',
#                       'phone_number': None,
#                       'type': 'merchant',
#                       'website': 'united.com'}],
#   'date': datetime.date(2025, 11, 13),
#   'datetime': None,
#   'iso_currency_code': 'USD',
#   'location': {'address': None,
#                'city': None,
#                'country': None,
#                'lat': None,
#                'lon': None,
#                'postal_code': None,
#                'region': None,
#                'store_number': None},
#   'logo_url': 'https://plaid-merchant-logos.plaid.com/united_airlines_1065.png',
#   'merchant_entity_id': 'NKDjqyAdQQzpyeD8qpLnX0D6yvLe2KYKYYzQ4',
#   'merchant_name': 'United Airlines',
#   'name': 'United Airlines',
#   'payment_channel': 'in store',
#   'payment_meta': {'by_order_of': None,
#                    'payee': None,
#                    'payer': None,
#                    'payment_method': None,
#                    'payment_processor': None,
#                    'ppd_id': None,
#                    'reason': None,
#                    'reference_number': None},
#   'pending': False,
#   'pending_transaction_id': None,
#   'personal_finance_category': {'confidence_level': 'VERY_HIGH',
#                                 'detailed': 'TRAVEL_FLIGHTS',
#                                 'primary': 'TRAVEL',
#                                 'version': 'v1'},
#   'personal_finance_category_icon_url': 'https://plaid-category-icons.plaid.com/PFC_TRAVEL.png',
#   'transaction_code': None,
#   'transaction_id': '9PJ639MQ5RC88kgejVjVf6deVp6AAjCB4bGVl',
#   'transaction_type': 'special',
#   'unofficial_currency_code': None,
#   'website': 'united.com'},
#  {'account_id': 'Wa3k6PyvpXczzBQ8rRrRhZdvz9RpXXC6Ba3RL',
#   'account_owner': None,
#   'amount': 12.0,
#   'authorized_date': datetime.date(2025, 11, 12),
#   'authorized_datetime': None,
#   'category': None,
#   'category_id': None,
#   'check_number': None,
#   'counterparties': [{'confidence_level': 'VERY_HIGH',
#                       'entity_id': 'vzWXDWBjB06j5BJoD3Jo84OJZg7JJzmqOZA22',
#                       'logo_url': 'https://plaid-merchant-logos.plaid.com/mcdonalds_619.png',
#                       'name': "McDonald's",
#                       'phone_number': None,
#                       'type': 'merchant',
#                       'website': 'mcdonalds.com'}],
#   'date': datetime.date(2025, 11, 12),
#   'datetime': None,
#   'iso_currency_code': 'USD',
#   'location': {'address': None,
#                'city': None,
#                'country': None,
#                'lat': None,
#                'lon': None,
#                'postal_code': None,
#                'region': None,
#                'store_number': '3322'},
#   'logo_url': 'https://plaid-merchant-logos.plaid.com/mcdonalds_619.png',
#   'merchant_entity_id': 'vzWXDWBjB06j5BJoD3Jo84OJZg7JJzmqOZA22',
#   'merchant_name': "McDonald's",
#   'name': "McDonald's",
#   'payment_channel': 'in store',
#   'payment_meta': {'by_order_of': None,
#                    'payee': None,
#                    'payer': None,
#                    'payment_method': None,
#                    'payment_processor': None,
#                    'ppd_id': None,
#                    'reason': None,
#                    'reference_number': None},
#   'pending': False,
#   'pending_transaction_id': None,
#   'personal_finance_category': {'confidence_level': 'VERY_HIGH',
#                                 'detailed': 'FOOD_AND_DRINK_FAST_FOOD',
#                                 'primary': 'FOOD_AND_DRINK',
#                                 'version': 'v1'},
#   'personal_finance_category_icon_url': 'https://plaid-category-icons.plaid.com/PFC_FOOD_AND_DRINK.png',
#   'transaction_code': None,
#   'transaction_id': 'vxvlG8WZ3gFllmeyzNzNime9zwmbbGFJq4znW',
#   'transaction_type': 'place',
#   'unofficial_currency_code': None,
#   'website': 'mcdonalds.com'},
#  {'account_id': 'Wa3k6PyvpXczzBQ8rRrRhZdvz9RpXXC6Ba3RL',
#   'account_owner': None,
#   'amount': 4.33,
#   'authorized_date': datetime.date(2025, 11, 12),
#   'authorized_datetime': None,
#   'category': None,
#   'category_id': None,
#   'check_number': None,
#   'counterparties': [{'confidence_level': 'VERY_HIGH',
#                       'entity_id': 'NZAJQ5wYdo1W1p39X5q5gpb15OMe39pj4pJBb',
#                       'logo_url': 'https://plaid-merchant-logos.plaid.com/starbucks_956.png',
#                       'name': 'Starbucks',
#                       'phone_number': None,
#                       'type': 'merchant',
#                       'website': 'starbucks.com'}],
#   'date': datetime.date(2025, 11, 12),
#   'datetime': None,
#   'iso_currency_code': 'USD',
#   'location': {'address': None,
#                'city': None,
#                'country': None,
#                'lat': None,
#                'lon': None,
#                'postal_code': None,
#                'region': None,
#                'store_number': None},
#   'logo_url': 'https://plaid-merchant-logos.plaid.com/starbucks_956.png',
#   'merchant_entity_id': 'NZAJQ5wYdo1W1p39X5q5gpb15OMe39pj4pJBb',
#   'merchant_name': 'Starbucks',
#   'name': 'Starbucks',
#   'payment_channel': 'in store',
#   'payment_meta': {'by_order_of': None,
#                    'payee': None,
#                    'payer': None,
#                    'payment_method': None,
#                    'payment_processor': None,
#                    'ppd_id': None,
#                    'reason': None,
#                    'reference_number': None},
#   'pending': False,
#   'pending_transaction_id': None,
#   'personal_finance_category': {'confidence_level': 'VERY_HIGH',
#                                 'detailed': 'FOOD_AND_DRINK_COFFEE',
#                                 'primary': 'FOOD_AND_DRINK',
#                                 'version': 'v1'},
#   'personal_finance_category_icon_url': 'https://plaid-category-icons.plaid.com/PFC_FOOD_AND_DRINK.png',
#   'transaction_code': None,
#   'transaction_id': 'RzqGmxyvZwiVVBNpb3b3uDgxE4D55pCMarlXa',
#   'transaction_type': 'place',
#   'unofficial_currency_code': None,
#   'website': 'starbucks.com'}]

# %%
transactions
# Out:
# [{'account_id': '3l8qaWV7ANHb8rxplGpVcN5Kbp4vXEfZ1VQzg',
#   'account_owner': None,
#   'amount': 6.33,
#   'authorized_date': datetime.date(2025, 11, 27),
#   'authorized_datetime': None,
#   'category': None,
#   'category_id': None,
#   'check_number': None,
#   'counterparties': [{'confidence_level': 'VERY_HIGH',
#                       'entity_id': 'eyg8o776k0QmNgVpAmaQj4WgzW9Qzo6O51gdd',
#                       'logo_url': 'https://plaid-merchant-logos.plaid.com/uber_1060.png',
#                       'name': 'Uber',
#                       'phone_number': None,
#                       'type': 'merchant',
#                       'website': 'uber.com'}],
#   'date': datetime.date(2025, 11, 28),
#   'datetime': None,
#   'iso_currency_code': 'USD',
#   'location': {'address': None,
#                'city': None,
#                'country': None,
#                'lat': None,
#                'lon': None,
#                'postal_code': None,
#                'region': None,
#                'store_number': None},
#   'logo_url': 'https://plaid-merchant-logos.plaid.com/uber_1060.png',
#   'merchant_entity_id': 'eyg8o776k0QmNgVpAmaQj4WgzW9Qzo6O51gdd',
#   'merchant_name': 'Uber',
#   'name': 'Uber 072515 SF**POOL**',
#   'payment_channel': 'online',
#   'payment_meta': {'by_order_of': None,
#                    'payee': None,
#                    'payer': None,
#                    'payment_method': None,
#                    'payment_processor': None,
#                    'ppd_id': None,
#                    'reason': None,
#                    'reference_number': None},
#   'pending': False,
#   'pending_transaction_id': None,
#   'personal_finance_category': {'confidence_level': 'VERY_HIGH',
#                                 'detailed': 'TRANSPORTATION_TAXIS_AND_RIDE_SHARES',
#                                 'primary': 'TRANSPORTATION',
#                                 'version': 'v1'},
#   'personal_finance_category_icon_url': 'https://plaid-category-icons.plaid.com/PFC_TRANSPORTATION.png',
#   'transaction_code': None,
#   'transaction_id': '8Bn37x41EQUPleXgjZgDsVAmMD54VvfWlZE7Z',
#   'transaction_type': 'special',
#   'unofficial_currency_code': None,
#   'website': 'uber.com'},
#  {'account_id': '3l8qaWV7ANHb8rxplGpVcN5Kbp4vXEfZ1VQzg',
#   'account_owner': None,
#   'amount': 5.4,
#   'authorized_date': datetime.date(2025, 11, 14),
#   'authorized_datetime': None,
#   'category': None,
#   'category_id': None,
#   'check_number': None,
#   'counterparties': [{'confidence_level': 'VERY_HIGH',
#                       'entity_id': 'eyg8o776k0QmNgVpAmaQj4WgzW9Qzo6O51gdd',
#                       'logo_url': 'https://plaid-merchant-logos.plaid.com/uber_1060.png',
#                       'name': 'Uber',
#                       'phone_number': None,
#                       'type': 'merchant',
#                       'website': 'uber.com'}],
#   'date': datetime.date(2025, 11, 15),
#   'datetime': None,
#   'iso_currency_code': 'USD',
#   'location': {'address': None,
#                'city': None,
#                'country': None,
#                'lat': None,
#                'lon': None,
#                'postal_code': None,
#                'region': None,
#                'store_number': None},
#   'logo_url': 'https://plaid-merchant-logos.plaid.com/uber_1060.png',
#   'merchant_entity_id': 'eyg8o776k0QmNgVpAmaQj4WgzW9Qzo6O51gdd',
#   'merchant_name': 'Uber',
#   'name': 'Uber 063015 SF**POOL**',
#   'payment_channel': 'online',
#   'payment_meta': {'by_order_of': None,
#                    'payee': None,
#                    'payer': None,
#                    'payment_method': None,
#                    'payment_processor': None,
#                    'ppd_id': None,
#                    'reason': None,
#                    'reference_number': None},
#   'pending': False,
#   'pending_transaction_id': None,
#   'personal_finance_category': {'confidence_level': 'VERY_HIGH',
#                                 'detailed': 'TRANSPORTATION_TAXIS_AND_RIDE_SHARES',
#                                 'primary': 'TRANSPORTATION',
#                                 'version': 'v1'},
#   'personal_finance_category_icon_url': 'https://plaid-category-icons.plaid.com/PFC_TRANSPORTATION.png',
#   'transaction_code': None,
#   'transaction_id': 'EMq1AzRyD6C4jnPXdJX6cArpkdv8Aqh4Kgd89',
#   'transaction_type': 'special',
#   'unofficial_currency_code': None,
#   'website': 'uber.com'},
#  {'account_id': '3l8qaWV7ANHb8rxplGpVcN5Kbp4vXEfZ1VQzg',
#   'account_owner': None,
#   'amount': -500.0,
#   'authorized_date': datetime.date(2025, 11, 13),
#   'authorized_datetime': None,
#   'category': None,
#   'category_id': None,
#   'check_number': None,
#   'counterparties': [{'confidence_level': 'VERY_HIGH',
#                       'entity_id': 'NKDjqyAdQQzpyeD8qpLnX0D6yvLe2KYKYYzQ4',
#                       'logo_url': 'https://plaid-merchant-logos.plaid.com/united_airlines_1065.png',
#                       'name': 'United Airlines',
#                       'phone_number': None,
#                       'type': 'merchant',
#                       'website': 'united.com'}],
#   'date': datetime.date(2025, 11, 13),
#   'datetime': None,
#   'iso_currency_code': 'USD',
#   'location': {'address': None,
#                'city': None,
#                'country': None,
#                'lat': None,
#                'lon': None,
#                'postal_code': None,
#                'region': None,
#                'store_number': None},
#   'logo_url': 'https://plaid-merchant-logos.plaid.com/united_airlines_1065.png',
#   'merchant_entity_id': 'NKDjqyAdQQzpyeD8qpLnX0D6yvLe2KYKYYzQ4',
#   'merchant_name': 'United Airlines',
#   'name': 'United Airlines',
#   'payment_channel': 'in store',
#   'payment_meta': {'by_order_of': None,
#                    'payee': None,
#                    'payer': None,
#                    'payment_method': None,
#                    'payment_processor': None,
#                    'ppd_id': None,
#                    'reason': None,
#                    'reference_number': None},
#   'pending': False,
#   'pending_transaction_id': None,
#   'personal_finance_category': {'confidence_level': 'VERY_HIGH',
#                                 'detailed': 'TRAVEL_FLIGHTS',
#                                 'primary': 'TRAVEL',
#                                 'version': 'v1'},
#   'personal_finance_category_icon_url': 'https://plaid-category-icons.plaid.com/PFC_TRAVEL.png',
#   'transaction_code': None,
#   'transaction_id': 'W61dZowQD9IMdELPlJPpsj3rnazkj1F6mPa34',
#   'transaction_type': 'special',
#   'unofficial_currency_code': None,
#   'website': 'united.com'},
#  {'account_id': '3l8qaWV7ANHb8rxplGpVcN5Kbp4vXEfZ1VQzg',
#   'account_owner': None,
#   'amount': 12.0,
#   'authorized_date': datetime.date(2025, 11, 12),
#   'authorized_datetime': None,
#   'category': None,
#   'category_id': None,
#   'check_number': None,
#   'counterparties': [{'confidence_level': 'VERY_HIGH',
#                       'entity_id': 'vzWXDWBjB06j5BJoD3Jo84OJZg7JJzmqOZA22',
#                       'logo_url': 'https://plaid-merchant-logos.plaid.com/mcdonalds_619.png',
#                       'name': "McDonald's",
#                       'phone_number': None,
#                       'type': 'merchant',
#                       'website': 'mcdonalds.com'}],
#   'date': datetime.date(2025, 11, 12),
#   'datetime': None,
#   'iso_currency_code': 'USD',
#   'location': {'address': None,
#                'city': None,
#                'country': None,
#                'lat': None,
#                'lon': None,
#                'postal_code': None,
#                'region': None,
#                'store_number': '3322'},
#   'logo_url': 'https://plaid-merchant-logos.plaid.com/mcdonalds_619.png',
#   'merchant_entity_id': 'vzWXDWBjB06j5BJoD3Jo84OJZg7JJzmqOZA22',
#   'merchant_name': "McDonald's",
#   'name': "McDonald's",
#   'payment_channel': 'in store',
#   'payment_meta': {'by_order_of': None,
#                    'payee': None,
#                    'payer': None,
#                    'payment_method': None,
#                    'payment_processor': None,
#                    'ppd_id': None,
#                    'reason': None,
#                    'reference_number': None},
#   'pending': False,
#   'pending_transaction_id': None,
#   'personal_finance_category': {'confidence_level': 'VERY_HIGH',
#                                 'detailed': 'FOOD_AND_DRINK_FAST_FOOD',
#                                 'primary': 'FOOD_AND_DRINK',
#                                 'version': 'v1'},
#   'personal_finance_category_icon_url': 'https://plaid-category-icons.plaid.com/PFC_FOOD_AND_DRINK.png',
#   'transaction_code': None,
#   'transaction_id': 'A7Degl5GEmTPandGLEGBsP7GrzbvPyt9X4eLy',
#   'transaction_type': 'place',
#   'unofficial_currency_code': None,
#   'website': 'mcdonalds.com'},
#  {'account_id': '3l8qaWV7ANHb8rxplGpVcN5Kbp4vXEfZ1VQzg',
#   'account_owner': None,
#   'amount': 4.33,
#   'authorized_date': datetime.date(2025, 11, 12),
#   'authorized_datetime': None,
#   'category': None,
#   'category_id': None,
#   'check_number': None,
#   'counterparties': [{'confidence_level': 'VERY_HIGH',
#                       'entity_id': 'NZAJQ5wYdo1W1p39X5q5gpb15OMe39pj4pJBb',
#                       'logo_url': 'https://plaid-merchant-logos.plaid.com/starbucks_956.png',
#                       'name': 'Starbucks',
#                       'phone_number': None,
#                       'type': 'merchant',
#                       'website': 'starbucks.com'}],
#   'date': datetime.date(2025, 11, 12),
#   'datetime': None,
#   'iso_currency_code': 'USD',
#   'location': {'address': None,
#                'city': None,
#                'country': None,
#                'lat': None,
#                'lon': None,
#                'postal_code': None,
#                'region': None,
#                'store_number': None},
#   'logo_url': 'https://plaid-merchant-logos.plaid.com/starbucks_956.png',
#   'merchant_entity_id': 'NZAJQ5wYdo1W1p39X5q5gpb15OMe39pj4pJBb',
#   'merchant_name': 'Starbucks',
#   'name': 'Starbucks',
#   'payment_channel': 'in store',
#   'payment_meta': {'by_order_of': None,
#                    'payee': None,
#                    'payer': None,
#                    'payment_method': None,
#                    'payment_processor': None,
#                    'ppd_id': None,
#                    'reason': None,
#                    'reference_number': None},
#   'pending': False,
#   'pending_transaction_id': None,
#   'personal_finance_category': {'confidence_level': 'VERY_HIGH',
#                                 'detailed': 'FOOD_AND_DRINK_COFFEE',
#                                 'primary': 'FOOD_AND_DRINK',
#                                 'version': 'v1'},
#   'personal_finance_category_icon_url': 'https://plaid-category-icons.plaid.com/PFC_FOOD_AND_DRINK.png',
#   'transaction_code': None,
#   'transaction_id': 'GLrpqGblDmsWex7gyagAH6P17jWb6rf6eGjKq',
#   'transaction_type': 'place',
#   'unofficial_currency_code': None,
#   'website': 'starbucks.com'},
#  {'account_id': '3l8qaWV7ANHb8rxplGpVcN5Kbp4vXEfZ1VQzg',
#   'account_owner': None,
#   'amount': 89.4,
#   'authorized_date': datetime.date(2025, 11, 10),
#   'authorized_datetime': None,
#   'category': None,
#   'category_id': None,
#   'check_number': None,
#   'counterparties': [{'confidence_level': 'LOW',
#                       'entity_id': None,
#                       'logo_url': None,
#                       'name': 'FUN',
#                       'phone_number': None,
#                       'type': 'merchant',
#                       'website': None}],
#   'date': datetime.date(2025, 11, 11),
#   'datetime': None,
#   'iso_currency_code': 'USD',
#   'location': {'address': None,
#                'city': None,
#                'country': None,
#                'lat': None,
#                'lon': None,
#                'postal_code': None,
#                'region': None,
#                'store_number': None},
#   'logo_url': None,
#   'merchant_entity_id': None,
#   'merchant_name': 'FUN',
#   'name': 'SparkFun',
#   'payment_channel': 'in store',
#   'payment_meta': {'by_order_of': None,
#                    'payee': None,
#                    'payer': None,
#                    'payment_method': None,
#                    'payment_processor': None,
#                    'ppd_id': None,
#                    'reason': None,
#                    'reference_number': None},
#   'pending': False,
#   'pending_transaction_id': None,
#   'personal_finance_category': {'confidence_level': 'LOW',
#                                 'detailed': 'ENTERTAINMENT_SPORTING_EVENTS_AMUSEMENT_PARKS_AND_MUSEUMS',
#                                 'primary': 'ENTERTAINMENT',
#                                 'version': 'v1'},
#   'personal_finance_category_icon_url': 'https://plaid-category-icons.plaid.com/PFC_ENTERTAINMENT.png',
#   'transaction_code': None,
#   'transaction_id': 'nLqKPXmknjsJb6kMNWMpsvELbNWxvpiAy3m9J',
#   'transaction_type': 'place',
#   'unofficial_currency_code': None,
#   'website': None},
#  {'account_id': 'xbNPodLenJsWmvek9xkDHrwjzo3R9Di6GKk8P',
#   'account_owner': None,
#   'amount': 25.0,
#   'authorized_date': datetime.date(2025, 11, 14),
#   'authorized_datetime': None,
#   'category': None,
#   'category_id': None,
#   'check_number': None,
#   'counterparties': [],
#   'date': datetime.date(2025, 11, 15),
#   'datetime': None,
#   'iso_currency_code': 'USD',
#   'location': {'address': None,
#                'city': None,
#                'country': None,
#                'lat': None,
#                'lon': None,
#                'postal_code': None,
#                'region': None,
#                'store_number': None},
#   'logo_url': None,
#   'merchant_entity_id': None,
#   'merchant_name': None,
#   'name': 'CREDIT CARD 3333 PAYMENT *//',
#   'payment_channel': 'other',
#   'payment_meta': {'by_order_of': None,
#                    'payee': None,
#                    'payer': None,
#                    'payment_method': None,
#                    'payment_processor': None,
#                    'ppd_id': None,
#                    'reason': None,
#                    'reference_number': None},
#   'pending': False,
#   'pending_transaction_id': None,
#   'personal_finance_category': {'confidence_level': 'LOW',
#                                 'detailed': 'TRANSFER_OUT_ACCOUNT_TRANSFER',
#                                 'primary': 'TRANSFER_OUT',
#                                 'version': 'v1'},
#   'personal_finance_category_icon_url': 'https://plaid-category-icons.plaid.com/PFC_TRANSFER_OUT.png',
#   'transaction_code': None,
#   'transaction_id': 'bdb1laeAWqI813PLmWLqI6Kk7AGr6zfm4ovnP',
#   'transaction_type': 'special',
#   'unofficial_currency_code': None,
#   'website': None},
#  {'account_id': 'xbNPodLenJsWmvek9xkDHrwjzo3R9Di6GKk8P',
#   'account_owner': None,
#   'amount': -4.22,
#   'authorized_date': datetime.date(2025, 11, 10),
#   'authorized_datetime': None,
#   'category': None,
#   'category_id': None,
#   'check_number': None,
#   'counterparties': [],
#   'date': datetime.date(2025, 11, 10),
#   'datetime': None,
#   'iso_currency_code': 'USD',
#   'location': {'address': None,
#                'city': None,
#                'country': None,
#                'lat': None,
#                'lon': None,
#                'postal_code': None,
#                'region': None,
#                'store_number': None},
#   'logo_url': None,
#   'merchant_entity_id': None,
#   'merchant_name': None,
#   'name': 'INTRST PYMNT',
#   'payment_channel': 'other',
#   'payment_meta': {'by_order_of': None,
#                    'payee': None,
#                    'payer': None,
#                    'payment_method': None,
#                    'payment_processor': None,
#                    'ppd_id': None,
#                    'reason': None,
#                    'reference_number': None},
#   'pending': False,
#   'pending_transaction_id': None,
#   'personal_finance_category': {'confidence_level': 'LOW',
#                                 'detailed': 'INCOME_WAGES',
#                                 'primary': 'INCOME',
#                                 'version': 'v1'},
#   'personal_finance_category_icon_url': 'https://plaid-category-icons.plaid.com/PFC_INCOME.png',
#   'transaction_code': None,
#   'transaction_id': 'm1lqNeWznPCjbDzemVeWFRNgEnyvRWfgv43e8',
#   'transaction_type': 'special',
#   'unofficial_currency_code': None,
#   'website': None},
#  {'account_id': '3l8qaWV7ANHb8rxplGpVcN5Kbp4vXEfZ1VQzg',
#   'account_owner': None,
#   'amount': 6.33,
#   'authorized_date': datetime.date(2025, 10, 28),
#   'authorized_datetime': None,
#   'category': None,
#   'category_id': None,
#   'check_number': None,
#   'counterparties': [{'confidence_level': 'VERY_HIGH',
#                       'entity_id': 'eyg8o776k0QmNgVpAmaQj4WgzW9Qzo6O51gdd',
#                       'logo_url': 'https://plaid-merchant-logos.plaid.com/uber_1060.png',
#                       'name': 'Uber',
#                       'phone_number': None,
#                       'type': 'merchant',
#                       'website': 'uber.com'}],
#   'date': datetime.date(2025, 10, 29),
#   'datetime': None,
#   'iso_currency_code': 'USD',
#   'location': {'address': None,
#                'city': None,
#                'country': None,
#                'lat': None,
#                'lon': None,
#                'postal_code': None,
#                'region': None,
#                'store_number': None},
#   'logo_url': 'https://plaid-merchant-logos.plaid.com/uber_1060.png',
#   'merchant_entity_id': 'eyg8o776k0QmNgVpAmaQj4WgzW9Qzo6O51gdd',
#   'merchant_name': 'Uber',
#   'name': 'Uber 072515 SF**POOL**',
#   'payment_channel': 'online',
#   'payment_meta': {'by_order_of': None,
#                    'payee': None,
#                    'payer': None,
#                    'payment_method': None,
#                    'payment_processor': None,
#                    'ppd_id': None,
#                    'reason': None,
#                    'reference_number': None},
#   'pending': False,
#   'pending_transaction_id': None,
#   'personal_finance_category': {'confidence_level': 'VERY_HIGH',
#                                 'detailed': 'TRANSPORTATION_TAXIS_AND_RIDE_SHARES',
#                                 'primary': 'TRANSPORTATION',
#                                 'version': 'v1'},
#   'personal_finance_category_icon_url': 'https://plaid-category-icons.plaid.com/PFC_TRANSPORTATION.png',
#   'transaction_code': None,
#   'transaction_id': 'd4ypKlen6rHPvwrLmELBsJLZKwNdjoFJW6JrW',
#   'transaction_type': 'special',
#   'unofficial_currency_code': None,
#   'website': 'uber.com'},
#  {'account_id': '3l8qaWV7ANHb8rxplGpVcN5Kbp4vXEfZ1VQzg',
#   'account_owner': None,
#   'amount': 5.4,
#   'authorized_date': datetime.date(2025, 10, 15),
#   'authorized_datetime': None,
#   'category': None,
#   'category_id': None,
#   'check_number': None,
#   'counterparties': [{'confidence_level': 'VERY_HIGH',
#                       'entity_id': 'eyg8o776k0QmNgVpAmaQj4WgzW9Qzo6O51gdd',
#                       'logo_url': 'https://plaid-merchant-logos.plaid.com/uber_1060.png',
#                       'name': 'Uber',
#                       'phone_number': None,
#                       'type': 'merchant',
#                       'website': 'uber.com'}],
#   'date': datetime.date(2025, 10, 16),
#   'datetime': None,
#   'iso_currency_code': 'USD',
#   'location': {'address': None,
#                'city': None,
#                'country': None,
#                'lat': None,
#                'lon': None,
#                'postal_code': None,
#                'region': None,
#                'store_number': None},
#   'logo_url': 'https://plaid-merchant-logos.plaid.com/uber_1060.png',
#   'merchant_entity_id': 'eyg8o776k0QmNgVpAmaQj4WgzW9Qzo6O51gdd',
#   'merchant_name': 'Uber',
#   'name': 'Uber 063015 SF**POOL**',
#   'payment_channel': 'online',
#   'payment_meta': {'by_order_of': None,
#                    'payee': None,
#                    'payer': None,
#                    'payment_method': None,
#                    'payment_processor': None,
#                    'ppd_id': None,
#                    'reason': None,
#                    'reference_number': None},
#   'pending': False,
#   'pending_transaction_id': None,
#   'personal_finance_category': {'confidence_level': 'VERY_HIGH',
#                                 'detailed': 'TRANSPORTATION_TAXIS_AND_RIDE_SHARES',
#                                 'primary': 'TRANSPORTATION',
#                                 'version': 'v1'},
#   'personal_finance_category_icon_url': 'https://plaid-category-icons.plaid.com/PFC_TRANSPORTATION.png',
#   'transaction_code': None,
#   'transaction_id': 'axnMAEJWblSD5JLbBlbGswz4LJQKBDuZWeZVq',
#   'transaction_type': 'special',
#   'unofficial_currency_code': None,
#   'website': 'uber.com'},
#  {'account_id': '3l8qaWV7ANHb8rxplGpVcN5Kbp4vXEfZ1VQzg',
#   'account_owner': None,
#   'amount': -500.0,
#   'authorized_date': datetime.date(2025, 10, 14),
#   'authorized_datetime': None,
#   'category': None,
#   'category_id': None,
#   'check_number': None,
#   'counterparties': [{'confidence_level': 'VERY_HIGH',
#                       'entity_id': 'NKDjqyAdQQzpyeD8qpLnX0D6yvLe2KYKYYzQ4',
#                       'logo_url': 'https://plaid-merchant-logos.plaid.com/united_airlines_1065.png',
#                       'name': 'United Airlines',
#                       'phone_number': None,
#                       'type': 'merchant',
#                       'website': 'united.com'}],
#   'date': datetime.date(2025, 10, 14),
#   'datetime': None,
#   'iso_currency_code': 'USD',
#   'location': {'address': None,
#                'city': None,
#                'country': None,
#                'lat': None,
#                'lon': None,
#                'postal_code': None,
#                'region': None,
#                'store_number': None},
#   'logo_url': 'https://plaid-merchant-logos.plaid.com/united_airlines_1065.png',
#   'merchant_entity_id': 'NKDjqyAdQQzpyeD8qpLnX0D6yvLe2KYKYYzQ4',
#   'merchant_name': 'United Airlines',
#   'name': 'United Airlines',
#   'payment_channel': 'in store',
#   'payment_meta': {'by_order_of': None,
#                    'payee': None,
#                    'payer': None,
#                    'payment_method': None,
#                    'payment_processor': None,
#                    'ppd_id': None,
#                    'reason': None,
#                    'reference_number': None},
#   'pending': False,
#   'pending_transaction_id': None,
#   'personal_finance_category': {'confidence_level': 'VERY_HIGH',
#                                 'detailed': 'TRAVEL_FLIGHTS',
#                                 'primary': 'TRAVEL',
#                                 'version': 'v1'},
#   'personal_finance_category_icon_url': 'https://plaid-category-icons.plaid.com/PFC_TRAVEL.png',
#   'transaction_code': None,
#   'transaction_id': '4qEK43we5PuA8QPmBGmvULeJjW6pgvtJ13J4o',
#   'transaction_type': 'special',
#   'unofficial_currency_code': None,
#   'website': 'united.com'},
#  {'account_id': '3l8qaWV7ANHb8rxplGpVcN5Kbp4vXEfZ1VQzg',
#   'account_owner': None,
#   'amount': 12.0,
#   'authorized_date': datetime.date(2025, 10, 13),
#   'authorized_datetime': None,
#   'category': None,
#   'category_id': None,
#   'check_number': None,
#   'counterparties': [{'confidence_level': 'VERY_HIGH',
#                       'entity_id': 'vzWXDWBjB06j5BJoD3Jo84OJZg7JJzmqOZA22',
#                       'logo_url': 'https://plaid-merchant-logos.plaid.com/mcdonalds_619.png',
#                       'name': "McDonald's",
#                       'phone_number': None,
#                       'type': 'merchant',
#                       'website': 'mcdonalds.com'}],
#   'date': datetime.date(2025, 10, 13),
#   'datetime': None,
#   'iso_currency_code': 'USD',
#   'location': {'address': None,
#                'city': None,
#                'country': None,
#                'lat': None,
#                'lon': None,
#                'postal_code': None,
#                'region': None,
#                'store_number': '3322'},
#   'logo_url': 'https://plaid-merchant-logos.plaid.com/mcdonalds_619.png',
#   'merchant_entity_id': 'vzWXDWBjB06j5BJoD3Jo84OJZg7JJzmqOZA22',
#   'merchant_name': "McDonald's",
#   'name': "McDonald's",
#   'payment_channel': 'in store',
#   'payment_meta': {'by_order_of': None,
#                    'payee': None,
#                    'payer': None,
#                    'payment_method': None,
#                    'payment_processor': None,
#                    'ppd_id': None,
#                    'reason': None,
#                    'reference_number': None},
#   'pending': False,
#   'pending_transaction_id': None,
#   'personal_finance_category': {'confidence_level': 'VERY_HIGH',
#                                 'detailed': 'FOOD_AND_DRINK_FAST_FOOD',
#                                 'primary': 'FOOD_AND_DRINK',
#                                 'version': 'v1'},
#   'personal_finance_category_icon_url': 'https://plaid-category-icons.plaid.com/PFC_FOOD_AND_DRINK.png',
#   'transaction_code': None,
#   'transaction_id': 'Nk4GdeVxD9fRoap7vn7dsR3dr5bBqpcyD7ykG',
#   'transaction_type': 'place',
#   'unofficial_currency_code': None,
#   'website': 'mcdonalds.com'},
#  {'account_id': '3l8qaWV7ANHb8rxplGpVcN5Kbp4vXEfZ1VQzg',
#   'account_owner': None,
#   'amount': 4.33,
#   'authorized_date': datetime.date(2025, 10, 13),
#   'authorized_datetime': None,
#   'category': None,
#   'category_id': None,
#   'check_number': None,
#   'counterparties': [{'confidence_level': 'VERY_HIGH',
#                       'entity_id': 'NZAJQ5wYdo1W1p39X5q5gpb15OMe39pj4pJBb',
#                       'logo_url': 'https://plaid-merchant-logos.plaid.com/starbucks_956.png',
#                       'name': 'Starbucks',
#                       'phone_number': None,
#                       'type': 'merchant',
#                       'website': 'starbucks.com'}],
#   'date': datetime.date(2025, 10, 13),
#   'datetime': None,
#   'iso_currency_code': 'USD',
#   'location': {'address': None,
#                'city': None,
#                'country': None,
#                'lat': None,
#                'lon': None,
#                'postal_code': None,
#                'region': None,
#                'store_number': None},
#   'logo_url': 'https://plaid-merchant-logos.plaid.com/starbucks_956.png',
#   'merchant_entity_id': 'NZAJQ5wYdo1W1p39X5q5gpb15OMe39pj4pJBb',
#   'merchant_name': 'Starbucks',
#   'name': 'Starbucks',
#   'payment_channel': 'in store',
#   'payment_meta': {'by_order_of': None,
#                    'payee': None,
#                    'payer': None,
#                    'payment_method': None,
#                    'payment_processor': None,
#                    'ppd_id': None,
#                    'reason': None,
#                    'reference_number': None},
#   'pending': False,
#   'pending_transaction_id': None,
#   'personal_finance_category': {'confidence_level': 'VERY_HIGH',
#                                 'detailed': 'FOOD_AND_DRINK_COFFEE',
#                                 'primary': 'FOOD_AND_DRINK',
#                                 'version': 'v1'},
#   'personal_finance_category_icon_url': 'https://plaid-category-icons.plaid.com/PFC_FOOD_AND_DRINK.png',
#   'transaction_code': None,
#   'transaction_id': 'PnPq4yRaDwTQnwgjBejRTQZJz5469pToMNoVk',
#   'transaction_type': 'place',
#   'unofficial_currency_code': None,
#   'website': 'starbucks.com'},
#  {'account_id': '3l8qaWV7ANHb8rxplGpVcN5Kbp4vXEfZ1VQzg',
#   'account_owner': None,
#   'amount': 89.4,
#   'authorized_date': datetime.date(2025, 10, 11),
#   'authorized_datetime': None,
#   'category': None,
#   'category_id': None,
#   'check_number': None,
#   'counterparties': [{'confidence_level': 'LOW',
#                       'entity_id': None,
#                       'logo_url': None,
#                       'name': 'FUN',
#                       'phone_number': None,
#                       'type': 'merchant',
#                       'website': None}],
#   'date': datetime.date(2025, 10, 12),
#   'datetime': None,
#   'iso_currency_code': 'USD',
#   'location': {'address': None,
#                'city': None,
#                'country': None,
#                'lat': None,
#                'lon': None,
#                'postal_code': None,
#                'region': None,
#                'store_number': None},
#   'logo_url': None,
#   'merchant_entity_id': None,
#   'merchant_name': 'FUN',
#   'name': 'SparkFun',
#   'payment_channel': 'in store',
#   'payment_meta': {'by_order_of': None,
#                    'payee': None,
#                    'payer': None,
#                    'payment_method': None,
#                    'payment_processor': None,
#                    'ppd_id': None,
#                    'reason': None,
#                    'reference_number': None},
#   'pending': False,
#   'pending_transaction_id': None,
#   'personal_finance_category': {'confidence_level': 'LOW',
#                                 'detailed': 'ENTERTAINMENT_SPORTING_EVENTS_AMUSEMENT_PARKS_AND_MUSEUMS',
#                                 'primary': 'ENTERTAINMENT',
#                                 'version': 'v1'},
#   'personal_finance_category_icon_url': 'https://plaid-category-icons.plaid.com/PFC_ENTERTAINMENT.png',
#   'transaction_code': None,
#   'transaction_id': 'jQDAde3qnaIobmqZjdZWHR9XdmvaVAc6XG6l4',
#   'transaction_type': 'place',
#   'unofficial_currency_code': None,
#   'website': None},
#  {'account_id': '3l8qaWV7ANHb8rxplGpVcN5Kbp4vXEfZ1VQzg',
#   'account_owner': None,
#   'amount': 6.33,
#   'authorized_date': datetime.date(2025, 9, 28),
#   'authorized_datetime': None,
#   'category': None,
#   'category_id': None,
#   'check_number': None,
#   'counterparties': [{'confidence_level': 'VERY_HIGH',
#                       'entity_id': 'eyg8o776k0QmNgVpAmaQj4WgzW9Qzo6O51gdd',
#                       'logo_url': 'https://plaid-merchant-logos.plaid.com/uber_1060.png',
#                       'name': 'Uber',
#                       'phone_number': None,
#                       'type': 'merchant',
#                       'website': 'uber.com'}],
#   'date': datetime.date(2025, 9, 29),
#   'datetime': None,
#   'iso_currency_code': 'USD',
#   'location': {'address': None,
#                'city': None,
#                'country': None,
#                'lat': None,
#                'lon': None,
#                'postal_code': None,
#                'region': None,
#                'store_number': None},
#   'logo_url': 'https://plaid-merchant-logos.plaid.com/uber_1060.png',
#   'merchant_entity_id': 'eyg8o776k0QmNgVpAmaQj4WgzW9Qzo6O51gdd',
#   'merchant_name': 'Uber',
#   'name': 'Uber 072515 SF**POOL**',
#   'payment_channel': 'online',
#   'payment_meta': {'by_order_of': None,
#                    'payee': None,
#                    'payer': None,
#                    'payment_method': None,
#                    'payment_processor': None,
#                    'ppd_id': None,
#                    'reason': None,
#                    'reference_number': None},
#   'pending': False,
#   'pending_transaction_id': None,
#   'personal_finance_category': {'confidence_level': 'VERY_HIGH',
#                                 'detailed': 'TRANSPORTATION_TAXIS_AND_RIDE_SHARES',
#                                 'primary': 'TRANSPORTATION',
#                                 'version': 'v1'},
#   'personal_finance_category_icon_url': 'https://plaid-category-icons.plaid.com/PFC_TRANSPORTATION.png',
#   'transaction_code': None,
#   'transaction_id': '7zGBjJvMDeHy8Bq1a51JTKWNV8dqJBcd91drP',
#   'transaction_type': 'special',
#   'unofficial_currency_code': None,
#   'website': 'uber.com'},
#  {'account_id': '3l8qaWV7ANHb8rxplGpVcN5Kbp4vXEfZ1VQzg',
#   'account_owner': None,
#   'amount': 5.4,
#   'authorized_date': datetime.date(2025, 9, 15),
#   'authorized_datetime': None,
#   'category': None,
#   'category_id': None,
#   'check_number': None,
#   'counterparties': [{'confidence_level': 'VERY_HIGH',
#                       'entity_id': 'eyg8o776k0QmNgVpAmaQj4WgzW9Qzo6O51gdd',
#                       'logo_url': 'https://plaid-merchant-logos.plaid.com/uber_1060.png',
#                       'name': 'Uber',
#                       'phone_number': None,
#                       'type': 'merchant',
#                       'website': 'uber.com'}],
#   'date': datetime.date(2025, 9, 16),
#   'datetime': None,
#   'iso_currency_code': 'USD',
#   'location': {'address': None,
#                'city': None,
#                'country': None,
#                'lat': None,
#                'lon': None,
#                'postal_code': None,
#                'region': None,
#                'store_number': None},
#   'logo_url': 'https://plaid-merchant-logos.plaid.com/uber_1060.png',
#   'merchant_entity_id': 'eyg8o776k0QmNgVpAmaQj4WgzW9Qzo6O51gdd',
#   'merchant_name': 'Uber',
#   'name': 'Uber 063015 SF**POOL**',
#   'payment_channel': 'online',
#   'payment_meta': {'by_order_of': None,
#                    'payee': None,
#                    'payer': None,
#                    'payment_method': None,
#                    'payment_processor': None,
#                    'ppd_id': None,
#                    'reason': None,
#                    'reference_number': None},
#   'pending': False,
#   'pending_transaction_id': None,
#   'personal_finance_category': {'confidence_level': 'VERY_HIGH',
#                                 'detailed': 'TRANSPORTATION_TAXIS_AND_RIDE_SHARES',
#                                 'primary': 'TRANSPORTATION',
#                                 'version': 'v1'},
#   'personal_finance_category_icon_url': 'https://plaid-category-icons.plaid.com/PFC_TRANSPORTATION.png',
#   'transaction_code': None,
#   'transaction_id': 'eN9orq4kWzTpoqWLxnLEUMmAQqxJ45SrjVreG',
#   'transaction_type': 'special',
#   'unofficial_currency_code': None,
#   'website': 'uber.com'},
#  {'account_id': '3l8qaWV7ANHb8rxplGpVcN5Kbp4vXEfZ1VQzg',
#   'account_owner': None,
#   'amount': -500.0,
#   'authorized_date': datetime.date(2025, 9, 14),
#   'authorized_datetime': None,
#   'category': None,
#   'category_id': None,
#   'check_number': None,
#   'counterparties': [{'confidence_level': 'VERY_HIGH',
#                       'entity_id': 'NKDjqyAdQQzpyeD8qpLnX0D6yvLe2KYKYYzQ4',
#                       'logo_url': 'https://plaid-merchant-logos.plaid.com/united_airlines_1065.png',
#                       'name': 'United Airlines',
#                       'phone_number': None,
#                       'type': 'merchant',
#                       'website': 'united.com'}],
#   'date': datetime.date(2025, 9, 14),
#   'datetime': None,
#   'iso_currency_code': 'USD',
#   'location': {'address': None,
#                'city': None,
#                'country': None,
#                'lat': None,
#                'lon': None,
#                'postal_code': None,
#                'region': None,
#                'store_number': None},
#   'logo_url': 'https://plaid-merchant-logos.plaid.com/united_airlines_1065.png',
#   'merchant_entity_id': 'NKDjqyAdQQzpyeD8qpLnX0D6yvLe2KYKYYzQ4',
#   'merchant_name': 'United Airlines',
#   'name': 'United Airlines',
#   'payment_channel': 'in store',
#   'payment_meta': {'by_order_of': None,
#                    'payee': None,
#                    'payer': None,
#                    'payment_method': None,
#                    'payment_processor': None,
#                    'ppd_id': None,
#                    'reason': None,
#                    'reference_number': None},
#   'pending': False,
#   'pending_transaction_id': None,
#   'personal_finance_category': {'confidence_level': 'VERY_HIGH',
#                                 'detailed': 'TRAVEL_FLIGHTS',
#                                 'primary': 'TRAVEL',
#                                 'version': 'v1'},
#   'personal_finance_category_icon_url': 'https://plaid-category-icons.plaid.com/PFC_TRAVEL.png',
#   'transaction_code': None,
#   'transaction_id': 'QbjKNeQ4DksmnDWz1gzVsmVwRDXg5xuw8awRn',
#   'transaction_type': 'special',
#   'unofficial_currency_code': None,
#   'website': 'united.com'},
#  {'account_id': '3l8qaWV7ANHb8rxplGpVcN5Kbp4vXEfZ1VQzg',
#   'account_owner': None,
#   'amount': 12.0,
#   'authorized_date': datetime.date(2025, 9, 13),
#   'authorized_datetime': None,
#   'category': None,
#   'category_id': None,
#   'check_number': None,
#   'counterparties': [{'confidence_level': 'VERY_HIGH',
#                       'entity_id': 'vzWXDWBjB06j5BJoD3Jo84OJZg7JJzmqOZA22',
#                       'logo_url': 'https://plaid-merchant-logos.plaid.com/mcdonalds_619.png',
#                       'name': "McDonald's",
#                       'phone_number': None,
#                       'type': 'merchant',
#                       'website': 'mcdonalds.com'}],
#   'date': datetime.date(2025, 9, 13),
#   'datetime': None,
#   'iso_currency_code': 'USD',
#   'location': {'address': None,
#                'city': None,
#                'country': None,
#                'lat': None,
#                'lon': None,
#                'postal_code': None,
#                'region': None,
#                'store_number': '3322'},
#   'logo_url': 'https://plaid-merchant-logos.plaid.com/mcdonalds_619.png',
#   'merchant_entity_id': 'vzWXDWBjB06j5BJoD3Jo84OJZg7JJzmqOZA22',
#   'merchant_name': "McDonald's",
#   'name': "McDonald's",
#   'payment_channel': 'in store',
#   'payment_meta': {'by_order_of': None,
#                    'payee': None,
#                    'payer': None,
#                    'payment_method': None,
#                    'payment_processor': None,
#                    'ppd_id': None,
#                    'reason': None,
#                    'reference_number': None},
#   'pending': False,
#   'pending_transaction_id': None,
#   'personal_finance_category': {'confidence_level': 'VERY_HIGH',
#                                 'detailed': 'FOOD_AND_DRINK_FAST_FOOD',
#                                 'primary': 'FOOD_AND_DRINK',
#                                 'version': 'v1'},
#   'personal_finance_category_icon_url': 'https://plaid-category-icons.plaid.com/PFC_FOOD_AND_DRINK.png',
#   'transaction_code': None,
#   'transaction_id': 'ZloNLxw1WJHGnNbL5ELBTGanqpm6BzFeKbe9w',
#   'transaction_type': 'place',
#   'unofficial_currency_code': None,
#   'website': 'mcdonalds.com'},
#  {'account_id': '3l8qaWV7ANHb8rxplGpVcN5Kbp4vXEfZ1VQzg',
#   'account_owner': None,
#   'amount': 4.33,
#   'authorized_date': datetime.date(2025, 9, 13),
#   'authorized_datetime': None,
#   'category': None,
#   'category_id': None,
#   'check_number': None,
#   'counterparties': [{'confidence_level': 'VERY_HIGH',
#                       'entity_id': 'NZAJQ5wYdo1W1p39X5q5gpb15OMe39pj4pJBb',
#                       'logo_url': 'https://plaid-merchant-logos.plaid.com/starbucks_956.png',
#                       'name': 'Starbucks',
#                       'phone_number': None,
#                       'type': 'merchant',
#                       'website': 'starbucks.com'}],
#   'date': datetime.date(2025, 9, 13),
#   'datetime': None,
#   'iso_currency_code': 'USD',
#   'location': {'address': None,
#                'city': None,
#                'country': None,
#                'lat': None,
#                'lon': None,
#                'postal_code': None,
#                'region': None,
#                'store_number': None},
#   'logo_url': 'https://plaid-merchant-logos.plaid.com/starbucks_956.png',
#   'merchant_entity_id': 'NZAJQ5wYdo1W1p39X5q5gpb15OMe39pj4pJBb',
#   'merchant_name': 'Starbucks',
#   'name': 'Starbucks',
#   'payment_channel': 'in store',
#   'payment_meta': {'by_order_of': None,
#                    'payee': None,
#                    'payer': None,
#                    'payment_method': None,
#                    'payment_processor': None,
#                    'ppd_id': None,
#                    'reason': None,
#                    'reference_number': None},
#   'pending': False,
#   'pending_transaction_id': None,
#   'personal_finance_category': {'confidence_level': 'VERY_HIGH',
#                                 'detailed': 'FOOD_AND_DRINK_COFFEE',
#                                 'primary': 'FOOD_AND_DRINK',
#                                 'version': 'v1'},
#   'personal_finance_category_icon_url': 'https://plaid-category-icons.plaid.com/PFC_FOOD_AND_DRINK.png',
#   'transaction_code': None,
#   'transaction_id': 'MWaAx193DmfGpBL1yk18TGzon8M71pFLM7LGb',
#   'transaction_type': 'place',
#   'unofficial_currency_code': None,
#   'website': 'starbucks.com'},
#  {'account_id': '3l8qaWV7ANHb8rxplGpVcN5Kbp4vXEfZ1VQzg',
#   'account_owner': None,
#   'amount': 89.4,
#   'authorized_date': datetime.date(2025, 9, 11),
#   'authorized_datetime': None,
#   'category': None,
#   'category_id': None,
#   'check_number': None,
#   'counterparties': [{'confidence_level': 'LOW',
#                       'entity_id': None,
#                       'logo_url': None,
#                       'name': 'FUN',
#                       'phone_number': None,
#                       'type': 'merchant',
#                       'website': None}],
#   'date': datetime.date(2025, 9, 12),
#   'datetime': None,
#   'iso_currency_code': 'USD',
#   'location': {'address': None,
#                'city': None,
#                'country': None,
#                'lat': None,
#                'lon': None,
#                'postal_code': None,
#                'region': None,
#                'store_number': None},
#   'logo_url': None,
#   'merchant_entity_id': None,
#   'merchant_name': 'FUN',
#   'name': 'SparkFun',
#   'payment_channel': 'in store',
#   'payment_meta': {'by_order_of': None,
#                    'payee': None,
#                    'payer': None,
#                    'payment_method': None,
#                    'payment_processor': None,
#                    'ppd_id': None,
#                    'reason': None,
#                    'reference_number': None},
#   'pending': False,
#   'pending_transaction_id': None,
#   'personal_finance_category': {'confidence_level': 'LOW',
#                                 'detailed': 'ENTERTAINMENT_SPORTING_EVENTS_AMUSEMENT_PARKS_AND_MUSEUMS',
#                                 'primary': 'ENTERTAINMENT',
#                                 'version': 'v1'},
#   'personal_finance_category_icon_url': 'https://plaid-category-icons.plaid.com/PFC_ENTERTAINMENT.png',
#   'transaction_code': None,
#   'transaction_id': '1XoGxerkEahWQ8D1Kl1xHZxnKgzNQWCpJmpEQ',
#   'transaction_type': 'place',
#   'unofficial_currency_code': None,
#   'website': None},
#  {'account_id': 'xbNPodLenJsWmvek9xkDHrwjzo3R9Di6GKk8P',
#   'account_owner': None,
#   'amount': 25.0,
#   'authorized_date': datetime.date(2025, 10, 15),
#   'authorized_datetime': None,
#   'category': None,
#   'category_id': None,
#   'check_number': None,
#   'counterparties': [],
#   'date': datetime.date(2025, 10, 16),
#   'datetime': None,
#   'iso_currency_code': 'USD',
#   'location': {'address': None,
#                'city': None,
#                'country': None,
#                'lat': None,
#                'lon': None,
#                'postal_code': None,
#                'region': None,
#                'store_number': None},
#   'logo_url': None,
#   'merchant_entity_id': None,
#   'merchant_name': None,
#   'name': 'CREDIT CARD 3333 PAYMENT *//',
#   'payment_channel': 'other',
#   'payment_meta': {'by_order_of': None,
#                    'payee': None,
#                    'payer': None,
#                    'payment_method': None,
#                    'payment_processor': None,
#                    'ppd_id': None,
#                    'reason': None,
#                    'reference_number': None},
#   'pending': False,
#   'pending_transaction_id': None,
#   'personal_finance_category': {'confidence_level': 'LOW',
#                                 'detailed': 'LOAN_PAYMENTS_OTHER_PAYMENT',
#                                 'primary': 'LOAN_PAYMENTS',
#                                 'version': 'v1'},
#   'personal_finance_category_icon_url': 'https://plaid-category-icons.plaid.com/PFC_LOAN_PAYMENTS.png',
#   'transaction_code': None,
#   'transaction_id': 'opKrjRZ3n7sZbw3xdLxNHx5WDZwl86iolKoGp',
#   'transaction_type': 'special',
#   'unofficial_currency_code': None,
#   'website': None},
#  {'account_id': 'xbNPodLenJsWmvek9xkDHrwjzo3R9Di6GKk8P',
#   'account_owner': None,
#   'amount': -4.22,
#   'authorized_date': datetime.date(2025, 10, 11),
#   'authorized_datetime': None,
#   'category': None,
#   'category_id': None,
#   'check_number': None,
#   'counterparties': [],
#   'date': datetime.date(2025, 10, 11),
#   'datetime': None,
#   'iso_currency_code': 'USD',
#   'location': {'address': None,
#                'city': None,
#                'country': None,
#                'lat': None,
#                'lon': None,
#                'postal_code': None,
#                'region': None,
#                'store_number': None},
#   'logo_url': None,
#   'merchant_entity_id': None,
#   'merchant_name': None,
#   'name': 'INTRST PYMNT',
#   'payment_channel': 'other',
#   'payment_meta': {'by_order_of': None,
#                    'payee': None,
#                    'payer': None,
#                    'payment_method': None,
#                    'payment_processor': None,
#                    'ppd_id': None,
#                    'reason': None,
#                    'reference_number': None},
#   'pending': False,
#   'pending_transaction_id': None,
#   'personal_finance_category': {'confidence_level': 'LOW',
#                                 'detailed': 'INCOME_WAGES',
#                                 'primary': 'INCOME',
#                                 'version': 'v1'},
#   'personal_finance_category_icon_url': 'https://plaid-category-icons.plaid.com/PFC_INCOME.png',
#   'transaction_code': None,
#   'transaction_id': 'gjR8BrwyW3I8wk9WlGWoI7PLrRg1vntEmMEd4',
#   'transaction_type': 'special',
#   'unofficial_currency_code': None,
#   'website': None},
#  {'account_id': 'xbNPodLenJsWmvek9xkDHrwjzo3R9Di6GKk8P',
#   'account_owner': None,
#   'amount': 25.0,
#   'authorized_date': datetime.date(2025, 9, 15),
#   'authorized_datetime': None,
#   'category': None,
#   'category_id': None,
#   'check_number': None,
#   'counterparties': [],
#   'date': datetime.date(2025, 9, 16),
#   'datetime': None,
#   'iso_currency_code': 'USD',
#   'location': {'address': None,
#                'city': None,
#                'country': None,
#                'lat': None,
#                'lon': None,
#                'postal_code': None,
#                'region': None,
#                'store_number': None},
#   'logo_url': None,
#   'merchant_entity_id': None,
#   'merchant_name': None,
#   'name': 'CREDIT CARD 3333 PAYMENT *//',
#   'payment_channel': 'other',
#   'payment_meta': {'by_order_of': None,
#                    'payee': None,
#                    'payer': None,
#                    'payment_method': None,
#                    'payment_processor': None,
#                    'ppd_id': None,
#                    'reason': None,
#                    'reference_number': None},
#   'pending': False,
#   'pending_transaction_id': None,
#   'personal_finance_category': {'confidence_level': 'LOW',
#                                 'detailed': 'LOAN_PAYMENTS_OTHER_PAYMENT',
#                                 'primary': 'LOAN_PAYMENTS',
#                                 'version': 'v1'},
#   'personal_finance_category_icon_url': 'https://plaid-category-icons.plaid.com/PFC_LOAN_PAYMENTS.png',
#   'transaction_code': None,
#   'transaction_id': '8Bn37x41EQUPleXgjZgDsVA61w4E9niWlrWer',
#   'transaction_type': 'special',
#   'unofficial_currency_code': None,
#   'website': None},
#  {'account_id': 'xbNPodLenJsWmvek9xkDHrwjzo3R9Di6GKk8P',
#   'account_owner': None,
#   'amount': -4.22,
#   'authorized_date': datetime.date(2025, 9, 11),
#   'authorized_datetime': None,
#   'category': None,
#   'category_id': None,
#   'check_number': None,
#   'counterparties': [],
#   'date': datetime.date(2025, 9, 11),
#   'datetime': None,
#   'iso_currency_code': 'USD',
#   'location': {'address': None,
#                'city': None,
#                'country': None,
#                'lat': None,
#                'lon': None,
#                'postal_code': None,
#                'region': None,
#                'store_number': None},
#   'logo_url': None,
#   'merchant_entity_id': None,
#   'merchant_name': None,
#   'name': 'INTRST PYMNT',
#   'payment_channel': 'other',
#   'payment_meta': {'by_order_of': None,
#                    'payee': None,
#                    'payer': None,
#                    'payment_method': None,
#                    'payment_processor': None,
#                    'ppd_id': None,
#                    'reason': None,
#                    'reference_number': None},
#   'pending': False,
#   'pending_transaction_id': None,
#   'personal_finance_category': {'confidence_level': 'LOW',
#                                 'detailed': 'INCOME_WAGES',
#                                 'primary': 'INCOME',
#                                 'version': 'v1'},
#   'personal_finance_category_icon_url': 'https://plaid-category-icons.plaid.com/PFC_INCOME.png',
#   'transaction_code': None,
#   'transaction_id': 'EMq1AzRyD6C4jnPXdJX6cArnG58L1Wc4KE43V',
#   'transaction_type': 'special',
#   'unofficial_currency_code': None,
#   'website': None}]

# %%
# import plaid
from plaid.model.transactions_sync_request import TransactionsSyncRequest

# 1. Initial sync with no cursor
request = TransactionsSyncRequest(
    access_token=access_credentials["access_token"],
)

response = client.transactions_sync(request)

all_added = response["added"]
all_modified = response["modified"]
all_removed = response["removed"]
cursor = response["next_cursor"]

# 2. Continue until has_more = False
while response["has_more"]:
    request = TransactionsSyncRequest(
        access_token=access_credentials["access_token"],
        cursor=cursor
    )
    response = client.transactions_sync(request)

    all_added += response["added"]
    all_modified += response["modified"]
    all_removed += response["removed"]

    cursor = response["next_cursor"]

# 3. Display sample
all_added[:5]
# Out:
# [{'account_id': 'Wa3k6PyvpXczzBQ8rRrRhZdvz9RpXXC6Ba3RL',
#   'account_owner': None,
#   'amount': 6.33,
#   'authorized_date': datetime.date(2025, 11, 27),
#   'authorized_datetime': None,
#   'category': None,
#   'category_id': None,
#   'check_number': None,
#   'counterparties': [{'confidence_level': 'VERY_HIGH',
#                       'entity_id': 'eyg8o776k0QmNgVpAmaQj4WgzW9Qzo6O51gdd',
#                       'logo_url': 'https://plaid-merchant-logos.plaid.com/uber_1060.png',
#                       'name': 'Uber',
#                       'phone_number': None,
#                       'type': 'merchant',
#                       'website': 'uber.com'}],
#   'date': datetime.date(2025, 11, 28),
#   'datetime': None,
#   'iso_currency_code': 'USD',
#   'location': {'address': None,
#                'city': None,
#                'country': None,
#                'lat': None,
#                'lon': None,
#                'postal_code': None,
#                'region': None,
#                'store_number': None},
#   'logo_url': 'https://plaid-merchant-logos.plaid.com/uber_1060.png',
#   'merchant_entity_id': 'eyg8o776k0QmNgVpAmaQj4WgzW9Qzo6O51gdd',
#   'merchant_name': 'Uber',
#   'name': 'Uber 072515 SF**POOL**',
#   'payment_channel': 'online',
#   'payment_meta': {'by_order_of': None,
#                    'payee': None,
#                    'payer': None,
#                    'payment_method': None,
#                    'payment_processor': None,
#                    'ppd_id': None,
#                    'reason': None,
#                    'reference_number': None},
#   'pending': False,
#   'pending_transaction_id': None,
#   'personal_finance_category': {'confidence_level': 'VERY_HIGH',
#                                 'detailed': 'TRANSPORTATION_TAXIS_AND_RIDE_SHARES',
#                                 'primary': 'TRANSPORTATION',
#                                 'version': 'v1'},
#   'personal_finance_category_icon_url': 'https://plaid-category-icons.plaid.com/PFC_TRANSPORTATION.png',
#   'transaction_code': None,
#   'transaction_id': 'mmvA18XdaMULLNaZQdQdIeVXmGe66EfkgwmMK',
#   'transaction_type': 'special',
#   'unofficial_currency_code': None,
#   'website': 'uber.com'},
#  {'account_id': 'Wa3k6PyvpXczzBQ8rRrRhZdvz9RpXXC6Ba3RL',
#   'account_owner': None,
#   'amount': 5.4,
#   'authorized_date': datetime.date(2025, 11, 14),
#   'authorized_datetime': None,
#   'category': None,
#   'category_id': None,
#   'check_number': None,
#   'counterparties': [{'confidence_level': 'VERY_HIGH',
#                       'entity_id': 'eyg8o776k0QmNgVpAmaQj4WgzW9Qzo6O51gdd',
#                       'logo_url': 'https://plaid-merchant-logos.plaid.com/uber_1060.png',
#                       'name': 'Uber',
#                       'phone_number': None,
#                       'type': 'merchant',
#                       'website': 'uber.com'}],
#   'date': datetime.date(2025, 11, 15),
#   'datetime': None,
#   'iso_currency_code': 'USD',
#   'location': {'address': None,
#                'city': None,
#                'country': None,
#                'lat': None,
#                'lon': None,
#                'postal_code': None,
#                'region': None,
#                'store_number': None},
#   'logo_url': 'https://plaid-merchant-logos.plaid.com/uber_1060.png',
#   'merchant_entity_id': 'eyg8o776k0QmNgVpAmaQj4WgzW9Qzo6O51gdd',
#   'merchant_name': 'Uber',
#   'name': 'Uber 063015 SF**POOL**',
#   'payment_channel': 'online',
#   'payment_meta': {'by_order_of': None,
#                    'payee': None,
#                    'payer': None,
#                    'payment_method': None,
#                    'payment_processor': None,
#                    'ppd_id': None,
#                    'reason': None,
#                    'reference_number': None},
#   'pending': False,
#   'pending_transaction_id': None,
#   'personal_finance_category': {'confidence_level': 'VERY_HIGH',
#                                 'detailed': 'TRANSPORTATION_TAXIS_AND_RIDE_SHARES',
#                                 'primary': 'TRANSPORTATION',
#                                 'version': 'v1'},
#   'personal_finance_category_icon_url': 'https://plaid-category-icons.plaid.com/PFC_TRANSPORTATION.png',
#   'transaction_code': None,
#   'transaction_id': 'y4wrm8WLDkC66Gn7xPxPU1We3V1PPZCM4L3Wk',
#   'transaction_type': 'special',
#   'unofficial_currency_code': None,
#   'website': 'uber.com'},
#  {'account_id': 'Wa3k6PyvpXczzBQ8rRrRhZdvz9RpXXC6Ba3RL',
#   'account_owner': None,
#   'amount': -500.0,
#   'authorized_date': datetime.date(2025, 11, 13),
#   'authorized_datetime': None,
#   'category': None,
#   'category_id': None,
#   'check_number': None,
#   'counterparties': [{'confidence_level': 'VERY_HIGH',
#                       'entity_id': 'NKDjqyAdQQzpyeD8qpLnX0D6yvLe2KYKYYzQ4',
#                       'logo_url': 'https://plaid-merchant-logos.plaid.com/united_airlines_1065.png',
#                       'name': 'United Airlines',
#                       'phone_number': None,
#                       'type': 'merchant',
#                       'website': 'united.com'}],
#   'date': datetime.date(2025, 11, 13),
#   'datetime': None,
#   'iso_currency_code': 'USD',
#   'location': {'address': None,
#                'city': None,
#                'country': None,
#                'lat': None,
#                'lon': None,
#                'postal_code': None,
#                'region': None,
#                'store_number': None},
#   'logo_url': 'https://plaid-merchant-logos.plaid.com/united_airlines_1065.png',
#   'merchant_entity_id': 'NKDjqyAdQQzpyeD8qpLnX0D6yvLe2KYKYYzQ4',
#   'merchant_name': 'United Airlines',
#   'name': 'United Airlines',
#   'payment_channel': 'in store',
#   'payment_meta': {'by_order_of': None,
#                    'payee': None,
#                    'payer': None,
#                    'payment_method': None,
#                    'payment_processor': None,
#                    'ppd_id': None,
#                    'reason': None,
#                    'reference_number': None},
#   'pending': False,
#   'pending_transaction_id': None,
#   'personal_finance_category': {'confidence_level': 'VERY_HIGH',
#                                 'detailed': 'TRAVEL_FLIGHTS',
#                                 'primary': 'TRAVEL',
#                                 'version': 'v1'},
#   'personal_finance_category_icon_url': 'https://plaid-category-icons.plaid.com/PFC_TRAVEL.png',
#   'transaction_code': None,
#   'transaction_id': '9PJ639MQ5RC88kgejVjVf6deVp6AAjCB4bGVl',
#   'transaction_type': 'special',
#   'unofficial_currency_code': None,
#   'website': 'united.com'},
#  {'account_id': 'Wa3k6PyvpXczzBQ8rRrRhZdvz9RpXXC6Ba3RL',
#   'account_owner': None,
#   'amount': 12.0,
#   'authorized_date': datetime.date(2025, 11, 12),
#   'authorized_datetime': None,
#   'category': None,
#   'category_id': None,
#   'check_number': None,
#   'counterparties': [{'confidence_level': 'VERY_HIGH',
#                       'entity_id': 'vzWXDWBjB06j5BJoD3Jo84OJZg7JJzmqOZA22',
#                       'logo_url': 'https://plaid-merchant-logos.plaid.com/mcdonalds_619.png',
#                       'name': "McDonald's",
#                       'phone_number': None,
#                       'type': 'merchant',
#                       'website': 'mcdonalds.com'}],
#   'date': datetime.date(2025, 11, 12),
#   'datetime': None,
#   'iso_currency_code': 'USD',
#   'location': {'address': None,
#                'city': None,
#                'country': None,
#                'lat': None,
#                'lon': None,
#                'postal_code': None,
#                'region': None,
#                'store_number': '3322'},
#   'logo_url': 'https://plaid-merchant-logos.plaid.com/mcdonalds_619.png',
#   'merchant_entity_id': 'vzWXDWBjB06j5BJoD3Jo84OJZg7JJzmqOZA22',
#   'merchant_name': "McDonald's",
#   'name': "McDonald's",
#   'payment_channel': 'in store',
#   'payment_meta': {'by_order_of': None,
#                    'payee': None,
#                    'payer': None,
#                    'payment_method': None,
#                    'payment_processor': None,
#                    'ppd_id': None,
#                    'reason': None,
#                    'reference_number': None},
#   'pending': False,
#   'pending_transaction_id': None,
#   'personal_finance_category': {'confidence_level': 'VERY_HIGH',
#                                 'detailed': 'FOOD_AND_DRINK_FAST_FOOD',
#                                 'primary': 'FOOD_AND_DRINK',
#                                 'version': 'v1'},
#   'personal_finance_category_icon_url': 'https://plaid-category-icons.plaid.com/PFC_FOOD_AND_DRINK.png',
#   'transaction_code': None,
#   'transaction_id': 'vxvlG8WZ3gFllmeyzNzNime9zwmbbGFJq4znW',
#   'transaction_type': 'place',
#   'unofficial_currency_code': None,
#   'website': 'mcdonalds.com'},
#  {'account_id': 'Wa3k6PyvpXczzBQ8rRrRhZdvz9RpXXC6Ba3RL',
#   'account_owner': None,
#   'amount': 4.33,
#   'authorized_date': datetime.date(2025, 11, 12),
#   'authorized_datetime': None,
#   'category': None,
#   'category_id': None,
#   'check_number': None,
#   'counterparties': [{'confidence_level': 'VERY_HIGH',
#                       'entity_id': 'NZAJQ5wYdo1W1p39X5q5gpb15OMe39pj4pJBb',
#                       'logo_url': 'https://plaid-merchant-logos.plaid.com/starbucks_956.png',
#                       'name': 'Starbucks',
#                       'phone_number': None,
#                       'type': 'merchant',
#                       'website': 'starbucks.com'}],
#   'date': datetime.date(2025, 11, 12),
#   'datetime': None,
#   'iso_currency_code': 'USD',
#   'location': {'address': None,
#                'city': None,
#                'country': None,
#                'lat': None,
#                'lon': None,
#                'postal_code': None,
#                'region': None,
#                'store_number': None},
#   'logo_url': 'https://plaid-merchant-logos.plaid.com/starbucks_956.png',
#   'merchant_entity_id': 'NZAJQ5wYdo1W1p39X5q5gpb15OMe39pj4pJBb',
#   'merchant_name': 'Starbucks',
#   'name': 'Starbucks',
#   'payment_channel': 'in store',
#   'payment_meta': {'by_order_of': None,
#                    'payee': None,
#                    'payer': None,
#                    'payment_method': None,
#                    'payment_processor': None,
#                    'ppd_id': None,
#                    'reason': None,
#                    'reference_number': None},
#   'pending': False,
#   'pending_transaction_id': None,
#   'personal_finance_category': {'confidence_level': 'VERY_HIGH',
#                                 'detailed': 'FOOD_AND_DRINK_COFFEE',
#                                 'primary': 'FOOD_AND_DRINK',
#                                 'version': 'v1'},
#   'personal_finance_category_icon_url': 'https://plaid-category-icons.plaid.com/PFC_FOOD_AND_DRINK.png',
#   'transaction_code': None,
#   'transaction_id': 'RzqGmxyvZwiVVBNpb3b3uDgxE4D55pCMarlXa',
#   'transaction_type': 'place',
#   'unofficial_currency_code': None,
#   'website': 'starbucks.com'}]

# %%
all_added
# Out:
# [{'account_id': 'Wa3k6PyvpXczzBQ8rRrRhZdvz9RpXXC6Ba3RL',
#   'account_owner': None,
#   'amount': 6.33,
#   'authorized_date': datetime.date(2025, 11, 27),
#   'authorized_datetime': None,
#   'category': None,
#   'category_id': None,
#   'check_number': None,
#   'counterparties': [{'confidence_level': 'VERY_HIGH',
#                       'entity_id': 'eyg8o776k0QmNgVpAmaQj4WgzW9Qzo6O51gdd',
#                       'logo_url': 'https://plaid-merchant-logos.plaid.com/uber_1060.png',
#                       'name': 'Uber',
#                       'phone_number': None,
#                       'type': 'merchant',
#                       'website': 'uber.com'}],
#   'date': datetime.date(2025, 11, 28),
#   'datetime': None,
#   'iso_currency_code': 'USD',
#   'location': {'address': None,
#                'city': None,
#                'country': None,
#                'lat': None,
#                'lon': None,
#                'postal_code': None,
#                'region': None,
#                'store_number': None},
#   'logo_url': 'https://plaid-merchant-logos.plaid.com/uber_1060.png',
#   'merchant_entity_id': 'eyg8o776k0QmNgVpAmaQj4WgzW9Qzo6O51gdd',
#   'merchant_name': 'Uber',
#   'name': 'Uber 072515 SF**POOL**',
#   'payment_channel': 'online',
#   'payment_meta': {'by_order_of': None,
#                    'payee': None,
#                    'payer': None,
#                    'payment_method': None,
#                    'payment_processor': None,
#                    'ppd_id': None,
#                    'reason': None,
#                    'reference_number': None},
#   'pending': False,
#   'pending_transaction_id': None,
#   'personal_finance_category': {'confidence_level': 'VERY_HIGH',
#                                 'detailed': 'TRANSPORTATION_TAXIS_AND_RIDE_SHARES',
#                                 'primary': 'TRANSPORTATION',
#                                 'version': 'v1'},
#   'personal_finance_category_icon_url': 'https://plaid-category-icons.plaid.com/PFC_TRANSPORTATION.png',
#   'transaction_code': None,
#   'transaction_id': 'mmvA18XdaMULLNaZQdQdIeVXmGe66EfkgwmMK',
#   'transaction_type': 'special',
#   'unofficial_currency_code': None,
#   'website': 'uber.com'},
#  {'account_id': 'Wa3k6PyvpXczzBQ8rRrRhZdvz9RpXXC6Ba3RL',
#   'account_owner': None,
#   'amount': 5.4,
#   'authorized_date': datetime.date(2025, 11, 14),
#   'authorized_datetime': None,
#   'category': None,
#   'category_id': None,
#   'check_number': None,
#   'counterparties': [{'confidence_level': 'VERY_HIGH',
#                       'entity_id': 'eyg8o776k0QmNgVpAmaQj4WgzW9Qzo6O51gdd',
#                       'logo_url': 'https://plaid-merchant-logos.plaid.com/uber_1060.png',
#                       'name': 'Uber',
#                       'phone_number': None,
#                       'type': 'merchant',
#                       'website': 'uber.com'}],
#   'date': datetime.date(2025, 11, 15),
#   'datetime': None,
#   'iso_currency_code': 'USD',
#   'location': {'address': None,
#                'city': None,
#                'country': None,
#                'lat': None,
#                'lon': None,
#                'postal_code': None,
#                'region': None,
#                'store_number': None},
#   'logo_url': 'https://plaid-merchant-logos.plaid.com/uber_1060.png',
#   'merchant_entity_id': 'eyg8o776k0QmNgVpAmaQj4WgzW9Qzo6O51gdd',
#   'merchant_name': 'Uber',
#   'name': 'Uber 063015 SF**POOL**',
#   'payment_channel': 'online',
#   'payment_meta': {'by_order_of': None,
#                    'payee': None,
#                    'payer': None,
#                    'payment_method': None,
#                    'payment_processor': None,
#                    'ppd_id': None,
#                    'reason': None,
#                    'reference_number': None},
#   'pending': False,
#   'pending_transaction_id': None,
#   'personal_finance_category': {'confidence_level': 'VERY_HIGH',
#                                 'detailed': 'TRANSPORTATION_TAXIS_AND_RIDE_SHARES',
#                                 'primary': 'TRANSPORTATION',
#                                 'version': 'v1'},
#   'personal_finance_category_icon_url': 'https://plaid-category-icons.plaid.com/PFC_TRANSPORTATION.png',
#   'transaction_code': None,
#   'transaction_id': 'y4wrm8WLDkC66Gn7xPxPU1We3V1PPZCM4L3Wk',
#   'transaction_type': 'special',
#   'unofficial_currency_code': None,
#   'website': 'uber.com'},
#  {'account_id': 'Wa3k6PyvpXczzBQ8rRrRhZdvz9RpXXC6Ba3RL',
#   'account_owner': None,
#   'amount': -500.0,
#   'authorized_date': datetime.date(2025, 11, 13),
#   'authorized_datetime': None,
#   'category': None,
#   'category_id': None,
#   'check_number': None,
#   'counterparties': [{'confidence_level': 'VERY_HIGH',
#                       'entity_id': 'NKDjqyAdQQzpyeD8qpLnX0D6yvLe2KYKYYzQ4',
#                       'logo_url': 'https://plaid-merchant-logos.plaid.com/united_airlines_1065.png',
#                       'name': 'United Airlines',
#                       'phone_number': None,
#                       'type': 'merchant',
#                       'website': 'united.com'}],
#   'date': datetime.date(2025, 11, 13),
#   'datetime': None,
#   'iso_currency_code': 'USD',
#   'location': {'address': None,
#                'city': None,
#                'country': None,
#                'lat': None,
#                'lon': None,
#                'postal_code': None,
#                'region': None,
#                'store_number': None},
#   'logo_url': 'https://plaid-merchant-logos.plaid.com/united_airlines_1065.png',
#   'merchant_entity_id': 'NKDjqyAdQQzpyeD8qpLnX0D6yvLe2KYKYYzQ4',
#   'merchant_name': 'United Airlines',
#   'name': 'United Airlines',
#   'payment_channel': 'in store',
#   'payment_meta': {'by_order_of': None,
#                    'payee': None,
#                    'payer': None,
#                    'payment_method': None,
#                    'payment_processor': None,
#                    'ppd_id': None,
#                    'reason': None,
#                    'reference_number': None},
#   'pending': False,
#   'pending_transaction_id': None,
#   'personal_finance_category': {'confidence_level': 'VERY_HIGH',
#                                 'detailed': 'TRAVEL_FLIGHTS',
#                                 'primary': 'TRAVEL',
#                                 'version': 'v1'},
#   'personal_finance_category_icon_url': 'https://plaid-category-icons.plaid.com/PFC_TRAVEL.png',
#   'transaction_code': None,
#   'transaction_id': '9PJ639MQ5RC88kgejVjVf6deVp6AAjCB4bGVl',
#   'transaction_type': 'special',
#   'unofficial_currency_code': None,
#   'website': 'united.com'},
#  {'account_id': 'Wa3k6PyvpXczzBQ8rRrRhZdvz9RpXXC6Ba3RL',
#   'account_owner': None,
#   'amount': 12.0,
#   'authorized_date': datetime.date(2025, 11, 12),
#   'authorized_datetime': None,
#   'category': None,
#   'category_id': None,
#   'check_number': None,
#   'counterparties': [{'confidence_level': 'VERY_HIGH',
#                       'entity_id': 'vzWXDWBjB06j5BJoD3Jo84OJZg7JJzmqOZA22',
#                       'logo_url': 'https://plaid-merchant-logos.plaid.com/mcdonalds_619.png',
#                       'name': "McDonald's",
#                       'phone_number': None,
#                       'type': 'merchant',
#                       'website': 'mcdonalds.com'}],
#   'date': datetime.date(2025, 11, 12),
#   'datetime': None,
#   'iso_currency_code': 'USD',
#   'location': {'address': None,
#                'city': None,
#                'country': None,
#                'lat': None,
#                'lon': None,
#                'postal_code': None,
#                'region': None,
#                'store_number': '3322'},
#   'logo_url': 'https://plaid-merchant-logos.plaid.com/mcdonalds_619.png',
#   'merchant_entity_id': 'vzWXDWBjB06j5BJoD3Jo84OJZg7JJzmqOZA22',
#   'merchant_name': "McDonald's",
#   'name': "McDonald's",
#   'payment_channel': 'in store',
#   'payment_meta': {'by_order_of': None,
#                    'payee': None,
#                    'payer': None,
#                    'payment_method': None,
#                    'payment_processor': None,
#                    'ppd_id': None,
#                    'reason': None,
#                    'reference_number': None},
#   'pending': False,
#   'pending_transaction_id': None,
#   'personal_finance_category': {'confidence_level': 'VERY_HIGH',
#                                 'detailed': 'FOOD_AND_DRINK_FAST_FOOD',
#                                 'primary': 'FOOD_AND_DRINK',
#                                 'version': 'v1'},
#   'personal_finance_category_icon_url': 'https://plaid-category-icons.plaid.com/PFC_FOOD_AND_DRINK.png',
#   'transaction_code': None,
#   'transaction_id': 'vxvlG8WZ3gFllmeyzNzNime9zwmbbGFJq4znW',
#   'transaction_type': 'place',
#   'unofficial_currency_code': None,
#   'website': 'mcdonalds.com'},
#  {'account_id': 'Wa3k6PyvpXczzBQ8rRrRhZdvz9RpXXC6Ba3RL',
#   'account_owner': None,
#   'amount': 4.33,
#   'authorized_date': datetime.date(2025, 11, 12),
#   'authorized_datetime': None,
#   'category': None,
#   'category_id': None,
#   'check_number': None,
#   'counterparties': [{'confidence_level': 'VERY_HIGH',
#                       'entity_id': 'NZAJQ5wYdo1W1p39X5q5gpb15OMe39pj4pJBb',
#                       'logo_url': 'https://plaid-merchant-logos.plaid.com/starbucks_956.png',
#                       'name': 'Starbucks',
#                       'phone_number': None,
#                       'type': 'merchant',
#                       'website': 'starbucks.com'}],
#   'date': datetime.date(2025, 11, 12),
#   'datetime': None,
#   'iso_currency_code': 'USD',
#   'location': {'address': None,
#                'city': None,
#                'country': None,
#                'lat': None,
#                'lon': None,
#                'postal_code': None,
#                'region': None,
#                'store_number': None},
#   'logo_url': 'https://plaid-merchant-logos.plaid.com/starbucks_956.png',
#   'merchant_entity_id': 'NZAJQ5wYdo1W1p39X5q5gpb15OMe39pj4pJBb',
#   'merchant_name': 'Starbucks',
#   'name': 'Starbucks',
#   'payment_channel': 'in store',
#   'payment_meta': {'by_order_of': None,
#                    'payee': None,
#                    'payer': None,
#                    'payment_method': None,
#                    'payment_processor': None,
#                    'ppd_id': None,
#                    'reason': None,
#                    'reference_number': None},
#   'pending': False,
#   'pending_transaction_id': None,
#   'personal_finance_category': {'confidence_level': 'VERY_HIGH',
#                                 'detailed': 'FOOD_AND_DRINK_COFFEE',
#                                 'primary': 'FOOD_AND_DRINK',
#                                 'version': 'v1'},
#   'personal_finance_category_icon_url': 'https://plaid-category-icons.plaid.com/PFC_FOOD_AND_DRINK.png',
#   'transaction_code': None,
#   'transaction_id': 'RzqGmxyvZwiVVBNpb3b3uDgxE4D55pCMarlXa',
#   'transaction_type': 'place',
#   'unofficial_currency_code': None,
#   'website': 'starbucks.com'},
#  {'account_id': 'Wa3k6PyvpXczzBQ8rRrRhZdvz9RpXXC6Ba3RL',
#   'account_owner': None,
#   'amount': 89.4,
#   'authorized_date': datetime.date(2025, 11, 10),
#   'authorized_datetime': None,
#   'category': None,
#   'category_id': None,
#   'check_number': None,
#   'counterparties': [{'confidence_level': 'LOW',
#                       'entity_id': None,
#                       'logo_url': None,
#                       'name': 'FUN',
#                       'phone_number': None,
#                       'type': 'merchant',
#                       'website': None}],
#   'date': datetime.date(2025, 11, 11),
#   'datetime': None,
#   'iso_currency_code': 'USD',
#   'location': {'address': None,
#                'city': None,
#                'country': None,
#                'lat': None,
#                'lon': None,
#                'postal_code': None,
#                'region': None,
#                'store_number': None},
#   'logo_url': None,
#   'merchant_entity_id': None,
#   'merchant_name': 'FUN',
#   'name': 'SparkFun',
#   'payment_channel': 'in store',
#   'payment_meta': {'by_order_of': None,
#                    'payee': None,
#                    'payer': None,
#                    'payment_method': None,
#                    'payment_processor': None,
#                    'ppd_id': None,
#                    'reason': None,
#                    'reference_number': None},
#   'pending': False,
#   'pending_transaction_id': None,
#   'personal_finance_category': {'confidence_level': 'LOW',
#                                 'detailed': 'ENTERTAINMENT_SPORTING_EVENTS_AMUSEMENT_PARKS_AND_MUSEUMS',
#                                 'primary': 'ENTERTAINMENT',
#                                 'version': 'v1'},
#   'personal_finance_category_icon_url': 'https://plaid-category-icons.plaid.com/PFC_ENTERTAINMENT.png',
#   'transaction_code': None,
#   'transaction_id': '6apvr9bjLncJJe6ljLjLhPZGDwPbbLfk8M9b1',
#   'transaction_type': 'place',
#   'unofficial_currency_code': None,
#   'website': None},
#  {'account_id': 'ALJK7Bk84wcwwyJ5q6q6hmE3bnM1ggF9BeLpg',
#   'account_owner': None,
#   'amount': 25.0,
#   'authorized_date': datetime.date(2025, 11, 14),
#   'authorized_datetime': None,
#   'category': None,
#   'category_id': None,
#   'check_number': None,
#   'counterparties': [],
#   'date': datetime.date(2025, 11, 15),
#   'datetime': None,
#   'iso_currency_code': 'USD',
#   'location': {'address': None,
#                'city': None,
#                'country': None,
#                'lat': None,
#                'lon': None,
#                'postal_code': None,
#                'region': None,
#                'store_number': None},
#   'logo_url': None,
#   'merchant_entity_id': None,
#   'merchant_name': None,
#   'name': 'CREDIT CARD 3333 PAYMENT *//',
#   'payment_channel': 'other',
#   'payment_meta': {'by_order_of': None,
#                    'payee': None,
#                    'payer': None,
#                    'payment_method': None,
#                    'payment_processor': None,
#                    'ppd_id': None,
#                    'reason': None,
#                    'reference_number': None},
#   'pending': False,
#   'pending_transaction_id': None,
#   'personal_finance_category': {'confidence_level': 'LOW',
#                                 'detailed': 'TRANSFER_OUT_ACCOUNT_TRANSFER',
#                                 'primary': 'TRANSFER_OUT',
#                                 'version': 'v1'},
#   'personal_finance_category_icon_url': 'https://plaid-category-icons.plaid.com/PFC_TRANSFER_OUT.png',
#   'transaction_code': None,
#   'transaction_id': 'X4xrXjVvQbCQQjZ8XNXNUzpbPvz66efJbz6PP',
#   'transaction_type': 'special',
#   'unofficial_currency_code': None,
#   'website': None},
#  {'account_id': 'ALJK7Bk84wcwwyJ5q6q6hmE3bnM1ggF9BeLpg',
#   'account_owner': None,
#   'amount': -4.22,
#   'authorized_date': datetime.date(2025, 11, 10),
#   'authorized_datetime': None,
#   'category': None,
#   'category_id': None,
#   'check_number': None,
#   'counterparties': [],
#   'date': datetime.date(2025, 11, 10),
#   'datetime': None,
#   'iso_currency_code': 'USD',
#   'location': {'address': None,
#                'city': None,
#                'country': None,
#                'lat': None,
#                'lon': None,
#                'postal_code': None,
#                'region': None,
#                'store_number': None},
#   'logo_url': None,
#   'merchant_entity_id': None,
#   'merchant_name': None,
#   'name': 'INTRST PYMNT',
#   'payment_channel': 'other',
#   'payment_meta': {'by_order_of': None,
#                    'payee': None,
#                    'payer': None,
#                    'payment_method': None,
#                    'payment_processor': None,
#                    'ppd_id': None,
#                    'reason': None,
#                    'reference_number': None},
#   'pending': False,
#   'pending_transaction_id': None,
#   'personal_finance_category': {'confidence_level': 'LOW',
#                                 'detailed': 'INCOME_WAGES',
#                                 'primary': 'INCOME',
#                                 'version': 'v1'},
#   'personal_finance_category_icon_url': 'https://plaid-category-icons.plaid.com/PFC_INCOME.png',
#   'transaction_code': None,
#   'transaction_id': 'DgJBZdzA4nfddDeV8Z8ZfMKEWLMvvbHd39wEX',
#   'transaction_type': 'special',
#   'unofficial_currency_code': None,
#   'website': None},
#  {'account_id': 'Wa3k6PyvpXczzBQ8rRrRhZdvz9RpXXC6Ba3RL',
#   'account_owner': None,
#   'amount': 6.33,
#   'authorized_date': datetime.date(2025, 10, 28),
#   'authorized_datetime': None,
#   'category': None,
#   'category_id': None,
#   'check_number': None,
#   'counterparties': [{'confidence_level': 'VERY_HIGH',
#                       'entity_id': 'eyg8o776k0QmNgVpAmaQj4WgzW9Qzo6O51gdd',
#                       'logo_url': 'https://plaid-merchant-logos.plaid.com/uber_1060.png',
#                       'name': 'Uber',
#                       'phone_number': None,
#                       'type': 'merchant',
#                       'website': 'uber.com'}],
#   'date': datetime.date(2025, 10, 29),
#   'datetime': None,
#   'iso_currency_code': 'USD',
#   'location': {'address': None,
#                'city': None,
#                'country': None,
#                'lat': None,
#                'lon': None,
#                'postal_code': None,
#                'region': None,
#                'store_number': None},
#   'logo_url': 'https://plaid-merchant-logos.plaid.com/uber_1060.png',
#   'merchant_entity_id': 'eyg8o776k0QmNgVpAmaQj4WgzW9Qzo6O51gdd',
#   'merchant_name': 'Uber',
#   'name': 'Uber 072515 SF**POOL**',
#   'payment_channel': 'online',
#   'payment_meta': {'by_order_of': None,
#                    'payee': None,
#                    'payer': None,
#                    'payment_method': None,
#                    'payment_processor': None,
#                    'ppd_id': None,
#                    'reason': None,
#                    'reference_number': None},
#   'pending': False,
#   'pending_transaction_id': None,
#   'personal_finance_category': {'confidence_level': 'VERY_HIGH',
#                                 'detailed': 'TRANSPORTATION_TAXIS_AND_RIDE_SHARES',
#                                 'primary': 'TRANSPORTATION',
#                                 'version': 'v1'},
#   'personal_finance_category_icon_url': 'https://plaid-category-icons.plaid.com/PFC_TRANSPORTATION.png',
#   'transaction_code': None,
#   'transaction_id': 'NlJPkrjvM8iBBexENXNXUwxJAx9l59Sy1m4eR',
#   'transaction_type': 'special',
#   'unofficial_currency_code': None,
#   'website': 'uber.com'},
#  {'account_id': 'Wa3k6PyvpXczzBQ8rRrRhZdvz9RpXXC6Ba3RL',
#   'account_owner': None,
#   'amount': 5.4,
#   'authorized_date': datetime.date(2025, 10, 15),
#   'authorized_datetime': None,
#   'category': None,
#   'category_id': None,
#   'check_number': None,
#   'counterparties': [{'confidence_level': 'VERY_HIGH',
#                       'entity_id': 'eyg8o776k0QmNgVpAmaQj4WgzW9Qzo6O51gdd',
#                       'logo_url': 'https://plaid-merchant-logos.plaid.com/uber_1060.png',
#                       'name': 'Uber',
#                       'phone_number': None,
#                       'type': 'merchant',
#                       'website': 'uber.com'}],
#   'date': datetime.date(2025, 10, 16),
#   'datetime': None,
#   'iso_currency_code': 'USD',
#   'location': {'address': None,
#                'city': None,
#                'country': None,
#                'lat': None,
#                'lon': None,
#                'postal_code': None,
#                'region': None,
#                'store_number': None},
#   'logo_url': 'https://plaid-merchant-logos.plaid.com/uber_1060.png',
#   'merchant_entity_id': 'eyg8o776k0QmNgVpAmaQj4WgzW9Qzo6O51gdd',
#   'merchant_name': 'Uber',
#   'name': 'Uber 063015 SF**POOL**',
#   'payment_channel': 'online',
#   'payment_meta': {'by_order_of': None,
#                    'payee': None,
#                    'payer': None,
#                    'payment_method': None,
#                    'payment_processor': None,
#                    'ppd_id': None,
#                    'reason': None,
#                    'reference_number': None},
#   'pending': False,
#   'pending_transaction_id': None,
#   'personal_finance_category': {'confidence_level': 'VERY_HIGH',
#                                 'detailed': 'TRANSPORTATION_TAXIS_AND_RIDE_SHARES',
#                                 'primary': 'TRANSPORTATION',
#                                 'version': 'v1'},
#   'personal_finance_category_icon_url': 'https://plaid-category-icons.plaid.com/PFC_TRANSPORTATION.png',
#   'transaction_code': None,
#   'transaction_id': 'PKJ7nBZvjkSEEoapNzNzIgwDowe35eto4ZP33',
#   'transaction_type': 'special',
#   'unofficial_currency_code': None,
#   'website': 'uber.com'},
#  {'account_id': 'Wa3k6PyvpXczzBQ8rRrRhZdvz9RpXXC6Ba3RL',
#   'account_owner': None,
#   'amount': -500.0,
#   'authorized_date': datetime.date(2025, 10, 14),
#   'authorized_datetime': None,
#   'category': None,
#   'category_id': None,
#   'check_number': None,
#   'counterparties': [{'confidence_level': 'VERY_HIGH',
#                       'entity_id': 'NKDjqyAdQQzpyeD8qpLnX0D6yvLe2KYKYYzQ4',
#                       'logo_url': 'https://plaid-merchant-logos.plaid.com/united_airlines_1065.png',
#                       'name': 'United Airlines',
#                       'phone_number': None,
#                       'type': 'merchant',
#                       'website': 'united.com'}],
#   'date': datetime.date(2025, 10, 14),
#   'datetime': None,
#   'iso_currency_code': 'USD',
#   'location': {'address': None,
#                'city': None,
#                'country': None,
#                'lat': None,
#                'lon': None,
#                'postal_code': None,
#                'region': None,
#                'store_number': None},
#   'logo_url': 'https://plaid-merchant-logos.plaid.com/united_airlines_1065.png',
#   'merchant_entity_id': 'NKDjqyAdQQzpyeD8qpLnX0D6yvLe2KYKYYzQ4',
#   'merchant_name': 'United Airlines',
#   'name': 'United Airlines',
#   'payment_channel': 'in store',
#   'payment_meta': {'by_order_of': None,
#                    'payee': None,
#                    'payer': None,
#                    'payment_method': None,
#                    'payment_processor': None,
#                    'ppd_id': None,
#                    'reason': None,
#                    'reference_number': None},
#   'pending': False,
#   'pending_transaction_id': None,
#   'personal_finance_category': {'confidence_level': 'VERY_HIGH',
#                                 'detailed': 'TRAVEL_FLIGHTS',
#                                 'primary': 'TRAVEL',
#                                 'version': 'v1'},
#   'personal_finance_category_icon_url': 'https://plaid-category-icons.plaid.com/PFC_TRAVEL.png',
#   'transaction_code': None,
#   'transaction_id': 'jGv7Q8mBkLSMMGe1VLVLhDb4xbpKmpt63q3JJ',
#   'transaction_type': 'special',
#   'unofficial_currency_code': None,
#   'website': 'united.com'},
#  {'account_id': 'Wa3k6PyvpXczzBQ8rRrRhZdvz9RpXXC6Ba3RL',
#   'account_owner': None,
#   'amount': 12.0,
#   'authorized_date': datetime.date(2025, 10, 13),
#   'authorized_datetime': None,
#   'category': None,
#   'category_id': None,
#   'check_number': None,
#   'counterparties': [{'confidence_level': 'VERY_HIGH',
#                       'entity_id': 'vzWXDWBjB06j5BJoD3Jo84OJZg7JJzmqOZA22',
#                       'logo_url': 'https://plaid-merchant-logos.plaid.com/mcdonalds_619.png',
#                       'name': "McDonald's",
#                       'phone_number': None,
#                       'type': 'merchant',
#                       'website': 'mcdonalds.com'}],
#   'date': datetime.date(2025, 10, 13),
#   'datetime': None,
#   'iso_currency_code': 'USD',
#   'location': {'address': None,
#                'city': None,
#                'country': None,
#                'lat': None,
#                'lon': None,
#                'postal_code': None,
#                'region': None,
#                'store_number': '3322'},
#   'logo_url': 'https://plaid-merchant-logos.plaid.com/mcdonalds_619.png',
#   'merchant_entity_id': 'vzWXDWBjB06j5BJoD3Jo84OJZg7JJzmqOZA22',
#   'merchant_name': "McDonald's",
#   'name': "McDonald's",
#   'payment_channel': 'in store',
#   'payment_meta': {'by_order_of': None,
#                    'payee': None,
#                    'payer': None,
#                    'payment_method': None,
#                    'payment_processor': None,
#                    'ppd_id': None,
#                    'reason': None,
#                    'reference_number': None},
#   'pending': False,
#   'pending_transaction_id': None,
#   'personal_finance_category': {'confidence_level': 'VERY_HIGH',
#                                 'detailed': 'FOOD_AND_DRINK_FAST_FOOD',
#                                 'primary': 'FOOD_AND_DRINK',
#                                 'version': 'v1'},
#   'personal_finance_category_icon_url': 'https://plaid-category-icons.plaid.com/PFC_FOOD_AND_DRINK.png',
#   'transaction_code': None,
#   'transaction_id': '74oXz957LRCQQlgoGVGVUypZPpDQ8DfdGLGXR',
#   'transaction_type': 'place',
#   'unofficial_currency_code': None,
#   'website': 'mcdonalds.com'},
#  {'account_id': 'Wa3k6PyvpXczzBQ8rRrRhZdvz9RpXXC6Ba3RL',
#   'account_owner': None,
#   'amount': 4.33,
#   'authorized_date': datetime.date(2025, 10, 13),
#   'authorized_datetime': None,
#   'category': None,
#   'category_id': None,
#   'check_number': None,
#   'counterparties': [{'confidence_level': 'VERY_HIGH',
#                       'entity_id': 'NZAJQ5wYdo1W1p39X5q5gpb15OMe39pj4pJBb',
#                       'logo_url': 'https://plaid-merchant-logos.plaid.com/starbucks_956.png',
#                       'name': 'Starbucks',
#                       'phone_number': None,
#                       'type': 'merchant',
#                       'website': 'starbucks.com'}],
#   'date': datetime.date(2025, 10, 13),
#   'datetime': None,
#   'iso_currency_code': 'USD',
#   'location': {'address': None,
#                'city': None,
#                'country': None,
#                'lat': None,
#                'lon': None,
#                'postal_code': None,
#                'region': None,
#                'store_number': None},
#   'logo_url': 'https://plaid-merchant-logos.plaid.com/starbucks_956.png',
#   'merchant_entity_id': 'NZAJQ5wYdo1W1p39X5q5gpb15OMe39pj4pJBb',
#   'merchant_name': 'Starbucks',
#   'name': 'Starbucks',
#   'payment_channel': 'in store',
#   'payment_meta': {'by_order_of': None,
#                    'payee': None,
#                    'payer': None,
#                    'payment_method': None,
#                    'payment_processor': None,
#                    'ppd_id': None,
#                    'reason': None,
#                    'reference_number': None},
#   'pending': False,
#   'pending_transaction_id': None,
#   'personal_finance_category': {'confidence_level': 'VERY_HIGH',
#                                 'detailed': 'FOOD_AND_DRINK_COFFEE',
#                                 'primary': 'FOOD_AND_DRINK',
#                                 'version': 'v1'},
#   'personal_finance_category_icon_url': 'https://plaid-category-icons.plaid.com/PFC_FOOD_AND_DRINK.png',
#   'transaction_code': None,
#   'transaction_id': 'egLwNmxlyMf33rJl1z1zhZaR1aBwqBtrw1wWp',
#   'transaction_type': 'place',
#   'unofficial_currency_code': None,
#   'website': 'starbucks.com'},
#  {'account_id': 'Wa3k6PyvpXczzBQ8rRrRhZdvz9RpXXC6Ba3RL',
#   'account_owner': None,
#   'amount': 89.4,
#   'authorized_date': datetime.date(2025, 10, 11),
#   'authorized_datetime': None,
#   'category': None,
#   'category_id': None,
#   'check_number': None,
#   'counterparties': [{'confidence_level': 'LOW',
#                       'entity_id': None,
#                       'logo_url': None,
#                       'name': 'FUN',
#                       'phone_number': None,
#                       'type': 'merchant',
#                       'website': None}],
#   'date': datetime.date(2025, 10, 12),
#   'datetime': None,
#   'iso_currency_code': 'USD',
#   'location': {'address': None,
#                'city': None,
#                'country': None,
#                'lat': None,
#                'lon': None,
#                'postal_code': None,
#                'region': None,
#                'store_number': None},
#   'logo_url': None,
#   'merchant_entity_id': None,
#   'merchant_name': 'FUN',
#   'name': 'SparkFun',
#   'payment_channel': 'in store',
#   'payment_meta': {'by_order_of': None,
#                    'payee': None,
#                    'payer': None,
#                    'payment_method': None,
#                    'payment_processor': None,
#                    'ppd_id': None,
#                    'reason': None,
#                    'reference_number': None},
#   'pending': False,
#   'pending_transaction_id': None,
#   'personal_finance_category': {'confidence_level': 'LOW',
#                                 'detailed': 'ENTERTAINMENT_SPORTING_EVENTS_AMUSEMENT_PARKS_AND_MUSEUMS',
#                                 'primary': 'ENTERTAINMENT',
#                                 'version': 'v1'},
#   'personal_finance_category_icon_url': 'https://plaid-category-icons.plaid.com/PFC_ENTERTAINMENT.png',
#   'transaction_code': None,
#   'transaction_id': 'QrlZb3Gw7pfQQ7vrNoNoU7npknGeDGFwdEdKJ',
#   'transaction_type': 'place',
#   'unofficial_currency_code': None,
#   'website': None},
#  {'account_id': 'Wa3k6PyvpXczzBQ8rRrRhZdvz9RpXXC6Ba3RL',
#   'account_owner': None,
#   'amount': 6.33,
#   'authorized_date': datetime.date(2025, 9, 28),
#   'authorized_datetime': None,
#   'category': None,
#   'category_id': None,
#   'check_number': None,
#   'counterparties': [{'confidence_level': 'VERY_HIGH',
#                       'entity_id': 'eyg8o776k0QmNgVpAmaQj4WgzW9Qzo6O51gdd',
#                       'logo_url': 'https://plaid-merchant-logos.plaid.com/uber_1060.png',
#                       'name': 'Uber',
#                       'phone_number': None,
#                       'type': 'merchant',
#                       'website': 'uber.com'}],
#   'date': datetime.date(2025, 9, 29),
#   'datetime': None,
#   'iso_currency_code': 'USD',
#   'location': {'address': None,
#                'city': None,
#                'country': None,
#                'lat': None,
#                'lon': None,
#                'postal_code': None,
#                'region': None,
#                'store_number': None},
#   'logo_url': 'https://plaid-merchant-logos.plaid.com/uber_1060.png',
#   'merchant_entity_id': 'eyg8o776k0QmNgVpAmaQj4WgzW9Qzo6O51gdd',
#   'merchant_name': 'Uber',
#   'name': 'Uber 072515 SF**POOL**',
#   'payment_channel': 'online',
#   'payment_meta': {'by_order_of': None,
#                    'payee': None,
#                    'payer': None,
#                    'payment_method': None,
#                    'payment_processor': None,
#                    'ppd_id': None,
#                    'reason': None,
#                    'reference_number': None},
#   'pending': False,
#   'pending_transaction_id': None,
#   'personal_finance_category': {'confidence_level': 'VERY_HIGH',
#                                 'detailed': 'TRANSPORTATION_TAXIS_AND_RIDE_SHARES',
#                                 'primary': 'TRANSPORTATION',
#                                 'version': 'v1'},
#   'personal_finance_category_icon_url': 'https://plaid-category-icons.plaid.com/PFC_TRANSPORTATION.png',
#   'transaction_code': None,
#   'transaction_id': 'ZPaBlmyXpECyyzvp3m3mSJAeDAMjpMuejVj7D',
#   'transaction_type': 'special',
#   'unofficial_currency_code': None,
#   'website': 'uber.com'},
#  {'account_id': 'Wa3k6PyvpXczzBQ8rRrRhZdvz9RpXXC6Ba3RL',
#   'account_owner': None,
#   'amount': 5.4,
#   'authorized_date': datetime.date(2025, 9, 15),
#   'authorized_datetime': None,
#   'category': None,
#   'category_id': None,
#   'check_number': None,
#   'counterparties': [{'confidence_level': 'VERY_HIGH',
#                       'entity_id': 'eyg8o776k0QmNgVpAmaQj4WgzW9Qzo6O51gdd',
#                       'logo_url': 'https://plaid-merchant-logos.plaid.com/uber_1060.png',
#                       'name': 'Uber',
#                       'phone_number': None,
#                       'type': 'merchant',
#                       'website': 'uber.com'}],
#   'date': datetime.date(2025, 9, 16),
#   'datetime': None,
#   'iso_currency_code': 'USD',
#   'location': {'address': None,
#                'city': None,
#                'country': None,
#                'lat': None,
#                'lon': None,
#                'postal_code': None,
#                'region': None,
#                'store_number': None},
#   'logo_url': 'https://plaid-merchant-logos.plaid.com/uber_1060.png',
#   'merchant_entity_id': 'eyg8o776k0QmNgVpAmaQj4WgzW9Qzo6O51gdd',
#   'merchant_name': 'Uber',
#   'name': 'Uber 063015 SF**POOL**',
#   'payment_channel': 'online',
#   'payment_meta': {'by_order_of': None,
#                    'payee': None,
#                    'payer': None,
#                    'payment_method': None,
#                    'payment_processor': None,
#                    'ppd_id': None,
#                    'reason': None,
#                    'reference_number': None},
#   'pending': False,
#   'pending_transaction_id': None,
#   'personal_finance_category': {'confidence_level': 'VERY_HIGH',
#                                 'detailed': 'TRANSPORTATION_TAXIS_AND_RIDE_SHARES',
#                                 'primary': 'TRANSPORTATION',
#                                 'version': 'v1'},
#   'personal_finance_category_icon_url': 'https://plaid-category-icons.plaid.com/PFC_TRANSPORTATION.png',
#   'transaction_code': None,
#   'transaction_id': 'MyJPWKNvRgHJJ73zPqPqhrRXvR3W83iLoVoQV',
#   'transaction_type': 'special',
#   'unofficial_currency_code': None,
#   'website': 'uber.com'},
#  {'account_id': 'Wa3k6PyvpXczzBQ8rRrRhZdvz9RpXXC6Ba3RL',
#   'account_owner': None,
#   'amount': -500.0,
#   'authorized_date': datetime.date(2025, 9, 14),
#   'authorized_datetime': None,
#   'category': None,
#   'category_id': None,
#   'check_number': None,
#   'counterparties': [{'confidence_level': 'VERY_HIGH',
#                       'entity_id': 'NKDjqyAdQQzpyeD8qpLnX0D6yvLe2KYKYYzQ4',
#                       'logo_url': 'https://plaid-merchant-logos.plaid.com/united_airlines_1065.png',
#                       'name': 'United Airlines',
#                       'phone_number': None,
#                       'type': 'merchant',
#                       'website': 'united.com'}],
#   'date': datetime.date(2025, 9, 14),
#   'datetime': None,
#   'iso_currency_code': 'USD',
#   'location': {'address': None,
#                'city': None,
#                'country': None,
#                'lat': None,
#                'lon': None,
#                'postal_code': None,
#                'region': None,
#                'store_number': None},
#   'logo_url': 'https://plaid-merchant-logos.plaid.com/united_airlines_1065.png',
#   'merchant_entity_id': 'NKDjqyAdQQzpyeD8qpLnX0D6yvLe2KYKYYzQ4',
#   'merchant_name': 'United Airlines',
#   'name': 'United Airlines',
#   'payment_channel': 'in store',
#   'payment_meta': {'by_order_of': None,
#                    'payee': None,
#                    'payer': None,
#                    'payment_method': None,
#                    'payment_processor': None,
#                    'ppd_id': None,
#                    'reason': None,
#                    'reference_number': None},
#   'pending': False,
#   'pending_transaction_id': None,
#   'personal_finance_category': {'confidence_level': 'VERY_HIGH',
#                                 'detailed': 'TRAVEL_FLIGHTS',
#                                 'primary': 'TRAVEL',
#                                 'version': 'v1'},
#   'personal_finance_category_icon_url': 'https://plaid-category-icons.plaid.com/PFC_TRAVEL.png',
#   'transaction_code': None,
#   'transaction_id': '1zQWX9MdL6iggrL6BpBphLGVyG4og4cpwlwMe',
#   'transaction_type': 'special',
#   'unofficial_currency_code': None,
#   'website': 'united.com'},
#  {'account_id': 'Wa3k6PyvpXczzBQ8rRrRhZdvz9RpXXC6Ba3RL',
#   'account_owner': None,
#   'amount': 12.0,
#   'authorized_date': datetime.date(2025, 9, 13),
#   'authorized_datetime': None,
#   'category': None,
#   'category_id': None,
#   'check_number': None,
#   'counterparties': [{'confidence_level': 'VERY_HIGH',
#                       'entity_id': 'vzWXDWBjB06j5BJoD3Jo84OJZg7JJzmqOZA22',
#                       'logo_url': 'https://plaid-merchant-logos.plaid.com/mcdonalds_619.png',
#                       'name': "McDonald's",
#                       'phone_number': None,
#                       'type': 'merchant',
#                       'website': 'mcdonalds.com'}],
#   'date': datetime.date(2025, 9, 13),
#   'datetime': None,
#   'iso_currency_code': 'USD',
#   'location': {'address': None,
#                'city': None,
#                'country': None,
#                'lat': None,
#                'lon': None,
#                'postal_code': None,
#                'region': None,
#                'store_number': '3322'},
#   'logo_url': 'https://plaid-merchant-logos.plaid.com/mcdonalds_619.png',
#   'merchant_entity_id': 'vzWXDWBjB06j5BJoD3Jo84OJZg7JJzmqOZA22',
#   'merchant_name': "McDonald's",
#   'name': "McDonald's",
#   'payment_channel': 'in store',
#   'payment_meta': {'by_order_of': None,
#                    'payee': None,
#                    'payer': None,
#                    'payment_method': None,
#                    'payment_processor': None,
#                    'ppd_id': None,
#                    'reason': None,
#                    'reference_number': None},
#   'pending': False,
#   'pending_transaction_id': None,
#   'personal_finance_category': {'confidence_level': 'VERY_HIGH',
#                                 'detailed': 'FOOD_AND_DRINK_FAST_FOOD',
#                                 'primary': 'FOOD_AND_DRINK',
#                                 'version': 'v1'},
#   'personal_finance_category_icon_url': 'https://plaid-category-icons.plaid.com/PFC_FOOD_AND_DRINK.png',
#   'transaction_code': None,
#   'transaction_id': 'LmJPEqNvQpUggyBXPlPlh5M6JM7og7HkJGJNa',
#   'transaction_type': 'place',
#   'unofficial_currency_code': None,
#   'website': 'mcdonalds.com'},
#  {'account_id': 'Wa3k6PyvpXczzBQ8rRrRhZdvz9RpXXC6Ba3RL',
#   'account_owner': None,
#   'amount': 4.33,
#   'authorized_date': datetime.date(2025, 9, 13),
#   'authorized_datetime': None,
#   'category': None,
#   'category_id': None,
#   'check_number': None,
#   'counterparties': [{'confidence_level': 'VERY_HIGH',
#                       'entity_id': 'NZAJQ5wYdo1W1p39X5q5gpb15OMe39pj4pJBb',
#                       'logo_url': 'https://plaid-merchant-logos.plaid.com/starbucks_956.png',
#                       'name': 'Starbucks',
#                       'phone_number': None,
#                       'type': 'merchant',
#                       'website': 'starbucks.com'}],
#   'date': datetime.date(2025, 9, 13),
#   'datetime': None,
#   'iso_currency_code': 'USD',
#   'location': {'address': None,
#                'city': None,
#                'country': None,
#                'lat': None,
#                'lon': None,
#                'postal_code': None,
#                'region': None,
#                'store_number': None},
#   'logo_url': 'https://plaid-merchant-logos.plaid.com/starbucks_956.png',
#   'merchant_entity_id': 'NZAJQ5wYdo1W1p39X5q5gpb15OMe39pj4pJBb',
#   'merchant_name': 'Starbucks',
#   'name': 'Starbucks',
#   'payment_channel': 'in store',
#   'payment_meta': {'by_order_of': None,
#                    'payee': None,
#                    'payer': None,
#                    'payment_method': None,
#                    'payment_processor': None,
#                    'ppd_id': None,
#                    'reason': None,
#                    'reference_number': None},
#   'pending': False,
#   'pending_transaction_id': None,
#   'personal_finance_category': {'confidence_level': 'VERY_HIGH',
#                                 'detailed': 'FOOD_AND_DRINK_COFFEE',
#                                 'primary': 'FOOD_AND_DRINK',
#                                 'version': 'v1'},
#   'personal_finance_category_icon_url': 'https://plaid-category-icons.plaid.com/PFC_FOOD_AND_DRINK.png',
#   'transaction_code': None,
#   'transaction_id': 'pqvAoWRNlMSJJGAgQqQqhWzJkzGwLGhpx3x5z',
#   'transaction_type': 'place',
#   'unofficial_currency_code': None,
#   'website': 'starbucks.com'},
#  {'account_id': 'Wa3k6PyvpXczzBQ8rRrRhZdvz9RpXXC6Ba3RL',
#   'account_owner': None,
#   'amount': 89.4,
#   'authorized_date': datetime.date(2025, 9, 11),
#   'authorized_datetime': None,
#   'category': None,
#   'category_id': None,
#   'check_number': None,
#   'counterparties': [{'confidence_level': 'LOW',
#                       'entity_id': None,
#                       'logo_url': None,
#                       'name': 'FUN',
#                       'phone_number': None,
#                       'type': 'merchant',
#                       'website': None}],
#   'date': datetime.date(2025, 9, 12),
#   'datetime': None,
#   'iso_currency_code': 'USD',
#   'location': {'address': None,
#                'city': None,
#                'country': None,
#                'lat': None,
#                'lon': None,
#                'postal_code': None,
#                'region': None,
#                'store_number': None},
#   'logo_url': None,
#   'merchant_entity_id': None,
#   'merchant_name': 'FUN',
#   'name': 'SparkFun',
#   'payment_channel': 'in store',
#   'payment_meta': {'by_order_of': None,
#                    'payee': None,
#                    'payer': None,
#                    'payment_method': None,
#                    'payment_processor': None,
#                    'ppd_id': None,
#                    'reason': None,
#                    'reference_number': None},
#   'pending': False,
#   'pending_transaction_id': None,
#   'personal_finance_category': {'confidence_level': 'LOW',
#                                 'detailed': 'ENTERTAINMENT_SPORTING_EVENTS_AMUSEMENT_PARKS_AND_MUSEUMS',
#                                 'primary': 'ENTERTAINMENT',
#                                 'version': 'v1'},
#   'personal_finance_category_icon_url': 'https://plaid-category-icons.plaid.com/PFC_ENTERTAINMENT.png',
#   'transaction_code': None,
#   'transaction_id': 'olvypwm4W1i55jm9VlVlSErzAr3QZ3ho383NV',
#   'transaction_type': 'place',
#   'unofficial_currency_code': None,
#   'website': None},
#  {'account_id': 'ALJK7Bk84wcwwyJ5q6q6hmE3bnM1ggF9BeLpg',
#   'account_owner': None,
#   'amount': 25.0,
#   'authorized_date': datetime.date(2025, 10, 15),
#   'authorized_datetime': None,
#   'category': None,
#   'category_id': None,
#   'check_number': None,
#   'counterparties': [],
#   'date': datetime.date(2025, 10, 16),
#   'datetime': None,
#   'iso_currency_code': 'USD',
#   'location': {'address': None,
#                'city': None,
#                'country': None,
#                'lat': None,
#                'lon': None,
#                'postal_code': None,
#                'region': None,
#                'store_number': None},
#   'logo_url': None,
#   'merchant_entity_id': None,
#   'merchant_name': None,
#   'name': 'CREDIT CARD 3333 PAYMENT *//',
#   'payment_channel': 'other',
#   'payment_meta': {'by_order_of': None,
#                    'payee': None,
#                    'payer': None,
#                    'payment_method': None,
#                    'payment_processor': None,
#                    'ppd_id': None,
#                    'reason': None,
#                    'reference_number': None},
#   'pending': False,
#   'pending_transaction_id': None,
#   'personal_finance_category': {'confidence_level': 'LOW',
#                                 'detailed': 'LOAN_PAYMENTS_OTHER_PAYMENT',
#                                 'primary': 'LOAN_PAYMENTS',
#                                 'version': 'v1'},
#   'personal_finance_category_icon_url': 'https://plaid-category-icons.plaid.com/PFC_LOAN_PAYMENTS.png',
#   'transaction_code': None,
#   'transaction_id': 'E8J3MkBGnVtggbA7zyzyhNwopwkz5kf4LJLox',
#   'transaction_type': 'special',
#   'unofficial_currency_code': None,
#   'website': None},
#  {'account_id': 'ALJK7Bk84wcwwyJ5q6q6hmE3bnM1ggF9BeLpg',
#   'account_owner': None,
#   'amount': -4.22,
#   'authorized_date': datetime.date(2025, 10, 11),
#   'authorized_datetime': None,
#   'category': None,
#   'category_id': None,
#   'check_number': None,
#   'counterparties': [],
#   'date': datetime.date(2025, 10, 11),
#   'datetime': None,
#   'iso_currency_code': 'USD',
#   'location': {'address': None,
#                'city': None,
#                'country': None,
#                'lat': None,
#                'lon': None,
#                'postal_code': None,
#                'region': None,
#                'store_number': None},
#   'logo_url': None,
#   'merchant_entity_id': None,
#   'merchant_name': None,
#   'name': 'INTRST PYMNT',
#   'payment_channel': 'other',
#   'payment_meta': {'by_order_of': None,
#                    'payee': None,
#                    'payer': None,
#                    'payment_method': None,
#                    'payment_processor': None,
#                    'ppd_id': None,
#                    'reason': None,
#                    'reference_number': None},
#   'pending': False,
#   'pending_transaction_id': None,
#   'personal_finance_category': {'confidence_level': 'LOW',
#                                 'detailed': 'INCOME_WAGES',
#                                 'primary': 'INCOME',
#                                 'version': 'v1'},
#   'personal_finance_category_icon_url': 'https://plaid-category-icons.plaid.com/PFC_INCOME.png',
#   'transaction_code': None,
#   'transaction_id': 'Wa3k6PyvpXczzBQ8rRrRhZd8rdnqNnt6GKGpz',
#   'transaction_type': 'special',
#   'unofficial_currency_code': None,
#   'website': None},
#  {'account_id': 'ALJK7Bk84wcwwyJ5q6q6hmE3bnM1ggF9BeLpg',
#   'account_owner': None,
#   'amount': 25.0,
#   'authorized_date': datetime.date(2025, 9, 15),
#   'authorized_datetime': None,
#   'category': None,
#   'category_id': None,
#   'check_number': None,
#   'counterparties': [],
#   'date': datetime.date(2025, 9, 16),
#   'datetime': None,
#   'iso_currency_code': 'USD',
#   'location': {'address': None,
#                'city': None,
#                'country': None,
#                'lat': None,
#                'lon': None,
#                'postal_code': None,
#                'region': None,
#                'store_number': None},
#   'logo_url': None,
#   'merchant_entity_id': None,
#   'merchant_name': None,
#   'name': 'CREDIT CARD 3333 PAYMENT *//',
#   'payment_channel': 'other',
#   'payment_meta': {'by_order_of': None,
#                    'payee': None,
#                    'payer': None,
#                    'payment_method': None,
#                    'payment_processor': None,
#                    'ppd_id': None,
#                    'reason': None,
#                    'reference_number': None},
#   'pending': False,
#   'pending_transaction_id': None,
#   'personal_finance_category': {'confidence_level': 'LOW',
#                                 'detailed': 'LOAN_PAYMENTS_OTHER_PAYMENT',
#                                 'primary': 'LOAN_PAYMENTS',
#                                 'version': 'v1'},
#   'personal_finance_category_icon_url': 'https://plaid-category-icons.plaid.com/PFC_LOAN_PAYMENTS.png',
#   'transaction_code': None,
#   'transaction_id': 'ALJK7Bk84wcwwyJ5q6q6hmEDGErpKru9vEvgQ',
#   'transaction_type': 'special',
#   'unofficial_currency_code': None,
#   'website': None},
#  {'account_id': 'ALJK7Bk84wcwwyJ5q6q6hmE3bnM1ggF9BeLpg',
#   'account_owner': None,
#   'amount': -4.22,
#   'authorized_date': datetime.date(2025, 9, 11),
#   'authorized_datetime': None,
#   'category': None,
#   'category_id': None,
#   'check_number': None,
#   'counterparties': [],
#   'date': datetime.date(2025, 9, 11),
#   'datetime': None,
#   'iso_currency_code': 'USD',
#   'location': {'address': None,
#                'city': None,
#                'country': None,
#                'lat': None,
#                'lon': None,
#                'postal_code': None,
#                'region': None,
#                'store_number': None},
#   'logo_url': None,
#   'merchant_entity_id': None,
#   'merchant_name': None,
#   'name': 'INTRST PYMNT',
#   'payment_channel': 'other',
#   'payment_meta': {'by_order_of': None,
#                    'payee': None,
#                    'payer': None,
#                    'payment_method': None,
#                    'payment_processor': None,
#                    'ppd_id': None,
#                    'reason': None,
#                    'reference_number': None},
#   'pending': False,
#   'pending_transaction_id': None,
#   'personal_finance_category': {'confidence_level': 'LOW',
#                                 'detailed': 'INCOME_WAGES',
#                                 'primary': 'INCOME',
#                                 'version': 'v1'},
#   'personal_finance_category_icon_url': 'https://plaid-category-icons.plaid.com/PFC_INCOME.png',
#   'transaction_code': None,
#   'transaction_id': 'GWJdLNxvRnI66XlzoZoZUdq41q7pD7u64y4b4',
#   'transaction_type': 'special',
#   'unofficial_currency_code': None,
#   'website': None}]

# %%
import plaid
from plaid.model.transactions_sync_request import TransactionsSyncRequest

def sync_transactions(access_token):
    request = TransactionsSyncRequest(access_token=access_token)
    response = client.transactions_sync(request)

    all_added = response["added"]
    all_modified = response["modified"]
    all_removed = response["removed"]
    cursor = response["next_cursor"]

    while response["has_more"]:
        request = TransactionsSyncRequest(
            access_token=access_token,
            cursor=cursor
        )
        response = client.transactions_sync(request)

        all_added += response["added"]
        all_modified += response["modified"]
        all_removed += response["removed"]
        cursor = response["next_cursor"]

    return {
        "added": all_added,
        "modified": all_modified,
        "removed": all_removed,
        "cursor": cursor
    }

# --- RUN IT ---
result = sync_transactions(access_credentials["access_token"])

print("Added:", len(result["added"]))
print("Modified:", len(result["modified"]))
print("Removed:", len(result["removed"]))
print("Cursor:", result["cursor"])

result["added"][:5]
# Out:
# Added: 24
# Modified: 0
# Removed: 0
# Cursor: CAESJUdXSmRMTnh2Um5JNjZYbHpvWm9aVWRxNDFxN3BEN3U2NHk0YjQaCwjisb/JBhCwvf4FIgsI4rG/yQYQsL3+BSoLCOKxv8kGELC9/gU=
# [{'account_id': 'Wa3k6PyvpXczzBQ8rRrRhZdvz9RpXXC6Ba3RL',
#   'account_owner': None,
#   'amount': 6.33,
#   'authorized_date': datetime.date(2025, 11, 27),
#   'authorized_datetime': None,
#   'category': None,
#   'category_id': None,
#   'check_number': None,
#   'counterparties': [{'confidence_level': 'VERY_HIGH',
#                       'entity_id': 'eyg8o776k0QmNgVpAmaQj4WgzW9Qzo6O51gdd',
#                       'logo_url': 'https://plaid-merchant-logos.plaid.com/uber_1060.png',
#                       'name': 'Uber',
#                       'phone_number': None,
#                       'type': 'merchant',
#                       'website': 'uber.com'}],
#   'date': datetime.date(2025, 11, 28),
#   'datetime': None,
#   'iso_currency_code': 'USD',
#   'location': {'address': None,
#                'city': None,
#                'country': None,
#                'lat': None,
#                'lon': None,
#                'postal_code': None,
#                'region': None,
#                'store_number': None},
#   'logo_url': 'https://plaid-merchant-logos.plaid.com/uber_1060.png',
#   'merchant_entity_id': 'eyg8o776k0QmNgVpAmaQj4WgzW9Qzo6O51gdd',
#   'merchant_name': 'Uber',
#   'name': 'Uber 072515 SF**POOL**',
#   'payment_channel': 'online',
#   'payment_meta': {'by_order_of': None,
#                    'payee': None,
#                    'payer': None,
#                    'payment_method': None,
#                    'payment_processor': None,
#                    'ppd_id': None,
#                    'reason': None,
#                    'reference_number': None},
#   'pending': False,
#   'pending_transaction_id': None,
#   'personal_finance_category': {'confidence_level': 'VERY_HIGH',
#                                 'detailed': 'TRANSPORTATION_TAXIS_AND_RIDE_SHARES',
#                                 'primary': 'TRANSPORTATION',
#                                 'version': 'v1'},
#   'personal_finance_category_icon_url': 'https://plaid-category-icons.plaid.com/PFC_TRANSPORTATION.png',
#   'transaction_code': None,
#   'transaction_id': 'mmvA18XdaMULLNaZQdQdIeVXmGe66EfkgwmMK',
#   'transaction_type': 'special',
#   'unofficial_currency_code': None,
#   'website': 'uber.com'},
#  {'account_id': 'Wa3k6PyvpXczzBQ8rRrRhZdvz9RpXXC6Ba3RL',
#   'account_owner': None,
#   'amount': 5.4,
#   'authorized_date': datetime.date(2025, 11, 14),
#   'authorized_datetime': None,
#   'category': None,
#   'category_id': None,
#   'check_number': None,
#   'counterparties': [{'confidence_level': 'VERY_HIGH',
#                       'entity_id': 'eyg8o776k0QmNgVpAmaQj4WgzW9Qzo6O51gdd',
#                       'logo_url': 'https://plaid-merchant-logos.plaid.com/uber_1060.png',
#                       'name': 'Uber',
#                       'phone_number': None,
#                       'type': 'merchant',
#                       'website': 'uber.com'}],
#   'date': datetime.date(2025, 11, 15),
#   'datetime': None,
#   'iso_currency_code': 'USD',
#   'location': {'address': None,
#                'city': None,
#                'country': None,
#                'lat': None,
#                'lon': None,
#                'postal_code': None,
#                'region': None,
#                'store_number': None},
#   'logo_url': 'https://plaid-merchant-logos.plaid.com/uber_1060.png',
#   'merchant_entity_id': 'eyg8o776k0QmNgVpAmaQj4WgzW9Qzo6O51gdd',
#   'merchant_name': 'Uber',
#   'name': 'Uber 063015 SF**POOL**',
#   'payment_channel': 'online',
#   'payment_meta': {'by_order_of': None,
#                    'payee': None,
#                    'payer': None,
#                    'payment_method': None,
#                    'payment_processor': None,
#                    'ppd_id': None,
#                    'reason': None,
#                    'reference_number': None},
#   'pending': False,
#   'pending_transaction_id': None,
#   'personal_finance_category': {'confidence_level': 'VERY_HIGH',
#                                 'detailed': 'TRANSPORTATION_TAXIS_AND_RIDE_SHARES',
#                                 'primary': 'TRANSPORTATION',
#                                 'version': 'v1'},
#   'personal_finance_category_icon_url': 'https://plaid-category-icons.plaid.com/PFC_TRANSPORTATION.png',
#   'transaction_code': None,
#   'transaction_id': 'y4wrm8WLDkC66Gn7xPxPU1We3V1PPZCM4L3Wk',
#   'transaction_type': 'special',
#   'unofficial_currency_code': None,
#   'website': 'uber.com'},
#  {'account_id': 'Wa3k6PyvpXczzBQ8rRrRhZdvz9RpXXC6Ba3RL',
#   'account_owner': None,
#   'amount': -500.0,
#   'authorized_date': datetime.date(2025, 11, 13),
#   'authorized_datetime': None,
#   'category': None,
#   'category_id': None,
#   'check_number': None,
#   'counterparties': [{'confidence_level': 'VERY_HIGH',
#                       'entity_id': 'NKDjqyAdQQzpyeD8qpLnX0D6yvLe2KYKYYzQ4',
#                       'logo_url': 'https://plaid-merchant-logos.plaid.com/united_airlines_1065.png',
#                       'name': 'United Airlines',
#                       'phone_number': None,
#                       'type': 'merchant',
#                       'website': 'united.com'}],
#   'date': datetime.date(2025, 11, 13),
#   'datetime': None,
#   'iso_currency_code': 'USD',
#   'location': {'address': None,
#                'city': None,
#                'country': None,
#                'lat': None,
#                'lon': None,
#                'postal_code': None,
#                'region': None,
#                'store_number': None},
#   'logo_url': 'https://plaid-merchant-logos.plaid.com/united_airlines_1065.png',
#   'merchant_entity_id': 'NKDjqyAdQQzpyeD8qpLnX0D6yvLe2KYKYYzQ4',
#   'merchant_name': 'United Airlines',
#   'name': 'United Airlines',
#   'payment_channel': 'in store',
#   'payment_meta': {'by_order_of': None,
#                    'payee': None,
#                    'payer': None,
#                    'payment_method': None,
#                    'payment_processor': None,
#                    'ppd_id': None,
#                    'reason': None,
#                    'reference_number': None},
#   'pending': False,
#   'pending_transaction_id': None,
#   'personal_finance_category': {'confidence_level': 'VERY_HIGH',
#                                 'detailed': 'TRAVEL_FLIGHTS',
#                                 'primary': 'TRAVEL',
#                                 'version': 'v1'},
#   'personal_finance_category_icon_url': 'https://plaid-category-icons.plaid.com/PFC_TRAVEL.png',
#   'transaction_code': None,
#   'transaction_id': '9PJ639MQ5RC88kgejVjVf6deVp6AAjCB4bGVl',
#   'transaction_type': 'special',
#   'unofficial_currency_code': None,
#   'website': 'united.com'},
#  {'account_id': 'Wa3k6PyvpXczzBQ8rRrRhZdvz9RpXXC6Ba3RL',
#   'account_owner': None,
#   'amount': 12.0,
#   'authorized_date': datetime.date(2025, 11, 12),
#   'authorized_datetime': None,
#   'category': None,
#   'category_id': None,
#   'check_number': None,
#   'counterparties': [{'confidence_level': 'VERY_HIGH',
#                       'entity_id': 'vzWXDWBjB06j5BJoD3Jo84OJZg7JJzmqOZA22',
#                       'logo_url': 'https://plaid-merchant-logos.plaid.com/mcdonalds_619.png',
#                       'name': "McDonald's",
#                       'phone_number': None,
#                       'type': 'merchant',
#                       'website': 'mcdonalds.com'}],
#   'date': datetime.date(2025, 11, 12),
#   'datetime': None,
#   'iso_currency_code': 'USD',
#   'location': {'address': None,
#                'city': None,
#                'country': None,
#                'lat': None,
#                'lon': None,
#                'postal_code': None,
#                'region': None,
#                'store_number': '3322'},
#   'logo_url': 'https://plaid-merchant-logos.plaid.com/mcdonalds_619.png',
#   'merchant_entity_id': 'vzWXDWBjB06j5BJoD3Jo84OJZg7JJzmqOZA22',
#   'merchant_name': "McDonald's",
#   'name': "McDonald's",
#   'payment_channel': 'in store',
#   'payment_meta': {'by_order_of': None,
#                    'payee': None,
#                    'payer': None,
#                    'payment_method': None,
#                    'payment_processor': None,
#                    'ppd_id': None,
#                    'reason': None,
#                    'reference_number': None},
#   'pending': False,
#   'pending_transaction_id': None,
#   'personal_finance_category': {'confidence_level': 'VERY_HIGH',
#                                 'detailed': 'FOOD_AND_DRINK_FAST_FOOD',
#                                 'primary': 'FOOD_AND_DRINK',
#                                 'version': 'v1'},
#   'personal_finance_category_icon_url': 'https://plaid-category-icons.plaid.com/PFC_FOOD_AND_DRINK.png',
#   'transaction_code': None,
#   'transaction_id': 'vxvlG8WZ3gFllmeyzNzNime9zwmbbGFJq4znW',
#   'transaction_type': 'place',
#   'unofficial_currency_code': None,
#   'website': 'mcdonalds.com'},
#  {'account_id': 'Wa3k6PyvpXczzBQ8rRrRhZdvz9RpXXC6Ba3RL',
#   'account_owner': None,
#   'amount': 4.33,
#   'authorized_date': datetime.date(2025, 11, 12),
#   'authorized_datetime': None,
#   'category': None,
#   'category_id': None,
#   'check_number': None,
#   'counterparties': [{'confidence_level': 'VERY_HIGH',
#                       'entity_id': 'NZAJQ5wYdo1W1p39X5q5gpb15OMe39pj4pJBb',
#                       'logo_url': 'https://plaid-merchant-logos.plaid.com/starbucks_956.png',
#                       'name': 'Starbucks',
#                       'phone_number': None,
#                       'type': 'merchant',
#                       'website': 'starbucks.com'}],
#   'date': datetime.date(2025, 11, 12),
#   'datetime': None,
#   'iso_currency_code': 'USD',
#   'location': {'address': None,
#                'city': None,
#                'country': None,
#                'lat': None,
#                'lon': None,
#                'postal_code': None,
#                'region': None,
#                'store_number': None},
#   'logo_url': 'https://plaid-merchant-logos.plaid.com/starbucks_956.png',
#   'merchant_entity_id': 'NZAJQ5wYdo1W1p39X5q5gpb15OMe39pj4pJBb',
#   'merchant_name': 'Starbucks',
#   'name': 'Starbucks',
#   'payment_channel': 'in store',
#   'payment_meta': {'by_order_of': None,
#                    'payee': None,
#                    'payer': None,
#                    'payment_method': None,
#                    'payment_processor': None,
#                    'ppd_id': None,
#                    'reason': None,
#                    'reference_number': None},
#   'pending': False,
#   'pending_transaction_id': None,
#   'personal_finance_category': {'confidence_level': 'VERY_HIGH',
#                                 'detailed': 'FOOD_AND_DRINK_COFFEE',
#                                 'primary': 'FOOD_AND_DRINK',
#                                 'version': 'v1'},
#   'personal_finance_category_icon_url': 'https://plaid-category-icons.plaid.com/PFC_FOOD_AND_DRINK.png',
#   'transaction_code': None,
#   'transaction_id': 'RzqGmxyvZwiVVBNpb3b3uDgxE4D55pCMarlXa',
#   'transaction_type': 'place',
#   'unofficial_currency_code': None,
#   'website': 'starbucks.com'}]
